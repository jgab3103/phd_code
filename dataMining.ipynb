# %%
import pandas as pd
# %pylab inline
import json
from pandas.io.json import json_normalize
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_pickle('data_set_as_pk.pkl')

# %%
users = {"Angelica": {"Blues Traveler": 3.5, "Broken Bells": 2.0, "Norah Jones": 4.5, "Phoenix": 5.0, "Slightly Stoopid": 1.5, "The Strokes": 2.5, "Vampire Weekend": 2.0},
         "Bill":{"Blues Traveler": 2.0, "Broken Bells": 3.5, "Deadmau5": 4.0, "Phoenix": 2.0, "Slightly Stoopid": 3.5, "Vampire Weekend": 3.0},
         "Chan": {"Blues Traveler": 5.0, "Broken Bells": 1.0, "Deadmau5": 1.0, "Norah Jones": 3.0, "Phoenix": 5, "Slightly Stoopid": 1.0},
         "Dan": {"Blues Traveler": 3.0, "Broken Bells": 4.0, "Deadmau5": 4.5, "Phoenix": 3.0, "Slightly Stoopid": 4.5, "The Strokes": 4.0, "Vampire Weekend": 2.0},
         "Hailey": {"Broken Bells": 4.0, "Deadmau5": 1.0, "Norah Jones": 4.0, "The Strokes": 4.0, "Vampire Weekend": 1.0},
         "Jordyn":  {"Broken Bells": 4.5, "Deadmau5": 4.0, "Norah Jones": 5.0, "Phoenix": 5.0, "Slightly Stoopid": 4.5, "The Strokes": 4.0, "Vampire Weekend": 4.0},
         "Sam": {"Blues Traveler": 5.0, "Broken Bells": 2.0, "Norah Jones": 3.0, "Phoenix": 5.0, "Slightly Stoopid": 4.0, "The Strokes": 5.0},
         "Veronica": {"Blues Traveler": 3.0, "Norah Jones": 5.0, "Phoenix": 4.0, "Slightly Stoopid": 2.5, "The Strokes": 3.0}
        }

# %%
df1 = pd.DataFrame.from_dict(users)

# %%
df1 = df1.T

# %%
df1.columns
# Out:
# Index([u'Blues Traveler', u'Broken Bells', u'Deadmau5', u'Norah Jones',
#        u'Phoenix', u'Slightly Stoopid', u'The Strokes', u'Vampire Weekend'],
#       dtype='object')

# %%
for eachCol in df1.columns:
    for eachUser in df1.index:
        for eachOtherUser in df1.index:
            print eachCol, df1[eachCol], eachOtherUser
# Out:
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Angelica
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Bill
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Chan
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Dan
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Hailey
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Jordyn
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Sam
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Veronica
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Angelica
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Bill
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Chan
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Dan
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Hailey
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Jordyn
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Sam
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Veronica
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Angelica
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Bill
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Chan
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Dan
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Hailey
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Jordyn
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Sam
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Veronica
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Angelica
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Bill
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Chan
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Dan
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Hailey
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Jordyn
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Sam
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Veronica
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Angelica
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Bill
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Chan
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Dan
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Hailey
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Jordyn
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Sam
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Veronica
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Angelica
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Bill
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Chan
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Dan
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Hailey
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Jordyn
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Sam
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Veronica
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Angelica
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Bill
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Chan
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Dan
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Hailey
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Jordyn
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Sam
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Veronica
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Angelica
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Bill
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Chan
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Dan
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Hailey
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Jordyn
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Sam
# Blues Traveler Angelica    3.5
# Bill        2.0
# Chan        5.0
# Dan         3.0
# Hailey      NaN
# Jordyn      NaN
# Sam         5.0
# Veronica    3.0
# Name: Blues Traveler, dtype: float64 Veronica
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Angelica
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Bill
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Chan
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Dan
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Hailey
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Jordyn
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Sam
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Veronica
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Angelica
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Bill
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Chan
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Dan
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Hailey
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Jordyn
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Sam
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Veronica
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Angelica
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Bill
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Chan
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Dan
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Hailey
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Jordyn
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Sam
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Veronica
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Angelica
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Bill
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Chan
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Dan
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Hailey
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Jordyn
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Sam
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Veronica
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Angelica
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Bill
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Chan
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Dan
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Hailey
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Jordyn
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Sam
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Veronica
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Angelica
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Bill
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Chan
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Dan
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Hailey
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Jordyn
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Sam
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Veronica
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Angelica
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Bill
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Chan
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Dan
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Hailey
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Jordyn
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Sam
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Veronica
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Angelica
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Bill
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Chan
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Dan
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Hailey
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Jordyn
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Sam
# Broken Bells Angelica    2.0
# Bill        3.5
# Chan        1.0
# Dan         4.0
# Hailey      4.0
# Jordyn      4.5
# Sam         2.0
# Veronica    NaN
# Name: Broken Bells, dtype: float64 Veronica
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Angelica
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Bill
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Chan
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Dan
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Hailey
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Jordyn
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Sam
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Veronica
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Angelica
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Bill
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Chan
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Dan
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Hailey
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Jordyn
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Sam
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Veronica
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Angelica
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Bill
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Chan
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Dan
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Hailey
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Jordyn
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Sam
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Veronica
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Angelica
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Bill
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Chan
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Dan
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Hailey
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Jordyn
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Sam
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Veronica
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Angelica
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Bill
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Chan
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Dan
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Hailey
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Jordyn
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Sam
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Veronica
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Angelica
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Bill
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Chan
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Dan
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Hailey
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Jordyn
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Sam
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Veronica
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Angelica
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Bill
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Chan
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Dan
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Hailey
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Jordyn
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Sam
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Veronica
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Angelica
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Bill
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Chan
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Dan
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Hailey
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Jordyn
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Sam
# Deadmau5 Angelica    NaN
# Bill        4.0
# Chan        1.0
# Dan         4.5
# Hailey      1.0
# Jordyn      4.0
# Sam         NaN
# Veronica    NaN
# Name: Deadmau5, dtype: float64 Veronica
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Angelica
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Bill
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Chan
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Dan
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Hailey
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Jordyn
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Sam
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Veronica
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Angelica
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Bill
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Chan
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Dan
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Hailey
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Jordyn
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Sam
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Veronica
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Angelica
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Bill
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Chan
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Dan
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Hailey
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Jordyn
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Sam
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Veronica
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Angelica
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Bill
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Chan
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Dan
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Hailey
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Jordyn
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Sam
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Veronica
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Angelica
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Bill
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Chan
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Dan
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Hailey
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Jordyn
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Sam
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Veronica
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Angelica
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Bill
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Chan
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Dan
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Hailey
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Jordyn
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Sam
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Veronica
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Angelica
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Bill
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Chan
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Dan
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Hailey
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Jordyn
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Sam
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Veronica
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Angelica
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Bill
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Chan
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Dan
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Hailey
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Jordyn
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Sam
# Norah Jones Angelica    4.5
# Bill        NaN
# Chan        3.0
# Dan         NaN
# Hailey      4.0
# Jordyn      5.0
# Sam         3.0
# Veronica    5.0
# Name: Norah Jones, dtype: float64 Veronica
# Phoenix Angelica     5
# Bill         2
# Chan         5
# Dan          3
# Hailey     NaN
# Jordyn       5
# Sam          5
# Veronica     4
# Name: Phoenix, dtype: float64 Angelica
# Phoenix Angelica     5
# Bill         2
# Chan         5
# Dan          3
# Hailey     NaN
# Jordyn       5
# Sam          5
# Veronica     4
# Name: Phoenix, dtype: float64 Bill
# Phoenix Angelica     5
# Bill         2
# Chan         5
# Dan          3
# Hailey     NaN
# Jordyn       5
# Sam          5
# Veronica     4
# Name: Phoenix, dtype: float64 Chan
# Phoenix Angelica     5
# Bill         2
# Chan         5
# Dan          3
# Hailey     NaN
# Jordyn       5
# Sam          5
# Veronica     4
# Name: Phoenix, dtype: float64 Dan
# Phoenix Angelica     5
# Bill         2
# Chan         5
# Dan          3
# Hailey     NaN
# Jordyn       5
# Sam          5
# Veronica     4
# Name: Phoenix, dtype: float64 Hailey
# Phoenix Angelica     5
# Bill         2
# Chan         5
# Dan          3
# Hailey     NaN
# Jordyn       5
# Sam          5
# Veronica     4
# Name: Phoenix, dtype: float64 Jordyn
# Phoenix Angelica     5
# Bill         2
# Chan         5
# Dan          3
# Hailey     NaN
# Jordyn       5
# Sam          5
# Veronica     4
# Name: Phoenix, dtype: float64 Sam
# Phoenix Angelica     5
# Bill         2
# Chan         5
# Dan          3
# Hailey     NaN
# Jordyn       5
# Sam          5
# Veronica     4
# Name: Phoenix, dtype: float64 Veronica
# Phoenix Angelica     5
# Bill         2
# Chan         5
# Dan          3
# Hailey     NaN
# Jordyn       5
# Sam          5
# Veronica     4
# Name: Phoenix, dtype: float64 Angelica
# Phoenix Angelica     5
# Bill         2
# Chan         5
# Dan          3
# Hailey     NaN
# Jordyn       5
# Sam          5
# Veronica     4
# Name: Phoenix, dtype: float64 Bill
# Phoenix Angelica     5
# Bill         2
# Chan         5
# Dan          3
# Hailey     NaN
# ...
# Dan         4.0
# Hailey      4.0
# Jordyn      4.0
# Sam         5.0
# Veronica    3.0
# Name: The Strokes, dtype: float64 Veronica
# The Strokes Angelica    2.5
# Bill        NaN
# Chan        NaN
# Dan         4.0
# Hailey      4.0
# Jordyn      4.0
# Sam         5.0
# Veronica    3.0
# Name: The Strokes, dtype: float64 Angelica
# The Strokes Angelica    2.5
# Bill        NaN
# Chan        NaN
# Dan         4.0
# Hailey      4.0
# Jordyn      4.0
# Sam         5.0
# Veronica    3.0
# Name: The Strokes, dtype: float64 Bill
# The Strokes Angelica    2.5
# Bill        NaN
# Chan        NaN
# Dan         4.0
# Hailey      4.0
# Jordyn      4.0
# Sam         5.0
# Veronica    3.0
# Name: The Strokes, dtype: float64 Chan
# The Strokes Angelica    2.5
# Bill        NaN
# Chan        NaN
# Dan         4.0
# Hailey      4.0
# Jordyn      4.0
# Sam         5.0
# Veronica    3.0
# Name: The Strokes, dtype: float64 Dan
# The Strokes Angelica    2.5
# Bill        NaN
# Chan        NaN
# Dan         4.0
# Hailey      4.0
# Jordyn      4.0
# Sam         5.0
# Veronica    3.0
# Name: The Strokes, dtype: float64 Hailey
# The Strokes Angelica    2.5
# Bill        NaN
# Chan        NaN
# Dan         4.0
# Hailey      4.0
# Jordyn      4.0
# Sam         5.0
# Veronica    3.0
# Name: The Strokes, dtype: float64 Jordyn
# The Strokes Angelica    2.5
# Bill        NaN
# Chan        NaN
# Dan         4.0
# Hailey      4.0
# Jordyn      4.0
# Sam         5.0
# Veronica    3.0
# Name: The Strokes, dtype: float64 Sam
# The Strokes Angelica    2.5
# Bill        NaN
# Chan        NaN
# Dan         4.0
# Hailey      4.0
# Jordyn      4.0
# Sam         5.0
# Veronica    3.0
# Name: The Strokes, dtype: float64 Veronica
# The Strokes Angelica    2.5
# Bill        NaN
# Chan        NaN
# Dan         4.0
# Hailey      4.0
# Jordyn      4.0
# Sam         5.0
# Veronica    3.0
# Name: The Strokes, dtype: float64 Angelica
# The Strokes Angelica    2.5
# Bill        NaN
# Chan        NaN
# Dan         4.0
# Hailey      4.0
# Jordyn      4.0
# Sam         5.0
# Veronica    3.0
# Name: The Strokes, dtype: float64 Bill
# The Strokes Angelica    2.5
# Bill        NaN
# Chan        NaN
# Dan         4.0
# Hailey      4.0
# Jordyn      4.0
# Sam         5.0
# Veronica    3.0
# Name: The Strokes, dtype: float64 Chan
# The Strokes Angelica    2.5
# Bill        NaN
# Chan        NaN
# Dan         4.0
# Hailey      4.0
# Jordyn      4.0
# Sam         5.0
# Veronica    3.0
# Name: The Strokes, dtype: float64 Dan
# The Strokes Angelica    2.5
# Bill        NaN
# Chan        NaN
# Dan         4.0
# Hailey      4.0
# Jordyn      4.0
# Sam         5.0
# Veronica    3.0
# Name: The Strokes, dtype: float64 Hailey
# The Strokes Angelica    2.5
# Bill        NaN
# Chan        NaN
# Dan         4.0
# Hailey      4.0
# Jordyn      4.0
# Sam         5.0
# Veronica    3.0
# Name: The Strokes, dtype: float64 Jordyn
# The Strokes Angelica    2.5
# Bill        NaN
# Chan        NaN
# Dan         4.0
# Hailey      4.0
# Jordyn      4.0
# Sam         5.0
# Veronica    3.0
# Name: The Strokes, dtype: float64 Sam
# The Strokes Angelica    2.5
# Bill        NaN
# Chan        NaN
# Dan         4.0
# Hailey      4.0
# Jordyn      4.0
# Sam         5.0
# Veronica    3.0
# Name: The Strokes, dtype: float64 Veronica
# The Strokes Angelica    2.5
# Bill        NaN
# Chan        NaN
# Dan         4.0
# Hailey      4.0
# Jordyn      4.0
# Sam         5.0
# Veronica    3.0
# Name: The Strokes, dtype: float64 Angelica
# The Strokes Angelica    2.5
# Bill        NaN
# Chan        NaN
# Dan         4.0
# Hailey      4.0
# Jordyn      4.0
# Sam         5.0
# Veronica    3.0
# Name: The Strokes, dtype: float64 Bill
# The Strokes Angelica    2.5
# Bill        NaN
# Chan        NaN
# Dan         4.0
# Hailey      4.0
# Jordyn      4.0
# Sam         5.0
# Veronica    3.0
# Name: The Strokes, dtype: float64 Chan
# The Strokes Angelica    2.5
# Bill        NaN
# Chan        NaN
# Dan         4.0
# Hailey      4.0
# Jordyn      4.0
# Sam         5.0
# Veronica    3.0
# Name: The Strokes, dtype: float64 Dan
# The Strokes Angelica    2.5
# Bill        NaN
# Chan        NaN
# Dan         4.0
# Hailey      4.0
# Jordyn      4.0
# Sam         5.0
# Veronica    3.0
# Name: The Strokes, dtype: float64 Hailey
# The Strokes Angelica    2.5
# Bill        NaN
# Chan        NaN
# Dan         4.0
# Hailey      4.0
# Jordyn      4.0
# Sam         5.0
# Veronica    3.0
# Name: The Strokes, dtype: float64 Jordyn
# The Strokes Angelica    2.5
# Bill        NaN
# Chan        NaN
# Dan         4.0
# Hailey      4.0
# Jordyn      4.0
# Sam         5.0
# Veronica    3.0
# Name: The Strokes, dtype: float64 Sam
# The Strokes Angelica    2.5
# Bill        NaN
# Chan        NaN
# Dan         4.0
# Hailey      4.0
# Jordyn      4.0
# Sam         5.0
# Veronica    3.0
# Name: The Strokes, dtype: float64 Veronica
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Angelica
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Bill
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Chan
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Dan
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Hailey
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Jordyn
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Sam
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Veronica
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Angelica
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Bill
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Chan
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Dan
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Hailey
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Jordyn
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Sam
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Veronica
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Angelica
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Bill
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Chan
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Dan
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Hailey
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Jordyn
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Sam
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Veronica
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Angelica
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Bill
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Chan
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Dan
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Hailey
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Jordyn
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Sam
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Veronica
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Angelica
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Bill
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Chan
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Dan
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Hailey
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Jordyn
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Sam
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Veronica
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Angelica
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Bill
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Chan
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Dan
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Hailey
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Jordyn
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Sam
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Veronica
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Angelica
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Bill
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Chan
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Dan
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Hailey
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Jordyn
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Sam
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Veronica
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Angelica
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Bill
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Chan
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Dan
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Hailey
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Jordyn
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Sam
# Vampire Weekend Angelica     2
# Bill         3
# Chan       NaN
# Dan          2
# Hailey       1
# Jordyn       4
# Sam        NaN
# Veronica   NaN
# Name: Vampire Weekend, dtype: float64 Veronica

# %%
for stuff in df1:
    print stuff.values()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-67-d90668425046> in <module>()
#       1 for stuff in df1:
# ----> 2     print stuff.values()
#
# AttributeError: 'str' object has no attribute 'values'
