# %% [markdown]
# <h1>Data Preparation - Polyphonic</h1>

# %%
import music21 as mu
import numpy as np
import pandas as pd
# %pylab inline
import math
import json
from IPython.core.display import HTML
from IPython.core.display import Image
# %load_ext music21.ipython21.ipExtension
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
globalPhraseCount = 0

# %%
#mu_stella = mu.converter.parse('xml_files/stella_by_starlight.xml')
#mu_autumn = mu.converter.parse('xml_files/autumn_leaves_v2.xml')
#mu_if_i_were = mu.converter.parse('xml_files/if_i_were_a_bell.xml')
#mu_groovin = mu.converter.parse('xml_files/groovin_high.xml')
#mu_all_the_things = mu.converter.parse('xml_files/all_the_things_you_are.xml')

# %%
#import files with music21 for visual data validation


#prep data functions
def prep_data_from_xml(xml_file=''):
    global globalPhraseCount
    globalPhraseCount = 0
    notes = mu.converter.parse(xml_file)
    i = 0
    parts_list = []
    while i < len(notes.parts):
        parts_list.append(notes.parts[i])
        i = i + 1


    notes_list = []
    part_name_list = []
    for part in parts_list:
        a = part.flat.getElementsByClass(mu.note.Note)
        b = part.id
        notes_list.append(a)
        part_name_list.append(b)


#create lists
    mel_notes = []
    mel_pos = []
    mel_duration = []

    solo_notes = []
    solo_pos = []
    solo_duration = []

    root_notes = []
    root_pos = []
    root_duration = []


    third_pos = []
    third_notes = []
    third_duration = []
    
    fifth_notes = []
    fifth_pos = []
    fifth_duration = []

    seventh_notes = []
    seventh_pos = []
    seventh_duration = []

#add notes from parts into lists
    for note in notes_list[0]:
        mel_pos.append(note.offset)
        mel_notes.append(note.midi)
        mel_duration.append(note.duration.quarterLength)
    
    for note in notes_list[1]:
        solo_pos.append(note.offset)
        solo_notes.append(note.midi)
        solo_duration.append(note.duration.quarterLength)
        
    for note in notes_list[5]:
        root_pos.append(note.offset)
        root_notes.append(note.midi)
        root_duration.append(note.duration.quarterLength)   
    
    for note in notes_list[4]:
        third_pos.append(note.offset)
        third_notes.append(note.midi)
        third_duration.append(note.duration.quarterLength)
        
    for note in notes_list[3]:
        fifth_pos.append(note.offset)
        fifth_notes.append(note.midi)
        fifth_duration.append(note.duration.quarterLength)
    
    for note in notes_list[2]:
        seventh_pos.append(note.offset)
        seventh_notes.append(note.midi)
        seventh_duration.append(note.duration.quarterLength)
        

# Create Data Frames for each part showing location and frequency</p>



    solo_df = pd.DataFrame({'part':0,
                   'noteLocation': solo_pos,
                   'noteFrequency': solo_notes,
                   'noteDuration' : solo_duration,
                   })

    root_df = pd.DataFrame({'part':1,
                  'noteLocation':root_pos,
                  'noteFrequency': root_notes,
                  'noteDuration' : root_duration,
                  })
    third_df = pd.DataFrame({'part':2,
                  'noteLocation':third_pos,
                  'noteFrequency': third_notes,
                  'noteDuration' : third_duration,
                  })

    fifth_df = pd.DataFrame({'part': 3,
                         'noteLocation':fifth_pos,
                         'noteFrequency':fifth_notes,
                         'noteDuration':fifth_duration,
                         })
    seventh_df = pd.DataFrame({'part': 4,
                           'noteLocation':seventh_pos,
                           'noteFrequency':seventh_notes,
                           'noteDuration' : seventh_duration,
                           })



    solo_root_df = solo_df.append(root_df)
    solo_root_third_df = solo_root_df.append(third_df)
    solo_root_third_fifth_df = solo_root_third_df.append(fifth_df)
    solo_root_third_fifth_seventh_df = solo_root_third_fifth_df.append(seventh_df)
    all_note_events = solo_root_third_fifth_seventh_df
    all_note_events = all_note_events.sort('noteLocation')


    def create_root_col(note_event):
        if note_event['part'] == 1:
            return note_event['noteFrequency']
        else:
            return None

    def create_third_col(note_event):
        if note_event['part'] == 2:
            return note_event['noteFrequency']
        else:
            return None
    
    def create_fifth_col(note_event):
        if note_event['part'] == 3:
            return note_event['noteFrequency']
        else:
            return None
    
    def create_seventh_col(note_event):
        if note_event['part'] == 4:
            return note_event['noteFrequency']
        else:
            return None
    
    

    all_note_events['jazzRootFrequency'] = all_note_events.apply(create_root_col, axis=1)
    all_note_events['jazzThirdFrequency'] = all_note_events.apply(create_third_col, axis=1)
    all_note_events['jazzFifthFrequency'] = all_note_events.apply(create_fifth_col, axis=1)
    all_note_events['jazzSeventhFrequency'] = all_note_events.apply(create_seventh_col, axis=1)


    all_note_events = all_note_events.sort(['noteLocation', 'jazzRootFrequency'], ascending=[True, False])
    all_note_events['jazzRootFrequency'] = all_note_events['jazzRootFrequency'].fillna(method="pad")
    
    all_note_events = all_note_events.sort(['noteLocation', 'jazzThirdFrequency'], ascending=[True, False])
    all_note_events['jazzThirdFrequency'] = all_note_events['jazzThirdFrequency'].fillna(method='pad')
    
    all_note_events = all_note_events.sort(['noteLocation', 'jazzFifthFrequency'], ascending=[True, False])
    all_note_events['jazzFifthFrequency'] = all_note_events['jazzFifthFrequency'].fillna(method='pad')

    all_note_events = all_note_events.sort(['noteLocation', 'jazzSeventhFrequency'], ascending=[True, False])
    all_note_events['jazzSeventhFrequency'] = all_note_events['jazzSeventhFrequency'].fillna(method='pad')
    all_note_events['locationInMeasure'] = (all_note_events['noteLocation'] + 4) / 4
    
    solo_note_events = all_note_events[all_note_events.part == 0]

    
    solo_note_events['previousNotePitchDistance'] = solo_note_events['noteFrequency'].shift(1)
    solo_note_events['previousNotePitchDistance'] = solo_note_events['previousNotePitchDistance'] - solo_note_events['noteFrequency']
    solo_note_events['nextNotePitchDistance'] = solo_note_events['noteFrequency'].shift(-1)
    solo_note_events['nextNotePitchDistance'] = solo_note_events['nextNotePitchDistance'] - solo_note_events['noteFrequency']
    solo_note_events['previousNoteDurationDistance'] = solo_note_events['noteLocation'].shift(1)
    solo_note_events['previousNoteDurationDistance'] = abs(solo_note_events['previousNoteDurationDistance'] - solo_note_events['noteLocation'])
    solo_note_events['nextNoteDurationDistance'] = solo_note_events['noteLocation'].shift(-1)
    solo_note_events['nextNoteDurationDistance'] = abs(solo_note_events['nextNoteDurationDistance'] - solo_note_events['noteLocation'])

    solo_note_events['endOfCurrentNoteDistanceToNextNote'] = abs(solo_note_events['nextNoteDurationDistance'] - solo_note_events['noteDuration'])


    
#each note belongs to scertain phrase  
    def phraseCounter(data_row):
        if data_row['endOfCurrentNoteDistanceToNextNote'] >= 0.5:
            return 'lastNoteOfPhrase'
        else: 
            return 'inPhrase'
        
    solo_note_events['phraseStatus'] = solo_note_events.apply(phraseCounter, axis=1)

    

    def incPhraseTwo(data_row):
        global globalPhraseCount
        x = globalPhraseCount
        if data_row['phraseStatus'] == 'lastNoteOfPhrase':
            globalPhraseCount = globalPhraseCount + 1
        return x
    
    
    solo_note_events['phrase'] = solo_note_events.apply(incPhraseTwo, axis=1)
    # get rid of phraseStatus
    del solo_note_events['phraseStatus']
            
####################################### FIND CHORD TYPE          
   
    
    def find_chord_type(row):
        if row['jazzThirdFrequency'] - row['jazzRootFrequency'] == 4 and row['jazzFifthFrequency'] - row['jazzThirdFrequency'] == 3 and row['jazzSeventhFrequency'] - row['jazzFifthFrequency'] == 3:
            return 'dom7'
        elif row['jazzThirdFrequency'] - row['jazzRootFrequency'] == 4 and row['jazzFifthFrequency'] - row['jazzThirdFrequency'] == 3 and row['jazzSeventhFrequency'] - row['jazzFifthFrequency'] == 4:
            return 'maj7'
        elif row['jazzThirdFrequency'] - row['jazzRootFrequency'] == 3 and row['jazzFifthFrequency'] - row['jazzThirdFrequency'] == 4 and row['jazzSeventhFrequency'] - row['jazzFifthFrequency'] == 3:
            return 'min7'
        elif row['jazzThirdFrequency'] - row['jazzRootFrequency'] == 3 and row['jazzFifthFrequency'] - row['jazzThirdFrequency'] == 3 and row['jazzSeventhFrequency'] - row['jazzFifthFrequency'] == 4:
            return 'min7b5'
        else:
            return 'notDetermined'

    solo_note_events['chordType'] = solo_note_events.apply(find_chord_type, axis=1)

    
####################################### DIST TO ROOT FUNCTION ##########    
    def calc_dist_note_root(data_row):
        x = (data_row['noteFrequency'] - data_row['jazzRootFrequency']) % 12
        return x
    
    
    solo_note_events['notePitchDistanceToRoot'] = solo_note_events.apply(calc_dist_note_root, axis=1)
    
########################## CURRENT MEASURE ######################    
    def calc_measure_floor(data_row):
        x = math.floor(data_row.locationInMeasure)
        return x
    
    solo_note_events['currentMeasure'] = solo_note_events.apply(calc_measure_floor, axis=1)

########################### API URL STRING ###########################
    
    
    def createUrlResourceString(data_row):
        url = 'http://api.musicdata.' + str(data_row['part']) + str(data_row['noteLocation'])
        return url
    
    solo_note_events['resourceUrl'] = solo_note_events.apply(createUrlResourceString, axis=1)
 
    

    
########### CREATE CHORD ROOT FREQ #############################################
    def createChordRootFrequency(data_row):
        chordRootFreq = data_row['jazzRootFrequency']
        return chordRootFreq
    
    solo_note_events['chordRootFrequency'] = solo_note_events.apply(createChordRootFrequency, axis=1)

########### CREATE CHORD ROOT MINIMISED FREQ #############################################
    def createChordRootMinimisedFrequency(data_row):
        chordRootMinFreq = data_row['jazzRootFrequency'] % 12
        return chordRootMinFreq
    
    solo_note_events['chordRootMinimizedFrequency'] = solo_note_events.apply(createChordRootMinimisedFrequency, axis=1)
########### CREATE CHORD BASS FREQ #############################################
    def createChordBassFrequency(data_row):
        chordBassFreq = data_row['jazzRootFrequency']
        return chordBassFreq
    
    solo_note_events['chordBassFrequency'] = solo_note_events.apply(createChordBassFrequency, axis=1)

########### CREATE CHORD BASS MIN FREQ #############################################
    def createChordBassMinimisedFrequency(data_row):
        chordBassMinFreq = data_row['jazzRootFrequency'] % 12
        return chordBassMinFreq
    
    solo_note_events['chordBassMinimizedFrequency'] = solo_note_events.apply(createChordBassMinimisedFrequency, axis=1)
    
    
    return solo_note_events

# %%
notesSample = mu.converter.parse('corpus/mozartTesting7.xml')

i = 0
parts_list = []

while i < len(notesSample.parts):
    parts_list.append(notesSample.parts[i])
    i = i + 1


notes_list = []
part_name_list = []
for part in parts_list:
    a = part.flat.getElementsByClass([mu.note.Note, mu.chord.Chord, mu.tempo.MetronomeMark, mu.expressions.TextExpression])
    print part.flat.getElementsByClass(mu.note.Note)
    b = part.id
    notes_list.append(a)
    part_name_list.append(b)
# Out:
# <music21.stream.PartStaff 4500623952>
# <music21.stream.PartStaff 4500624720>

# %%
for musicStuff in notes_list[0]:
    
    currentExpression = -1
    global currentTempo
    global textArray
    textArray = []
    
    try:
        musicStuff.content
        print '##### FOUND EXPRESSION #######', musicStuff.content
        
        
    except:
        ''
    
    try:
        musicStuff.intervalVector
            
#        print musicStuff.offset
        for stuff in musicStuff.pitches:
            print 'Tempo', currentTempo, 'Chord', '\t\tmidi: ', stuff.midi, '\tOffset: ', musicStuff.offset , '\t\t\tDuration: ', musicStuff.duration.quarterLength
        
    except:
        ''
    
    try:
        musicStuff.number
        currentTempo = musicStuff.number
        print '#####Found Tempo######:\t\t', musicStuff.number, musicStuff.text
        
    except: 
        pass
        
    try: 
        musicStuff.midi
        print 'Tempo', currentTempo , 'Note\t\tmidi:', musicStuff.midi, ' \tOffset:', musicStuff.offset, ' \t\tDuration:' , musicStuff.duration.quarterLength
    except:
        pass
# Out:
# #####Found Tempo######:		120.0 animato
# Tempo 120.0 Chord 		midi:  64 	Offset:  0.0 			Duration:  1.0
# Tempo 120.0 Chord 		midi:  67 	Offset:  0.0 			Duration:  1.0
# Tempo 120.0 Chord 		midi:  72 	Offset:  0.0 			Duration:  1.0
# Tempo 120.0 Note		midi: 72  	Offset: 1.5  		Duration: 0.25
# Tempo 120.0 Note		midi: 71  	Offset: 1.75  		Duration: 0.25
# Tempo 120.0 Note		midi: 74  	Offset: 2.0  		Duration: 0.25
# Tempo 120.0 Note		midi: 72  	Offset: 2.25  		Duration: 0.25
# Tempo 120.0 Note		midi: 76  	Offset: 2.5  		Duration: 0.25
# Tempo 120.0 Note		midi: 74  	Offset: 2.75  		Duration: 0.25
# Tempo 120.0 Note		midi: 77  	Offset: 3.0  		Duration: 0.25
# Tempo 120.0 Note		midi: 76  	Offset: 3.25  		Duration: 0.25
# Tempo 120.0 Note		midi: 79  	Offset: 3.5  		Duration: 0.25
# Tempo 120.0 Note		midi: 77  	Offset: 3.75  		Duration: 0.25
# Tempo 120.0 Chord 		midi:  69 	Offset:  4.0 			Duration:  1.0
# Tempo 120.0 Chord 		midi:  74 	Offset:  4.0 			Duration:  1.0
# Tempo 120.0 Chord 		midi:  77 	Offset:  4.0 			Duration:  1.0
# Tempo 120.0 Chord 		midi:  81 	Offset:  4.0 			Duration:  1.0
# Tempo 120.0 Note		midi: 79  	Offset: 5.0  		Duration: 0.25
# Tempo 120.0 Note		midi: 77  	Offset: 5.25  		Duration: 0.25
# Tempo 120.0 Note		midi: 76  	Offset: 5.5  		Duration: 0.25
# Tempo 120.0 Note		midi: 74  	Offset: 5.75  		Duration: 0.25
# Tempo 120.0 Note		midi: 72  	Offset: 6.0  		Duration: 0.25
# Tempo 120.0 Note		midi: 71  	Offset: 6.25  		Duration: 0.25
# Tempo 120.0 Note		midi: 72  	Offset: 6.5  		Duration: 0.25
# Tempo 120.0 Note		midi: 76  	Offset: 6.75  		Duration: 0.25
# Tempo 120.0 Note		midi: 74  	Offset: 7.0  		Duration: 0.25
# Tempo 120.0 Note		midi: 77  	Offset: 7.25  		Duration: 0.25
# Tempo 120.0 Note		midi: 71  	Offset: 7.5  		Duration: 0.25
# Tempo 120.0 Note		midi: 74  	Offset: 7.75  		Duration: 0.25
# Tempo 120.0 Chord 		midi:  64 	Offset:  8.0 			Duration:  1.0
# Tempo 120.0 Chord 		midi:  67 	Offset:  8.0 			Duration:  1.0
# Tempo 120.0 Chord 		midi:  72 	Offset:  8.0 			Duration:  1.0
# Tempo 120.0 Note		midi: 72  	Offset: 9.5  		Duration: 0.25
# Tempo 120.0 Note		midi: 71  	Offset: 9.75  		Duration: 0.25
# Tempo 120.0 Note		midi: 74  	Offset: 10.0  		Duration: 0.25
# Tempo 120.0 Note		midi: 72  	Offset: 10.25  		Duration: 0.25
# Tempo 120.0 Note		midi: 76  	Offset: 10.5  		Duration: 0.25
# Tempo 120.0 Note		midi: 74  	Offset: 10.75  		Duration: 0.25
# Tempo 120.0 Note		midi: 77  	Offset: 11.0  		Duration: 0.25
# Tempo 120.0 Note		midi: 76  	Offset: 11.25  		Duration: 0.25
# Tempo 120.0 Note		midi: 79  	Offset: 11.5  		Duration: 0.25
# Tempo 120.0 Note		midi: 77  	Offset: 11.75  		Duration: 0.25
# Tempo 120.0 Chord 		midi:  69 	Offset:  12.0 			Duration:  1.0
# Tempo 120.0 Chord 		midi:  74 	Offset:  12.0 			Duration:  1.0
# Tempo 120.0 Chord 		midi:  77 	Offset:  12.0 			Duration:  1.0
# Tempo 120.0 Chord 		midi:  81 	Offset:  12.0 			Duration:  1.0
# ##### FOUND EXPRESSION ####### tremolo
# Tempo 120.0 Note		midi: 79  	Offset: 13.0  		Duration: 0.25
# Tempo 120.0 Note		midi: 77  	Offset: 13.25  		Duration: 0.25
# Tempo 120.0 Note		midi: 76  	Offset: 13.5  		Duration: 0.25
# Tempo 120.0 Note		midi: 74  	Offset: 13.75  		Duration: 0.25
# Tempo 120.0 Note		midi: 72  	Offset: 14.0  		Duration: 0.25
# Tempo 120.0 Note		midi: 71  	Offset: 14.25  		Duration: 0.25
# Tempo 120.0 Note		midi: 72  	Offset: 14.5  		Duration: 0.25
# Tempo 120.0 Note		midi: 76  	Offset: 14.75  		Duration: 0.25
# #####Found Tempo######:		80.0 andantino
# Tempo 80.0 Note		midi: 74  	Offset: 15.0  		Duration: 0.25
# Tempo 80.0 Note		midi: 77  	Offset: 15.25  		Duration: 0.25
# Tempo 80.0 Note		midi: 71  	Offset: 15.5  		Duration: 0.25
# Tempo 80.0 Note		midi: 74  	Offset: 15.75  		Duration: 0.25
# Tempo 80.0 Note		midi: 72  	Offset: 16.0  		Duration: 0.5
# Tempo 80.0 Note		midi: 74  	Offset: 16.5  		Duration: 0.0
# Tempo 80.0 Note		midi: 72  	Offset: 16.5  		Duration: 0.25
# Tempo 80.0 Note		midi: 71  	Offset: 16.75  		Duration: 0.25
# Tempo 80.0 Note		midi: 72  	Offset: 17.0  		Duration: 0.5
# Tempo 80.0 Note		midi: 76  	Offset: 17.5  		Duration: 0.5
# Tempo 80.0 Note		midi: 73  	Offset: 18.0  		Duration: 1.0
# Tempo 80.0 Note		midi: 74  	Offset: 19.0  		Duration: 0.5
# Tempo 80.0 Chord 		midi:  64 	Offset:  19.5 			Duration:  0.5
# Tempo 80.0 Chord 		midi:  67 	Offset:  19.5 			Duration:  0.5
# Tempo 80.0 Chord 		midi:  72 	Offset:  19.5 			Duration:  0.5

# %%
notesSample.show('text')
# Out:
# {0.0} <music21.text.TextBox "2">
# {0.0} <music21.metadata.Metadata object at 0x10bfff810>
# {0.0} <music21.stream.PartStaff P1-Staff1>
#     {0.0} <music21.instrument.Instrument P1: Piano: Piano (2)>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.clef.TrebleClef>
#         {0.0} <music21.tempo.MetronomeMark animato Quarter=120.0>
#         {0.0} <music21.key.KeySignature of no sharps or flats, mode major>
#         {0.0} <music21.meter.TimeSignature 4/4>
#         {0.0} <music21.layout.StaffLayout distance None, staffNumber 1, staffSize None>
#         {0.0} <music21.layout.PageLayout>
#         {0.0} <music21.layout.SystemLayout>
#         {0.0} <music21.chord.Chord E4 G4 C5>
#         {1.0} <music21.note.Rest rest>
#         {1.5} <music21.note.Note C>
#         {1.75} <music21.note.Note B>
#         {2.0} <music21.note.Note D>
#         {2.25} <music21.note.Note C>
#         {2.5} <music21.note.Note E>
#         {2.75} <music21.note.Note D>
#         {3.0} <music21.note.Note F>
#         {3.25} <music21.note.Note E>
#         {3.5} <music21.note.Note G>
#         {3.75} <music21.note.Note F>
#     {4.0} <music21.stream.Measure 2 offset=4.0>
#         {0.0} <music21.chord.Chord A4 D5 F5 A5>
#         {1.0} <music21.note.Note G>
#         {1.25} <music21.note.Note F>
#         {1.5} <music21.note.Note E>
#         {1.75} <music21.note.Note D>
#         {2.0} <music21.note.Note C>
#         {2.25} <music21.note.Note B>
#         {2.5} <music21.note.Note C>
#         {2.75} <music21.note.Note E>
#         {3.0} <music21.note.Note D>
#         {3.25} <music21.note.Note F>
#         {3.5} <music21.note.Note B>
#         {3.75} <music21.note.Note D>
#     {8.0} <music21.stream.Measure 3 offset=8.0>
#         {0.0} <music21.layout.StaffLayout distance None, staffNumber 1, staffSize None>
#         {0.0} <music21.layout.SystemLayout>
#         {0.0} <music21.chord.Chord E4 G4 C5>
#         {1.0} <music21.note.Rest rest>
#         {1.5} <music21.note.Note C>
#         {1.75} <music21.note.Note B>
#         {2.0} <music21.note.Note D>
#         {2.25} <music21.note.Note C>
#         {2.5} <music21.note.Note E>
#         {2.75} <music21.note.Note D>
#         {3.0} <music21.note.Note F>
#         {3.25} <music21.note.Note E>
#         {3.5} <music21.note.Note G>
#         {3.75} <music21.note.Note F>
#     {12.0} <music21.stream.Measure 4 offset=12.0>
#         {0.0} <music21.chord.Chord A4 D5 F5 A5>
#         {1.0} <music21.expressions.TextExpression "tremolo">
#         {1.0} <music21.note.Note G>
#         {1.25} <music21.note.Note F>
#         {1.5} <music21.note.Note E>
#         {1.75} <music21.note.Note D>
#         {2.0} <music21.note.Note C>
#         {2.25} <music21.note.Note B>
#         {2.5} <music21.note.Note C>
#         {2.75} <music21.note.Note E>
#         {3.0} <music21.tempo.MetronomeMark animato Quarter=120.0>
#         {3.0} <music21.note.Note D>
#         {3.25} <music21.note.Note F>
#         {3.5} <music21.note.Note B>
#         {3.75} <music21.note.Note D>
#     {16.0} <music21.stream.Measure 5 offset=16.0>
#         {0.0} <music21.note.Note C>
#         {0.5} <music21.note.Note D>
#         {0.5} <music21.note.Note C>
#         {0.75} <music21.note.Note B>
#         {1.0} <music21.note.Note C>
#         {1.5} <music21.note.Note E>
#         {2.0} <music21.note.Note C#>
#         {3.0} <music21.note.Note D>
#         {3.5} <music21.chord.Chord E4 G4 C5>
#     {20.0} <music21.stream.Measure 6 offset=20.0>
#         {0.0} <music21.layout.StaffLayout distance None, staffNumber 1, staffSize None>
#         {0.0} <music21.layout.PageLayout>
#         {0.0} <music21.layout.SystemLayout>
#         {0.0} <music21.note.Rest rest>
# {0.0} <music21.stream.PartStaff P1-Staff2>
#     {0.0} <music21.instrument.Instrument P1: Piano: Piano (2)>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.clef.BassClef>
#         {0.0} <music21.key.KeySignature of no sharps or flats, mode major>
#         {0.0} <music21.meter.TimeSignature 4/4>
#         {0.0} <music21.layout.StaffLayout distance 55.0, staffNumber 2, staffSize None>
#         {0.0} <music21.layout.PageLayout>
#         {0.0} <music21.layout.SystemLayout>
#         {0.0} <music21.note.Note C>
#         {0.25} <music21.note.Note C>
#         {0.5} <music21.note.Note B>
#         {0.75} <music21.note.Note C>
#         {1.0} <music21.note.Note C>
#         {1.5} <music21.note.Rest rest>
#         {2.0} <music21.note.Rest rest>
#     {4.0} <music21.stream.Measure 2 offset=4.0>
#         {0.0} <music21.chord.Chord F2 F3>
#         {1.0} <music21.note.Rest rest>
#         {2.0} <music21.note.Rest rest>
#         {2.5} <music21.note.Note E>
#         {3.0} <music21.note.Note F>
#         {3.5} <music21.note.Note G>
#     {8.0} <music21.stream.Measure 3 offset=8.0>
#         {0.0} <music21.layout.StaffLayout distance 55.0, staffNumber 2, staffSize None>
#         {0.0} <music21.layout.SystemLayout>
#         {0.0} <music21.note.Note C>
#         {0.25} <music21.note.Note C>
#         {0.5} <music21.note.Note B>
#         {0.75} <music21.note.Note C>
#         {1.0} <music21.note.Note C>
#         {1.5} <music21.note.Rest rest>
#         {2.0} <music21.note.Rest rest>
#     {12.0} <music21.stream.Measure 4 offset=12.0>
#         {0.0} <music21.chord.Chord F2 F3>
#         {1.0} <music21.note.Rest rest>
#         {2.0} <music21.note.Rest rest>
#         {2.5} <music21.note.Note E>
#         {3.0} <music21.expressions.TextExpression "dolce">
#         {3.0} <music21.note.Note F>
#         {3.5} <music21.note.Note G>
#     {16.0} <music21.stream.Measure 5 offset=16.0>
#         {0.0} <music21.clef.TrebleClef>
#         {0.0} <music21.note.Note C>
#         {0.25} <music21.note.Note G>
#         {0.5} <music21.note.Note E>
#         {0.75} <music21.note.Note G>
#         {1.0} <music21.note.Note C>
#         {1.25} <music21.note.Note G>
#         {1.5} <music21.note.Note E>
#         {1.75} <music21.note.Note G>
#         {2.0} <music21.note.Note B>
#         {2.25} <music21.note.Note G>
#         {2.5} <music21.note.Note D>
#         {2.75} <music21.note.Note G>
#         {3.0} <music21.note.Note B>
#         {3.25} <music21.note.Note G>
#         {3.5} <music21.note.Note C>
#         {3.75} <music21.note.Note C>
#     {20.0} <music21.stream.Measure 6 offset=20.0>
#         {0.0} <music21.layout.StaffLayout distance 55.0, staffNumber 2, staffSize None>
#         {0.0} <music21.layout.PageLayout>
#         {0.0} <music21.layout.SystemLayout>
#         {0.0} <music21.note.Rest rest>
# {0.0} <music21.layout.ScoreLayout>
# {0.0} <music21.layout.StaffGroup <music21.stream.Part Piano>>

# %%
from xml.etree import ElementTree as ET

# %%
xml = """
<?xml version='1.0' encoding='UTF-8'?>
<!DOCTYPE xgdresponse SYSTEM 'xgdresponse.dtd'>
<xgdresponse version='1.0'>
  <transid>2771709</transid>
  <errorcode>0</errorcode>
  <response>
    <result>
      <element>666</element>
      <errorcode>0</errorcode>
      <value>SOMETHING IMPORTANT!</value>
    </result>
  </response>
</xgdresponse>
""".strip()

value = ET.fromstring(xml).find('response/result/value')
if value is not None:
    print 'Found value:', value.text
# Out:
# Found value: SOMETHING IMPORTANT!

# %%
xmlNotes = ET.parse('corpus/mozartTesting5.xml')

# %%
val = xmlNotes.find('score-partwise')
if val is not None:
    print val.text
else:
    print 'hi'
# Out:
# hi

# %%
for child in root:
    for c2 in child:
        for c3 in c2.findall('direction'):
            for c4 in c3.findall('direction-type'):
                for c5 in c4.findall('rehearsal'):
                    print c5.text
# Out:
# A
# B

# %%
notes_list[0].show('text')
# Out:
# {0.0} <music21.chord.Chord E4 G4 C5>
# {1.5} <music21.note.Note C>
# {1.75} <music21.note.Note B>
# {2.0} <music21.note.Note D>
# {2.25} <music21.note.Note C>
# {2.5} <music21.note.Note E>
# {2.75} <music21.note.Note D>
# {3.0} <music21.note.Note F>
# {3.25} <music21.note.Note E>
# {3.5} <music21.note.Note G>
# {3.75} <music21.note.Note F>
# {4.0} <music21.chord.Chord A4 D5 F5 A5>
# {5.0} <music21.note.Note G>
# {5.25} <music21.note.Note F>
# {5.5} <music21.note.Note E>
# {5.75} <music21.note.Note D>
# {6.0} <music21.note.Note C>
# {6.25} <music21.note.Note B>
# {6.5} <music21.note.Note C>
# {6.75} <music21.note.Note E>
# {7.0} <music21.note.Note D>
# {7.25} <music21.note.Note F>
# {7.5} <music21.note.Note B>
# {7.75} <music21.note.Note D>
# {8.0} <music21.chord.Chord E4 G4 C5>
# {9.5} <music21.note.Note C>
# {9.75} <music21.note.Note B>
# {10.0} <music21.note.Note D>
# {10.25} <music21.note.Note C>
# {10.5} <music21.note.Note E>
# {10.75} <music21.note.Note D>
# {11.0} <music21.note.Note F>
# {11.25} <music21.note.Note E>
# {11.5} <music21.note.Note G>
# {11.75} <music21.note.Note F>
# {12.0} <music21.chord.Chord A4 D5 F5 A5>
# {13.0} <music21.note.Note G>
# {13.25} <music21.note.Note F>
# {13.5} <music21.note.Note E>
# {13.75} <music21.note.Note D>
# {14.0} <music21.note.Note C>
# {14.25} <music21.note.Note B>
# {14.5} <music21.note.Note C>
# {14.75} <music21.note.Note E>
# {15.0} <music21.note.Note D>
# {15.25} <music21.note.Note F>
# {15.5} <music21.note.Note B>
# {15.75} <music21.note.Note D>
# {16.0} <music21.note.Note C>
# {16.5} <music21.note.Note D>
# {16.5} <music21.note.Note C>
# {16.75} <music21.note.Note B>
# {17.0} <music21.note.Note C>
# {17.5} <music21.note.Note E>
# {18.0} <music21.note.Note C#>
# {19.0} <music21.note.Note D>
# {19.5} <music21.chord.Chord E4 G4 C5>

# %%
part_name_list
# Out:
# [u'P1-Staff1', u'P1-Staff2']

# %%
notesSample.parts[0]
# Out:
# <music21.stream.PartStaff P1-Staff1>

# %%
#notesSample.show('text').length

# %%
####################### SMALL DATA SET VALIDATION AND TESTING ##########
testData = prep_data_from_xml('xml_files/testingData.xml')
testData['chordVoicingFrequencyArray']='67,33,21,17'
testData['minimisedChordVoicingFrequencyArray']='11,8,5,0'
testData['currentTempo'] = 120
testData['instrument']='piano'
testData['instrumentFamily']='keyboard'
testData['title'] = "stella_by_starlight"
testData['composerName'] = 'oscar_hammerstien'
testData['performerName'] = 'keith_jarrett'
testData['yearComposed'] = 1943
testData['yearPerformed'] = 1986

def createUniquePhraseId(data_row):
    phraseId = str(data_row['title']) + '_' + str(data_row['phrase'])
    return phraseId
    
testData['uniquePhraseId'] = testData.apply(createUniquePhraseId, axis=1)
# Out:
# -c:174: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_index,col_indexer] = value instead
# -c:176: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_index,col_indexer] = value instead
# -c:178: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_index,col_indexer] = value instead
# -c:180: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_index,col_indexer] = value instead

# %%
display(HTML(testData[0:10].to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>noteDuration</th>
#       <th>noteFrequency</th>
#       <th>noteLocation</th>
#       <th>part</th>
#       <th>jazzRootFrequency</th>
#       <th>jazzThirdFrequency</th>
#       <th>jazzFifthFrequency</th>
#       <th>jazzSeventhFrequency</th>
#       <th>locationInMeasure</th>
#       <th>previousNotePitchDistance</th>
#       <th>nextNotePitchDistance</th>
#       <th>previousNoteDurationDistance</th>
#       <th>nextNoteDurationDistance</th>
#       <th>endOfCurrentNoteDistanceToNextNote</th>
#       <th>phrase</th>
#       <th>chordType</th>
#       <th>notePitchDistanceToRoot</th>
#       <th>currentMeasure</th>
#       <th>resourceUrl</th>
#       <th>chordRootFrequency</th>
#       <th>chordRootMinimizedFrequency</th>
#       <th>chordBassFrequency</th>
#       <th>chordBassMinimizedFrequency</th>
#       <th>chordVoicingFrequencyArray</th>
#       <th>minimisedChordVoicingFrequencyArray</th>
#       <th>currentTempo</th>
#       <th>instrument</th>
#       <th>instrumentFamily</th>
#       <th>title</th>
#       <th>composerName</th>
#       <th>performerName</th>
#       <th>yearComposed</th>
#       <th>yearPerformed</th>
#       <th>uniquePhraseId</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td> 0.500000</td>
#       <td> 67</td>
#       <td>  0.000000</td>
#       <td> 0</td>
#       <td> 64</td>
#       <td> 67</td>
#       <td> 70</td>
#       <td> 74</td>
#       <td> 1.000000</td>
#       <td>NaN</td>
#       <td> 2</td>
#       <td>      NaN</td>
#       <td> 1.500000</td>
#       <td> 1.000000e+00</td>
#       <td> 0</td>
#       <td> min7b5</td>
#       <td>  3</td>
#       <td> 1</td>
#       <td>           http://api.musicdata.00.0</td>
#       <td> 64</td>
#       <td> 4</td>
#       <td> 64</td>
#       <td> 4</td>
#       <td> 67,33,21,17</td>
#       <td> 11,8,5,0</td>
#       <td> 120</td>
#       <td> piano</td>
#       <td> keyboard</td>
#       <td> stella_by_starlight</td>
#       <td> oscar_hammerstien</td>
#       <td> keith_jarrett</td>
#       <td> 1943</td>
#       <td> 1986</td>
#       <td> stella_by_starlight_0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td> 0.500000</td>
#       <td> 69</td>
#       <td>  1.500000</td>
#       <td> 0</td>
#       <td> 64</td>
#       <td> 67</td>
#       <td> 70</td>
#       <td> 74</td>
#       <td> 1.375000</td>
#       <td> -2</td>
#       <td> 1</td>
#       <td> 1.500000</td>
#       <td> 0.500000</td>
#       <td> 0.000000e+00</td>
#       <td> 1</td>
#       <td> min7b5</td>
#       <td>  5</td>
#       <td> 1</td>
#       <td>           http://api.musicdata.01.5</td>
#       <td> 64</td>
#       <td> 4</td>
#       <td> 64</td>
#       <td> 4</td>
#       <td> 67,33,21,17</td>
#       <td> 11,8,5,0</td>
#       <td> 120</td>
#       <td> piano</td>
#       <td> keyboard</td>
#       <td> stella_by_starlight</td>
#       <td> oscar_hammerstien</td>
#       <td> keith_jarrett</td>
#       <td> 1943</td>
#       <td> 1986</td>
#       <td> stella_by_starlight_1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td> 1.000000</td>
#       <td> 70</td>
#       <td>  2.000000</td>
#       <td> 0</td>
#       <td> 64</td>
#       <td> 67</td>
#       <td> 70</td>
#       <td> 74</td>
#       <td> 1.500000</td>
#       <td> -1</td>
#       <td>-1</td>
#       <td> 0.500000</td>
#       <td> 1.000000</td>
#       <td> 0.000000e+00</td>
#       <td> 1</td>
#       <td> min7b5</td>
#       <td>  6</td>
#       <td> 1</td>
#       <td>           http://api.musicdata.02.0</td>
#       <td> 64</td>
#       <td> 4</td>
#       <td> 64</td>
#       <td> 4</td>
#       <td> 67,33,21,17</td>
#       <td> 11,8,5,0</td>
#       <td> 120</td>
#       <td> piano</td>
#       <td> keyboard</td>
#       <td> stella_by_starlight</td>
#       <td> oscar_hammerstien</td>
#       <td> keith_jarrett</td>
#       <td> 1943</td>
#       <td> 1986</td>
#       <td> stella_by_starlight_1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td> 1.000000</td>
#       <td> 69</td>
#       <td>  3.000000</td>
#       <td> 0</td>
#       <td> 64</td>
#       <td> 67</td>
#       <td> 70</td>
#       <td> 74</td>
#       <td> 1.750000</td>
#       <td>  1</td>
#       <td>-2</td>
#       <td> 1.000000</td>
#       <td> 1.500000</td>
#       <td> 5.000000e-01</td>
#       <td> 1</td>
#       <td> min7b5</td>
#       <td>  5</td>
#       <td> 1</td>
#       <td>           http://api.musicdata.03.0</td>
#       <td> 64</td>
#       <td> 4</td>
#       <td> 64</td>
#       <td> 4</td>
#       <td> 67,33,21,17</td>
#       <td> 11,8,5,0</td>
#       <td> 120</td>
#       <td> piano</td>
#       <td> keyboard</td>
#       <td> stella_by_starlight</td>
#       <td> oscar_hammerstien</td>
#       <td> keith_jarrett</td>
#       <td> 1943</td>
#       <td> 1986</td>
#       <td> stella_by_starlight_1</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td> 0.500000</td>
#       <td> 67</td>
#       <td>  4.500000</td>
#       <td> 0</td>
#       <td> 57</td>
#       <td> 61</td>
#       <td> 64</td>
#       <td> 67</td>
#       <td> 2.125000</td>
#       <td>  2</td>
#       <td> 3</td>
#       <td> 1.500000</td>
#       <td> 0.500000</td>
#       <td> 0.000000e+00</td>
#       <td> 2</td>
#       <td>   dom7</td>
#       <td> 10</td>
#       <td> 2</td>
#       <td>           http://api.musicdata.04.5</td>
#       <td> 57</td>
#       <td> 9</td>
#       <td> 57</td>
#       <td> 9</td>
#       <td> 67,33,21,17</td>
#       <td> 11,8,5,0</td>
#       <td> 120</td>
#       <td> piano</td>
#       <td> keyboard</td>
#       <td> stella_by_starlight</td>
#       <td> oscar_hammerstien</td>
#       <td> keith_jarrett</td>
#       <td> 1943</td>
#       <td> 1986</td>
#       <td> stella_by_starlight_2</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td> 1.000000</td>
#       <td> 70</td>
#       <td>  5.000000</td>
#       <td> 0</td>
#       <td> 57</td>
#       <td> 61</td>
#       <td> 64</td>
#       <td> 67</td>
#       <td> 2.250000</td>
#       <td> -3</td>
#       <td>-1</td>
#       <td> 0.500000</td>
#       <td> 1.000000</td>
#       <td> 0.000000e+00</td>
#       <td> 2</td>
#       <td>   dom7</td>
#       <td>  1</td>
#       <td> 2</td>
#       <td>           http://api.musicdata.05.0</td>
#       <td> 57</td>
#       <td> 9</td>
#       <td> 57</td>
#       <td> 9</td>
#       <td> 67,33,21,17</td>
#       <td> 11,8,5,0</td>
#       <td> 120</td>
#       <td> piano</td>
#       <td> keyboard</td>
#       <td> stella_by_starlight</td>
#       <td> oscar_hammerstien</td>
#       <td> keith_jarrett</td>
#       <td> 1943</td>
#       <td> 1986</td>
#       <td> stella_by_starlight_2</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td> 2.000000</td>
#       <td> 69</td>
#       <td>  6.000000</td>
#       <td> 0</td>
#       <td> 57</td>
#       <td> 61</td>
#       <td> 64</td>
#       <td> 67</td>
#       <td> 2.500000</td>
#       <td>  1</td>
#       <td> 0</td>
#       <td> 1.000000</td>
#       <td> 2.000000</td>
#       <td> 0.000000e+00</td>
#       <td> 2</td>
#       <td>   dom7</td>
#       <td>  0</td>
#       <td> 2</td>
#       <td>           http://api.musicdata.06.0</td>
#       <td> 57</td>
#       <td> 9</td>
#       <td> 57</td>
#       <td> 9</td>
#       <td> 67,33,21,17</td>
#       <td> 11,8,5,0</td>
#       <td> 120</td>
#       <td> piano</td>
#       <td> keyboard</td>
#       <td> stella_by_starlight</td>
#       <td> oscar_hammerstien</td>
#       <td> keith_jarrett</td>
#       <td> 1943</td>
#       <td> 1986</td>
#       <td> stella_by_starlight_2</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td> 1.000000</td>
#       <td> 69</td>
#       <td>  8.000000</td>
#       <td> 0</td>
#       <td> 60</td>
#       <td> 63</td>
#       <td> 67</td>
#       <td> 70</td>
#       <td> 3.000000</td>
#       <td>  0</td>
#       <td>-2</td>
#       <td> 2.000000</td>
#       <td> 1.500000</td>
#       <td> 5.000000e-01</td>
#       <td> 2</td>
#       <td>   min7</td>
#       <td>  9</td>
#       <td> 3</td>
#       <td>           http://api.musicdata.08.0</td>
#       <td> 60</td>
#       <td> 0</td>
#       <td> 60</td>
#       <td> 0</td>
#       <td> 67,33,21,17</td>
#       <td> 11,8,5,0</td>
#       <td> 120</td>
#       <td> piano</td>
#       <td> keyboard</td>
#       <td> stella_by_starlight</td>
#       <td> oscar_hammerstien</td>
#       <td> keith_jarrett</td>
#       <td> 1943</td>
#       <td> 1986</td>
#       <td> stella_by_starlight

# %%
testData['globalCount'] = testData.index.values

# %%
display(HTML(testData[0:10].to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>noteDuration</th>
#       <th>noteFrequency</th>
#       <th>noteLocation</th>
#       <th>part</th>
#       <th>jazzRootFrequency</th>
#       <th>jazzThirdFrequency</th>
#       <th>jazzFifthFrequency</th>
#       <th>jazzSeventhFrequency</th>
#       <th>locationInMeasure</th>
#       <th>previousNotePitchDistance</th>
#       <th>nextNotePitchDistance</th>
#       <th>previousNoteDurationDistance</th>
#       <th>nextNoteDurationDistance</th>
#       <th>endOfCurrentNoteDistanceToNextNote</th>
#       <th>phrase</th>
#       <th>chordType</th>
#       <th>notePitchDistanceToRoot</th>
#       <th>currentMeasure</th>
#       <th>resourceUrl</th>
#       <th>chordRootFrequency</th>
#       <th>chordRootMinimizedFrequency</th>
#       <th>chordBassFrequency</th>
#       <th>chordBassMinimizedFrequency</th>
#       <th>chordVoicingFrequencyArray</th>
#       <th>minimisedChordVoicingFrequencyArray</th>
#       <th>currentTempo</th>
#       <th>instrument</th>
#       <th>instrumentFamily</th>
#       <th>title</th>
#       <th>composerName</th>
#       <th>performerName</th>
#       <th>yearComposed</th>
#       <th>yearPerformed</th>
#       <th>uniquePhraseId</th>
#       <th>globalCount</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td> 0.500000</td>
#       <td> 67</td>
#       <td>  0.000000</td>
#       <td> 0</td>
#       <td> 64</td>
#       <td> 67</td>
#       <td> 70</td>
#       <td> 74</td>
#       <td> 1.000000</td>
#       <td>NaN</td>
#       <td> 2</td>
#       <td>      NaN</td>
#       <td> 1.500000</td>
#       <td> 1.000000e+00</td>
#       <td> 0</td>
#       <td> min7b5</td>
#       <td>  3</td>
#       <td> 1</td>
#       <td>           http://api.musicdata.00.0</td>
#       <td> 64</td>
#       <td> 4</td>
#       <td> 64</td>
#       <td> 4</td>
#       <td> 67,33,21,17</td>
#       <td> 11,8,5,0</td>
#       <td> 120</td>
#       <td> piano</td>
#       <td> keyboard</td>
#       <td> stella_by_starlight</td>
#       <td> oscar_hammerstien</td>
#       <td> keith_jarrett</td>
#       <td> 1943</td>
#       <td> 1986</td>
#       <td> stella_by_starlight_0</td>
#       <td> 0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td> 0.500000</td>
#       <td> 69</td>
#       <td>  1.500000</td>
#       <td> 0</td>
#       <td> 64</td>
#       <td> 67</td>
#       <td> 70</td>
#       <td> 74</td>
#       <td> 1.375000</td>
#       <td> -2</td>
#       <td> 1</td>
#       <td> 1.500000</td>
#       <td> 0.500000</td>
#       <td> 0.000000e+00</td>
#       <td> 1</td>
#       <td> min7b5</td>
#       <td>  5</td>
#       <td> 1</td>
#       <td>           http://api.musicdata.01.5</td>
#       <td> 64</td>
#       <td> 4</td>
#       <td> 64</td>
#       <td> 4</td>
#       <td> 67,33,21,17</td>
#       <td> 11,8,5,0</td>
#       <td> 120</td>
#       <td> piano</td>
#       <td> keyboard</td>
#       <td> stella_by_starlight</td>
#       <td> oscar_hammerstien</td>
#       <td> keith_jarrett</td>
#       <td> 1943</td>
#       <td> 1986</td>
#       <td> stella_by_starlight_1</td>
#       <td> 1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td> 1.000000</td>
#       <td> 70</td>
#       <td>  2.000000</td>
#       <td> 0</td>
#       <td> 64</td>
#       <td> 67</td>
#       <td> 70</td>
#       <td> 74</td>
#       <td> 1.500000</td>
#       <td> -1</td>
#       <td>-1</td>
#       <td> 0.500000</td>
#       <td> 1.000000</td>
#       <td> 0.000000e+00</td>
#       <td> 1</td>
#       <td> min7b5</td>
#       <td>  6</td>
#       <td> 1</td>
#       <td>           http://api.musicdata.02.0</td>
#       <td> 64</td>
#       <td> 4</td>
#       <td> 64</td>
#       <td> 4</td>
#       <td> 67,33,21,17</td>
#       <td> 11,8,5,0</td>
#       <td> 120</td>
#       <td> piano</td>
#       <td> keyboard</td>
#       <td> stella_by_starlight</td>
#       <td> oscar_hammerstien</td>
#       <td> keith_jarrett</td>
#       <td> 1943</td>
#       <td> 1986</td>
#       <td> stella_by_starlight_1</td>
#       <td> 2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td> 1.000000</td>
#       <td> 69</td>
#       <td>  3.000000</td>
#       <td> 0</td>
#       <td> 64</td>
#       <td> 67</td>
#       <td> 70</td>
#       <td> 74</td>
#       <td> 1.750000</td>
#       <td>  1</td>
#       <td>-2</td>
#       <td> 1.000000</td>
#       <td> 1.500000</td>
#       <td> 5.000000e-01</td>
#       <td> 1</td>
#       <td> min7b5</td>
#       <td>  5</td>
#       <td> 1</td>
#       <td>           http://api.musicdata.03.0</td>
#       <td> 64</td>
#       <td> 4</td>
#       <td> 64</td>
#       <td> 4</td>
#       <td> 67,33,21,17</td>
#       <td> 11,8,5,0</td>
#       <td> 120</td>
#       <td> piano</td>
#       <td> keyboard</td>
#       <td> stella_by_starlight</td>
#       <td> oscar_hammerstien</td>
#       <td> keith_jarrett</td>
#       <td> 1943</td>
#       <td> 1986</td>
#       <td> stella_by_starlight_1</td>
#       <td> 3</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td> 0.500000</td>
#       <td> 67</td>
#       <td>  4.500000</td>
#       <td> 0</td>
#       <td> 57</td>
#       <td> 61</td>
#       <td> 64</td>
#       <td> 67</td>
#       <td> 2.125000</td>
#       <td>  2</td>
#       <td> 3</td>
#       <td> 1.500000</td>
#       <td> 0.500000</td>
#       <td> 0.000000e+00</td>
#       <td> 2</td>
#       <td>   dom7</td>
#       <td> 10</td>
#       <td> 2</td>
#       <td>           http://api.musicdata.04.5</td>
#       <td> 57</td>
#       <td> 9</td>
#       <td> 57</td>
#       <td> 9</td>
#       <td> 67,33,21,17</td>
#       <td> 11,8,5,0</td>
#       <td> 120</td>
#       <td> piano</td>
#       <td> keyboard</td>
#       <td> stella_by_starlight</td>
#       <td> oscar_hammerstien</td>
#       <td> keith_jarrett</td>
#       <td> 1943</td>
#       <td> 1986</td>
#       <td> stella_by_starlight_2</td>
#       <td> 4</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td> 1.000000</td>
#       <td> 70</td>
#       <td>  5.000000</td>
#       <td> 0</td>
#       <td> 57</td>
#       <td> 61</td>
#       <td> 64</td>
#       <td> 67</td>
#       <td> 2.250000</td>
#       <td> -3</td>
#       <td>-1</td>
#       <td> 0.500000</td>
#       <td> 1.000000</td>
#       <td> 0.000000e+00</td>
#       <td> 2</td>
#       <td>   dom7</td>
#       <td>  1</td>
#       <td> 2</td>
#       <td>           http://api.musicdata.05.0</td>
#       <td> 57</td>
#       <td> 9</td>
#       <td> 57</td>
#       <td> 9</td>
#       <td> 67,33,21,17</td>
#       <td> 11,8,5,0</td>
#       <td> 120</td>
#       <td> piano</td>
#       <td> keyboard</td>
#       <td> stella_by_starlight</td>
#       <td> oscar_hammerstien</td>
#       <td> keith_jarrett</td>
#       <td> 1943</td>
#       <td> 1986</td>
#       <td> stella_by_starlight_2</td>
#       <td> 5</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td> 2.000000</td>
#       <td> 69</td>
#       <td>  6.000000</td>
#       <td> 0</td>
#       <td> 57</td>
#       <td> 61</td>
#       <td> 64</td>
#       <td> 67</td>
#       <td> 2.500000</td>
#       <td>  1</td>
#       <td> 0</td>
#       <td> 1.000000</td>
#       <td> 2.000000</td>
#       <td> 0.000000e+00</td>
#       <td> 2</td>
#       <td>   dom7</td>
#       <td>  0</td>
#       <td> 2</td>
#       <td>           http://api.musicdata.06.0</td>
#       <td> 57</td>
#       <td> 9</td>
#       <td> 57</td>
#       <td> 9</td>
#       <td> 67,33,21,17</td>
#       <td> 11,8,5,0</td>
#       <td> 120</td>
#       <td> piano</td>
#       <td> keyboard</td>
#       <td> stella_by_starlight</td>
#       <td> oscar_hammerstien</td>
#       <td> keith_jarrett</td>
#       <td> 1943</td>
#       <td> 1986</td>
#       <td> stella_by_starlight_2</td>
#       <td> 6</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td> 1.000000</td>
#       <td> 69</td>
#       <td>  8.000000</td>
#       <td> 0</td>
#       <td> 60</td>
#       <td> 63</td>
#       <td> 67</td>
#       <td> 70</td>
#       <td> 3.000000</td>
#       <td>  0</td>
#       <td>-2</td>
#       <td> 2.000000</td>
#       <td> 1.500000</td>
#       <td> 5.000000e-01</td>
#       <td> 2</td>
#       <td>   min7</td>
#       <td>  9</td>
#       <td> 3</td>
#       <td>           http://api.musicdata.08.0</td>
#       <td> 60</td>
#       <td> 0</td>
#       <td> 60</td>
#       <td> 0</td>
#       <td> 67,33,21,17</td>
#       <td> 11,8,5,0</td>
#       <td> 120</td>
#       <td> piano</td>
#       <td> keyboard</td>
#       <td> stella_b

# %% [markdown]
# <p>Using Real Data</p>
