# %%
import pandas as pd
from IPython.core.display import HTML
from IPython.core.display import Image 
# %load_ext music21.ipython21.ipExtension
import numpy as np
import music21 as mu
import pymongo
from fractions import Fraction
# %pylab inline
from pymongo import MongoClient
from bs4 import BeautifulSoup
import re
import pydash as py_
pd.set_option('display.mpl_style', 'default')
plt.rcParams['figure.figsize'] = (15, 5)
import math
import music21 as mu
from functools import partial
import json
# This is necessary to show lots of columns in pandas 0.12. 
# Not necessary in pandas 0.13.
pd.set_option('display.width', 5000) 
pd.set_option('display.max_columns', 60)
# Out:
# The music21.ipython21.ipExtension extension is already loaded. To reload it, use:
#   %reload_ext music21.ipython21.ipExtension
# Populating the interactive namespace from numpy and matplotlib

# %%
muAllTheThingsYouAre = mu.converter.parse('FinalDataSet/XMLFiles/JazzSolos/KeithJarrettAllTheThingsYouAre.xml')
muAutumnLeaves = mu.converter.parse('FinalDataSet/XMLFiles/JazzSolos/KeithJarrettAutumnLeaves.xml')
muDaysOfWineAndRoses = mu.converter.parse('FinalDataSet/XMLFiles/JazzSolos/KeithJarrettDaysOfWineAndRoses.xml')
muGroovingHigh = mu.converter.parse('FinalDataSet/XMLFiles/JazzSolos/KeithJarrettGroovinHigh.xml')
muIfIWereABell = mu.converter.parse('FinalDataSet/XMLFiles/JazzSolos/KeithJarrettIfIWereABell.xml')
muSomedayMyPrinceWillCome = mu.converter.parse('FinalDataSet/XMLFiles/JazzSolos/KeithJarrettSomedayMyPrinceWillCome.xml')
muStellaByStarlight = mu.converter.parse('FinalDataSet/XMLFiles/JazzSolos/KeithJarrettStellaByStarlight.xml')
muArmandosRhumba = mu.converter.parse('FinalDataSet/XMLFiles/JazzSolos/ChickCoreaArmandosRhumba.xml')

# %%
def getDurationsForMongoQueries(data_row):
    valueToCheck = data_row['duration']
    try:
        valueToCheck = int(valueToCheck)
    except:
        valeToCheck = -1
    if valueToCheck == 21:
        return Fraction(21,1024) #Thirty Second note triplet
    
    elif valueToCheck == 32:
        return Fraction(1,32)  #Thirty second note
    
    elif valueToCheck == 42:
        return Fraction(21,512)  #Sixteenth note triplet
    
    elif valueToCheck == 43:
        return Fraction(21,512)  #Sixteenth note triplet

    elif valueToCheck == 51:
        return Fraction(51,1024)  #sixteenth note quintuplet
    
    elif valueToCheck == 52:
        return Fraction(51,1024)  #sixteenth note quintuplet    
    
    elif valueToCheck == 56:
        return Fraction(1,18)  #eighth note triplet of quarter note triplet
    
    elif valueToCheck == 57:
        return Fraction(1,18)  #eighth note triplet of quarter note triplet
    
    elif valueToCheck == 64:
        return Fraction(1,16)       #sixteenth note
    
    elif valueToCheck == 73:
        return Fraction(73,1024)       #Eighth note septuplet
    
    elif valueToCheck == 74:
        return Fraction(73,1024)       #Eighth note septuplet
    
    elif valueToCheck == 85:
        return Fraction (1,12)    #eight note triplet
    
    elif valueToCheck == 86:
        return Fraction (1,12)    #eight note triplet
    
    elif valueToCheck == 96:   #dotted sixteenth note
        return Fraction(3,32)
    
    elif valueToCheck == 102:     #eighth note quintuplet
        return Fraction(51,512)
    
    elif valueToCheck == 103:     #eighth note quintuplet
        return Fraction(51,512)
    
    elif valueToCheck == 128:   # eighth note
        return Fraction(1,8)
    
    elif valueToCheck == 170:   #quarter note triplet
        return Fraction(1,6)
    
    elif valueToCheck == 171:   #quarter note triplet
        return Fraction(1,6)
    
    elif valueToCheck == 192:   #dotted eighth note
        return Fraction(3,16)    
    
    elif valueToCheck == 213:   #dotted eighth note
        return Fraction(5,24)    
    
    elif valueToCheck == 214:   #dotted eighth note
        return Fraction(5,24)    
    
    elif valueToCheck == 256:   #quarter note
        return Fraction(1,4)

    
    elif valueToCheck == 320:   #dotted eighth note
        return Fraction(5,16)   
    
    elif valueToCheck == 342:   #half note triplet
        return Fraction(1,3)
    
    elif valueToCheck == 384:   #dotted quarter note
        return Fraction(3,8)
    
    elif valueToCheck == 406:   #dotted quarter note
        return Fraction(203,512)
    
    elif valueToCheck == 470:   #dotted quarter note
        return Fraction(235,512)
    
    elif valueToCheck == 512:   #half note
        return Fraction(1,2)
    
    elif valueToCheck == 576:   #half note
        return Fraction(9,16)
    
    elif valueToCheck == 598:   #half note
        return Fraction(299,512)
    
    elif valueToCheck == 640:   #half note
        return Fraction(5,8)
    
    elif valueToCheck == 682:   #half note
        return Fraction(341,512)
    
    elif valueToCheck == 768:   #dotted half note
        return Fraction(3,4)
    
    elif valueToCheck == 896:   #dotted half note
        return Fraction(3,4)
    
    elif valueToCheck == 1024:   #whole note
        return Fraction(1,1)
    
    elif valueToCheck == 1365:   #whole note
        return Fraction(1365,1024)
    
    elif valueToCheck == 1622:   #whole note
        return Fraction(811,512)
    
    elif valueToCheck == 1920:   #whole note
        return Fraction(15,8)
    
    else:
        #print 'Fix needed', data_row
        return Fraction(1)


    
def getDurationNamesForMongoQueries(data_row):
    valueToCheck = data_row['duration']
    try:
        valueToCheck = int(valueToCheck)
    except:
        valeToCheck = -1
    if valueToCheck == 21:
        return 'Thirtysecond note triplet' # Fraction(21,1024) #Thirty Second note triplet
    
    elif valueToCheck == 32:
        return 'Thirtysecond note' #Fraction(1,32)  #Thirty second note
    
    elif valueToCheck == 42:
        return 'Sixteenth note triplet' #Fraction(21,512)  #Sixteenth note triplet

    elif valueToCheck == 43:
        return 'Sixteenth note triplet' #Fraction(21,512)  #Sixteenth note triplet
    
    elif valueToCheck == 51:
        return 'Sixteenth note quintuplet' #Fraction(51,1024)  #sixteenth note quintuplet
    
    elif valueToCheck == 52:
        return 'Sixteenth note quintuplet' #Fraction(51,1024)  #sixteenth note quintuplet
    
    
    elif valueToCheck == 56:
        return 'Eighth note triplet of quarter note triplet' #Fraction(51,1024)
    elif valueToCheck == 57:
        return 'Eighth note triplet of quarter note triplet' #Fraction(51,1024)
    
    elif valueToCheck == 64:
        return 'Sixteenth note' #Fraction(1,16)       #sixteenth note
    
    elif valueToCheck == 73:
        return 'Eighth note septuplet' #Fraction(73,1024)       #sixteenth note
    
    elif valueToCheck == 74:
        return 'Eighth note septuplet' #Fraction(73,1024)       #sixteenth note
    
    elif valueToCheck == 85:
        return 'Eighth note triplet' # Fraction (1,12)    #eight note triplet
    
    elif valueToCheck == 86:
        return 'Eighth note triplet' # Fraction (1,12)    #eight note triplet
    
    elif valueToCheck == 96:   #dotted sixteenth note
        return 'Dotted sixteenth note' #Fraction(3,32)
    
    elif valueToCheck == 102:     #eighth note quintuplet
        return 'Eighth note quintuplet' #Fraction(51,512)

    elif valueToCheck == 103:     #eighth note quintuplet
        return 'Eighth note quintuplet' #Fraction(51,512)
    
    elif valueToCheck == 128:   # eighth note
        return 'Eighth note' #Fraction(1,8)
    
    elif valueToCheck == 170:   #quarter note triplet
        return 'Quarter note triplet' #Fraction(1,6)
    
    elif valueToCheck == 171:   #quarter note triplet
        return 'Quarter note triplet' #Fraction(1,6)
    
    elif valueToCheck == 192:   #dotted eighth note
        return 'Dotted eighth note' #Fraction(3,16)  
    
    elif valueToCheck == 213:   #dotted eighth note
        return 'Quarter note triplet tied to a sixteenth note triplet'    
    
    elif valueToCheck == 214:   #dotted eighth note
        return 'Quarter note triplet tied to a sixteenth note triplet'  
    
    elif valueToCheck == 256:   #quarter note
        return 'Quarter note' #Fraction(1,4)
    
    elif valueToCheck == 320:   #dotted eighth note
        return 'Quarter note tied to a sixteenth note'     

    elif valueToCheck == 342:   #dotted quarter note
        return 'Half note triplet'    
    
    elif valueToCheck == 384:   #dotted quarter note
        return 'Dotted quarter note' #Fraction(3,8)
    
    elif valueToCheck == 406:   #dotted quarter note
        return 'Half note triplet tied to a sixteenth note' #Fraction(3,8)
    
    elif valueToCheck == 470:   #dotted quarter note
        return 'Half note triplet tied to an eighth note' #Fraction(3,8)
    
    elif valueToCheck == 512:   #half note
        return 'Half note' #Fraction(1,2)
    
    elif valueToCheck == 576:   #half note
        return 'Half note tied to a sixteenth note' #Fraction(1,2)
    
    elif valueToCheck == 598:   #half note
        return 'Half note tied to an eighth note triplet' #Fraction(1,2)
    
    elif valueToCheck == 640:   #half note
        return 'Half note tied to a eighth note' #Fraction(1,2)
    
    elif valueToCheck == 682:   #half note
        return 'Half note tied to a quarter note triplet' #Fraction(1,2)
    
    elif valueToCheck == 768:   #dotted half note
        return 'Dotted half note' #Fraction(3,4)
    
    elif valueToCheck == 896:   #dotted half note
        return 'Half note tied to a dotted quarter note' #Fraction(3,4)
    
    elif valueToCheck == 1024:   #whole note
        return 'Whole note' #Fraction(1,1)
    
    elif valueToCheck == 1365:   #whole note
        return 'Whole note tied to a half note triplet' #Fraction(1,1)
    
    elif valueToCheck == 1622:   #whole note
        return 'Dotted whole note tied to an eighth note triplet' #Fraction(1,1)
    
    elif valueToCheck == 1920:   #whole note
        return 'Dotted whole note tied to a dotted quarter note' #Fraction(1,1)
    
    else:
        return None


def cleanAccidental(data_row):
    accidentalString = str(data_row['accidental'])
    test = re.sub('<[^>]*>', '', accidentalString)
    return str(test) 

# def cleanNoteName(data_row):
#     accidentalString = str(data_row['noteName'])
#     test = re.sub('<[^>]*>', '', accidentalString)
#     return str(test) 

def cleanOctave(data_row):
    accidentalString = str(data_row['Octave'])
    test = re.sub('<[^>]*>', '', accidentalString)
    return str(test) 

def cleanRest(data_row):
    restVal = -1
    restAsString = str(data_row['Rest or note flag'])
    if restAsString != 'None':
        restVal ='rest'
    else:
        restVal = 'note'

    return str(restVal)

def cleanPart(data_row):
    accidentalString = str(data_row['instrument'])
    test = accidentalString[3:5]
    return str(test) 

def convertDurationAsPerQuarterNoteIsOneBeat(data_row):
    asFloat = float(data_row['duration'])
    #print asFloat
    asFloat = asFloat / 256
    asFloat = floor(asFloat * 100) / 100.0
    
    return round(asFloat, 2)



def midiNumberAssign(data_row):
    offsetForC = 0
    offsetForD = 2
    offsetForE = 4
    offsetForF = 5
    offsetForG = 7
    offsetForA = 9
    offsetForB = 11

    def adjustForAccidental(accidentalVal):
        if accidentalVal == 'None':
            return 0
        else:
            return int(accidentalVal)

    if data_row['Octave'] != "None":
        baseVal = data_row['Octave'] * 12
        if data_row['Note name'] == 'C':
            return baseVal + adjustForAccidental(data_row['accidental'])
        elif data_row['Note name'] == 'D':
            return baseVal + offsetForD + adjustForAccidental(data_row['accidental'])
        elif data_row['Note name'] == 'E':
            return baseVal + offsetForE + adjustForAccidental(data_row['accidental'])
        elif data_row['Note name'] == 'F':
            return baseVal + offsetForF + adjustForAccidental(data_row['accidental'])
        elif data_row['Note name'] == 'G':
            return baseVal + offsetForG + adjustForAccidental(data_row['accidental'])
        elif data_row['Note name'] == 'A':
            return baseVal + offsetForA + adjustForAccidental(data_row['accidental'])
        elif data_row['Note name'] == 'B':
            return baseVal + offsetForB + adjustForAccidental(data_row['accidental'])



def adjustForAccidental(accidentalVal):
    if accidentalVal == 'None':
        return 0
    else:
        return int(accidentalVal)

    if data_row['Octave'] != "None":
        baseVal = int(data_row['Octave']) * 12
        if data_row['noteName'] == 'C':
            return baseVal + adjustForAccidental(data_row['accidental'])
        elif data_row['noteName'] == 'D':
            return baseVal + offsetForD + adjustForAccidental(data_row['accidental'])
        elif data_row['noteName'] == 'E':
            return baseVal + offsetForE + adjustForAccidental(data_row['accidental'])
        elif data_row['noteName'] == 'F':
            return baseVal + offsetForF + adjustForAccidental(data_row['accidental'])
        elif data_row['noteName'] == 'G':
            return baseVal + offsetForG + adjustForAccidental(data_row['accidental'])
        elif data_row['noteName'] == 'A':
            return baseVal + offsetForA + adjustForAccidental(data_row['accidental'])
        elif data_row['noteName'] == 'B':
            return baseVal + offsetForB + adjustForAccidental(data_row['accidental'])

def fixTiedNotes(data_row):
    tieFlagString = str(data_row['tieFlag'])
    durationToAdd = -1
    if tieFlagString == '<tie type="stop"></tie>':
        durationToAdd = data_row['Duration as a fraction of a whole note']
    else:
        durationToAdd = 0

    return durationToAdd


def getChordRootAsInt(data_row):
    x = data_row['Chord name']
    if x != -1:    
        chordLetterVal = data_row['Chord name'][0:2]
        #print chordLetterVal
        if chordLetterVal.strip() == 'C':
            return 0
        elif chordLetterVal.strip() =='C#':
            return 1
        elif chordLetterVal.strip() == 'Db':
            return 1
        elif chordLetterVal.strip() == 'D':
            return 2
        elif chordLetterVal.strip() == 'D#':
            return 3
        elif chordLetterVal.strip() == 'Eb':
            return 3
        elif chordLetterVal.strip() == 'E':
            return 4
        elif chordLetterVal.strip() == 'F':
            return 5
        elif chordLetterVal.strip() == 'F#':
            return 6
        elif chordLetterVal.strip() == 'Gb':
            return 6
        elif chordLetterVal.strip() == 'G':
            return 7
        elif chordLetterVal.strip() == 'G#':
            return 8
        elif chordLetterVal.strip() == 'Ab':
            return 8
        elif chordLetterVal.strip() == 'A':
            return 9
        elif chordLetterVal.strip() == 'A#':
            return 10
        elif chordLetterVal.strip() == 'Bb':
            return 10
        elif chordLetterVal.strip() == 'B':
            return 11
        else:
            return -1
       


    
def getChordTypeAsInt(data_row):
    x = data_row['Chord name']
    #print x
    if x != -1:
        chordType = re.findall('\s(.*)', x)
        try:
            chordType = str(chordType[0])
        except:
            chordType = 'fix'
        
        if chordType == 'maj7':
            return 0
        elif chordType == 'min7':
            return 1
        elif chordType == 'dom7':
            return 2
        elif chordType == 'dim7':
            return 3
        elif chordType == 'maj7b5':
            return 4
        elif chordType == 'maj7#5':
            return 5
        elif chordType == 'maj7sus4':
            return 6
        elif chordType == 'min7b5':
            return 7
        elif chordType == 'dom7b5':
            return 8
        elif chordType == 'dom7#5':
            return 9
        elif chordType == 'dom7sus4':
            return 10
        
        return -1


def chordTypeForDisplay(data_row):
    x = data_row['Chord name']
    if x != -1:
        chordType = re.findall('\s(.*)', x)   
        try:
            chordType = str(chordType[0])
        except:
            chordType = 'fix'
        return chordType
    
    
def chordBassAsInt(data_row):
    x = data_row['Chord name']
    if x != -1:
        x = str(x)
        indexOfBackslash = x.find('/')
        if indexOfBackslash == -1:
            return -1
        else:
            #function to deal with bass note
            return 'placeholder'
    

def concatenateNoteNamesAndAccidentals(data_row):
    retString = str(data_row['Note name'])
    octave = ''
    if data_row['accidental'] == '-1':
        retString = retString + 'b'
    elif data_row['accidental'] == '1':
        retString = retString + '#'
    if not np.isnan(data_row['Octave']):
        octave = int(data_row['Octave'])
        
    retString = retString + str(octave)
    return retString


def concatenateNoteNamesAndAccidentalsNoOctave(data_row):
    retString = str(data_row['Note name'])
    if data_row['accidental'] == '-1':
        retString = retString + 'b'
    elif data_row['accidental'] == '1':
        retString = retString + '#'

    return retString

def getFloorValueForMeasure(data_row):
    offsetForMeasure = 1
    floorValue = data_row['Location of note or rest']
    floorValue = (floorValue / 4) + offsetForMeasure
    return math.floor(floorValue)

def fixAccidentalEquivalencies(data_row):
    currentNoteName = data_row['Name of note without octave']
    if not np.isnan(data_row['Octave']):
        octave = int(data_row['Octave'])
    if currentNoteName == 'None':
        return 'None'
    if currentNoteName == 'C#':
        currentNoteName = 'Db'
    if currentNoteName == 'D#':
        currentNoteName = 'Eb'
    if currentNoteName == 'F#':
        currentNoteName = 'Gb'
    if currentNoteName == 'G#':
        currentNoteName = 'Ab'
    if currentNoteName == 'A#':
        currentNoteName = 'Bb'
    if currentNoteName == 'Cb':
        currentNoteName = 'B'
    if currentNoteName == 'Fb':
        currentNoteName = 'E'
    return currentNoteName + str(octave)

def fixAccidentalEquivalenciesNoOctave(data_row):
    currentNoteName = data_row['Name of note without octave']
    #currentOctave = data_row['octave']
    if currentNoteName == 'None':
        return 'None'
    if currentNoteName == 'C#':
        currentNoteName = 'Db'
    if currentNoteName == 'D#':
        currentNoteName = 'Eb'
    if currentNoteName == 'F#':
        currentNoteName = 'Gb'
    if currentNoteName == 'G#':
        currentNoteName = 'Ab'
    if currentNoteName == 'A#':
        currentNoteName = 'Bb'
    if currentNoteName == 'Cb':
        currentNoteName = 'B'
    if currentNoteName == 'Fb':
        currentNoteName = 'E'
    return currentNoteName


def calculateDistanceOfNoteToChordRoot(data_row):
    offsetForPositiveValue = 12
    midiNumber = data_row['Midi number']
    chordRoot = data_row['Chord root as minimized midi number']
    midiNumber = (midiNumber % 12) + 12
    distanceToRoot = midiNumber - chordRoot
    distanceToRoot = distanceToRoot % 12
    return distanceToRoot
    

def calculateDistanceOfNoteToChordBass(data_row):
    pass

def createReadableChordDegreeNames(data_row):
    noteRootDistance = data_row['Semitone distance between note and chord root']
    if noteRootDistance == 0:
        return 'root'
    if noteRootDistance == 1:
        return 'flat ninth'
    if noteRootDistance == 2:
        return 'ninth'
    if noteRootDistance == 3:
        return 'sharp ninth or minor third'
    if noteRootDistance == 4:
        return 'major third'
    if noteRootDistance == 5:
        return 'eleventh'
    if noteRootDistance == 6:
        return 'sharp eleventh or flat fifth'
    if noteRootDistance == 7:
        return 'fifth'
    if noteRootDistance == 8:
        return 'flat thirteenth or sharp fifth'
    if noteRootDistance == 9:
        return 'thirteenth'
    if noteRootDistance == 10:
        return 'seventh'
    if noteRootDistance == 11:
        return 'major seventh'
    return noteRootDistance

def getNextTenChords(chordRootAsIntValues, data_row):
    currentIndex = data_row.name
    currentChordRootAsInt = data_row['Chord root as minimized midi number']
    listOfAllChords = chordRootAsIntValues
    sliceOfChords = listOfAllChords[currentIndex:]
    sliceOfChords = sliceOfChords.tolist()
    sliceOfChords =  [a for a,b in zip(sliceOfChords, sliceOfChords[1:]+[not sliceOfChords[-1]]) if a != b]
    sliceOfChords = sliceOfChords[0:11]

    return sliceOfChords  


def createNextTenChordRootsAsNotes(data_row):
    stringToReturn = ''
    midiNumberSequence = data_row['Next ten chord root notes as midi numbers']
    for items in midiNumberSequence:
        if items == 0.0:
            stringToReturn = stringToReturn + 'Cx'
        elif items == 1.0:
            stringToReturn = stringToReturn + 'Db'
        elif items == 2.0:
            stringToReturn = stringToReturn + 'Dx'
        elif items == 3.0:
            stringToReturn = stringToReturn + 'Eb'
        elif items == 4.0:
            stringToReturn = stringToReturn + 'Ex'
        elif items == 5.0:
            stringToReturn = stringToReturn + 'Fx'
        elif items == 6.0:
            stringToReturn = stringToReturn + 'Gb'
        elif items == 7.0:
            stringToReturn = stringToReturn + 'Gx'
        elif items == 8.0:
            stringToReturn = stringToReturn + 'Ab'
        elif items == 9.0:
            stringToReturn = stringToReturn + 'Ax'
        elif items == 10.0:
            stringToReturn = stringToReturn + 'Bb'
        elif items == 11.0:
            stringToReturn = stringToReturn + 'Bx'
    return stringToReturn

def createNextTenChordRootsAsDegrees(data_row):
    stringToReturn = ''
    midiNumberSequence = data_row['Next ten chord root notes as midi numbers']
    firstValue = midiNumberSequence[0]
    for eachItem in midiNumberSequence:
        difference = int(eachItem) - int(firstValue)
        if difference < 0:
            difference = difference + 12
        if difference < 10:
            difference = '0' + str(difference)
        else: 
            difference = str(difference)
        stringToReturn = stringToReturn + str(difference)
    return stringToReturn


def getNextTenChordTypes(chordTypeValues, data_row):
    currentIndex = data_row.name
    currentChordType = data_row['Chord type name']
    listOfAllChords = chordTypeValues
    sliceOfChords = listOfAllChords[currentIndex:]
    sliceOfChords = sliceOfChords.tolist()
    sliceOfChords =  [a for a,b in zip(sliceOfChords, sliceOfChords[1:]+[not sliceOfChords[-1]]) if a != b]
    sliceOfChords = sliceOfChords[0:11]
    sliceOfChordsAsString = ''
    for eachValue in sliceOfChords:
        sliceOfChordsAsString = sliceOfChordsAsString + eachValue
    
    #return sliceOfChords  
    return sliceOfChordsAsString

def getNextTenChordTypesV2(chordTypeValues, data_row):
    currentIndex = data_row.name
    currentChordType = data_row['Chord type name']

    listOfAllChords = chordTypeValues
    sliceOfChords = listOfAllChords[currentIndex:]
    sliceOfChords = sliceOfChords.tolist()
    sliceOfChords =  [a for a,b in zip(sliceOfChords, sliceOfChords[1:]+[not sliceOfChords[-1]]) if a != b]
    sliceOfChords = sliceOfChords[0:11]
    sliceOfChordsAsString = ''
    for eachValue in sliceOfChords:
        paddedValue= eachValue.ljust(8, 'x')
        sliceOfChordsAsString = sliceOfChordsAsString + paddedValue
    
    #return sliceOfChords  
    return sliceOfChordsAsString


def getNextFiftyMidiNumbers(midiNumbersAsValues, data_row):
    currentIndex = data_row.name
    listOfAllMidiNumbers = midiNumbersAsValues
    sliceOfMidiNumbers = listOfAllMidiNumbers[currentIndex:]
    sliceOfMidiNumbers = sliceOfMidiNumbers.tolist()
    sliceOfMidiNumbers = sliceOfMidiNumbers[0:50]
    #print sliceOfMidiNumbers
    sliceOfMidiNumbersAsString = ''
    for eachValue in sliceOfMidiNumbers:
        if not (math.isnan(eachValue)):
            sliceOfMidiNumbersAsString = sliceOfMidiNumbersAsString + str(int(eachValue))
        else: 
            sliceOfMidiNumbersAsString = sliceOfMidiNumbersAsString + 'xx'
    

    return sliceOfMidiNumbersAsString




def getNextFiftyDurations(durationsAsValues, data_row):
    currentIndex = data_row.name
    listOfAllDurations = durationsAsValues
    sliceOfDurations = listOfAllDurations[currentIndex:]
    sliceOfDurations = sliceOfDurations.tolist()
    sliceOfDurations = sliceOfDurations[0:10]
    
    sliceOfDurationsAsString = ''
    for eachValue in sliceOfDurations:
        if not (math.isnan(eachValue)):
            paddedValue = str(eachValue)
            paddedValue = paddedValue.ljust(9, 'x')
            sliceOfDurationsAsString = sliceOfDurationsAsString + paddedValue
    
    return sliceOfDurationsAsString



def getNextFiftyLocations(locationsAsValues, data_row):
    currentIndex = data_row.name
    amountToNegate = data_row['Location of note or rest']
    listOfAllLocations = locationsAsValues
    sliceOfLocations = listOfAllLocations[currentIndex:]
    sliceOfLocations = sliceOfLocations.tolist()
    sliceOfLocations = sliceOfLocations[0:50]
    sliceOfLocationsAsString = ''
    for eachValue in sliceOfLocations:
        if not (math.isnan(eachValue)):
            offsetValue = eachValue - amountToNegate
            #roundedLocation = round(offsetValue, 4)
            paddedValue = str(offsetValue)
            paddedValue = paddedValue.ljust(9, 'x')
            sliceOfLocationsAsString = sliceOfLocationsAsString + paddedValue

    return sliceOfLocationsAsString.replace('False','0xxxx')


def getNextFiftyNotesAsDistancesFromStartingNote(midiNumbersAsValues, data_row):
    currentIndex = data_row.name
    listOfAllMidiNumbers = midiNumbersAsValues
    sliceOfMidiNumbers = listOfAllMidiNumbers[currentIndex:]
    sliceOfMidiNumbers = sliceOfMidiNumbers.tolist()
    sliceOfMidiNumbersWithoutNan = []
    
    for eachValue in sliceOfMidiNumbers:
        if not (math.isnan(eachValue)):
            sliceOfMidiNumbersWithoutNan.append(eachValue)

    stringToReturn = ''
    
    sliceOfMidiNumbersWithoutNan = sliceOfMidiNumbersWithoutNan[0:50]
    
    for i in range(0, len(sliceOfMidiNumbersWithoutNan)):
        currentValue = sliceOfMidiNumbersWithoutNan[i]
        try:
            nextValue = sliceOfMidiNumbersWithoutNan[i+1]
            difference = int(nextValue) - int(currentValue)
            differenceAsString = str(difference)
            if len(differenceAsString) == 1:
                differenceAsString = '+' + differenceAsString
            if len(differenceAsString) == 2:
                differenceAsString = differenceAsString + 'x'
            stringToReturn = stringToReturn + str(differenceAsString)
        except:
            pass

    return stringToReturn




def getCumulativeDuration(fullListOfDurationsAsFractions, data_row):
    currentIndex = data_row.name
    sumSoFar = fullListOfDurationsAsFractions[0:currentIndex].sum()
    #print 'At index', currentIndex, ' the sum is ' , sumSoFar

    return sumSoFar


def convertGlobalLocationToFloat( globalLocation, data_row):
    globalLocation = globalLocation
    locationInCurrentSong = data_row['Location of note or restV2']
    locationInCurrentSong = float(locationInCurrentSong)
    
    location = globalLocation + locationInCurrentSong
    return round(location, 8)

# %%
class CreateDataSetFromXML:
    def __init__(self, xmlFile="", performerName="", composerName="", 
                 genre="", numberOfParts=-1, title="", yearOfComposition="", 
                 yearOfPerformance="", ongoingTempo=-1, 
                 numberOfQuarterBeatsInBar = -1, tempoChangeIsOccuring = False, 
                 globalLocation = -1):

        self.xmlFile = xmlFile
        self.genre = genre
        self.numberOfParts = numberOfParts
        self.parsedXMLData = ""
        self.df = ""
        self.performerName = performerName
        self.composerName = composerName
        self.genre = genre
        self.numberOfParts = numberOfParts
        self.title = title
        self.yearOfComposition = yearOfComposition
        self.yearOfPerformance = yearOfPerformance
        self.ongoingTempo = ongoingTempo
        self.numberOfQuarterBeatsInBar = numberOfQuarterBeatsInBar
        self.tempoChangeIsOccuring = tempoChangeIsOccuring
        self.globalLocation = globalLocation
    

    def convertXMLToDataFrame(self):
        parsedXMLData = BeautifulSoup(open(self.xmlFile))
        allNotes = parsedXMLData.findAll('measure')
        listOfNoteEvents = []
        listOfSoloNotes = []
        listOfSoloNotesWithMergedRests = []
        for measure in allNotes:
            #print measure["number"]

            notes = measure.findAll('note')
            words = measure.findAll('words')
            
            for note in notes:
                measureDictionary = {}
                if note.pitch:
                    measureDictionary["Chord name"] = None
                    measureDictionary["instrument"] = measure.instrument["id"]
                    measureDictionary["Measure"] = int(measure["number"])
                    measureDictionary["Note name"] = note.step.text
                    measureDictionary["Octave"] = int(note.octave.text)
                    if note.duration != None:
                        measureDictionary['duration'] = float(note.duration.text)
                    measureDictionary['accidental'] = note.alter
                    measureDictionary["Rest or note flag"] = 'note'
                    measureDictionary['tieFlag'] = str(note.tie)
                else:
                    measureDictionary["Chord name"] = None
                    measureDictionary["instrument"] = measure.instrument["id"]
                    measureDictionary["Measure"] = int(measure["number"])
                    measureDictionary["Note name"] = None
                    measureDictionary["Octave"] = None
                    measureDictionary['duration'] = float(note.duration.text)
                    measureDictionary['accidental'] = None
                    measureDictionary["Rest or note flag"] = 'rest'
                    measureDictionary['tieFlag'] = None
                if measureDictionary['instrument'] == 'P1-I1':
                    measureDictionary['Instrument name'] = "Piano Solo Jazz (Treble)"
                    listOfNoteEvents.append(measureDictionary)
                    #listOfSoloNotes.append(measureDictionary)

            #print measure["number"]
            for word in range(0, len(words)):
                chordDictionary = {}
                chordDictionary['Chord name'] = words[word].text
                #print words[word].text
                chordDictionary["instrument"] = measure.instrument["id"]
                chordDictionary["Instrument name"] = "Jazz Harmony Bass Note" 
                chordDictionary["Measure"] = int(measure["number"])
                chordDictionary["Note name"] = words[word].parent.parent.parent.note.step.text
                #print chordDictionary["Note name"]
                chordDictionary["Octave"] = int(words[word].parent.parent.parent.note.octave.text)
                chordDictionary['duration'] = float(words[word].parent.parent.parent.note.duration.text)
                chordDictionary['accidental'] = words[word].parent.parent.parent.note.alter
                chordDictionary["Rest or note flag"] = 'note'
                chordDictionary['tieFlag'] = str(words[word].parent.parent.parent.note.tie)
                
                listOfNoteEvents.append(chordDictionary)
        
        self.df = pd.DataFrame(listOfNoteEvents)


    def fixLocationAndDuration(self):
        self.df['Duration as a fraction of a whole note'] = self.df.apply(getDurationsForMongoQueries, axis=1)
        
        soloPart = self.df[self.df['Instrument name'] == 'Piano Solo Jazz (Treble)']
        soloPart = soloPart.reset_index(drop=True)
        harmonyPart = self.df[self.df['Instrument name'] == 'Jazz Harmony Bass Note']
        harmonyPart = harmonyPart.reset_index(drop=True)
                             
        soloPart['Location of note or rest'] = soloPart['Duration as a fraction of a whole note'].cumsum()
        harmonyPart['Location of note or rest'] = harmonyPart['Duration as a fraction of a whole note'].cumsum()
        soloPart['Location of note or rest'] = soloPart['Location of note or rest'] - soloPart.iloc[0]['Duration as a fraction of a whole note']
        harmonyPart['Location of note or rest'] = harmonyPart['Location of note or rest'] - harmonyPart.iloc[0]['Duration as a fraction of a whole note']
        
        soloPart['valueToAddToTiedNote']=soloPart.apply(fixTiedNotes, axis=1)
        soloPart['moveTieForFix'] = soloPart['valueToAddToTiedNote'].shift(-1)
        soloPart = soloPart[soloPart.tieFlag != '<tie type="stop"></tie>']        
        soloPart['Duration as a fraction of a whole note'] = soloPart['Duration as a fraction of a whole note'] + soloPart['moveTieForFix']
        
        self.df = pd.concat([soloPart, harmonyPart], axis=0)
        self.df = self.df.sort(['Measure', 'Instrument name', 'Location of note or rest',], ascending=[1, 1,1])
        self.df = self.df.reset_index(drop=True)
        self.df['Name of duration'] = self.df.apply(getDurationNamesForMongoQueries, axis=1)

 
        #display(HTML(dataFrameWithMultipleRestsFixed.to_html()))
        
    def addMetaDataAndClean(self):
        self.df['Performer name'] = self.performerName
        self.df['Composer name'] = self.composerName
        self.df['Genre'] = self.genre
        self.df['Title'] = self.title
        self.df['Year of composition'] = self.yearOfComposition
        self.df['Year of performance'] = self.yearOfPerformance
        self.df['Tempo at this location'] = self.ongoingTempo
        self.df['Title'] = self.title
        self.df['accidental'] = self.df.apply(cleanAccidental, axis=1) 
        self.df['Midi number'] = self.df.apply(midiNumberAssign, axis=1)
        self.df['Name of note'] = self.df.apply(concatenateNoteNamesAndAccidentals, axis=1)
        self.df['Name of note without octave'] = self.df.apply(concatenateNoteNamesAndAccidentalsNoOctave, axis=1)
        self.df['convertAllSharpsToFlats'] = self.df.apply(fixAccidentalEquivalencies, axis=1)
        self.df['convertAllSharpsToFlatsNoOctave'] = self.df.apply(fixAccidentalEquivalenciesNoOctave, axis=1)
        self.df['Name of note'] = self.df['convertAllSharpsToFlats']
        self.df['Name of note without octave'] = self.df['convertAllSharpsToFlatsNoOctave']
        self.df['Text written on score'] = None
        self.df['Link to audio file'] = None
        self.df['Time position in audio file where note appears'] = None
        self.df['Global location'] = None
        self.df['Structural note flag'] = None
        self.df['Auxillary note flag'] = None
        self.df['User defined search tags'] = None
        
        del self.df["Note name"]
        del self.df["accidental"]
        del self.df["duration"]
        del self.df["instrument"]
        del self.df["moveTieForFix"]
        del self.df["tieFlag"]
        del self.df["convertAllSharpsToFlatsNoOctave"]
        del self.df["convertAllSharpsToFlats"]
        del self.df["valueToAddToTiedNote"]
        
    def sortByInstrumentsAndCalculateMidiDistancesBetweenNotes(self):
        
        soloPart = self.df[self.df['Instrument name'] == 'Piano Solo Jazz (Treble)']
        soloPart = soloPart.reset_index(drop=True)
        harmonyPart = self.df[self.df['Instrument name'] == 'Jazz Harmony Bass Note']
        harmonyPart = harmonyPart.reset_index(drop=True)
        
        soloPart['Semitone distance between current and next note'] = soloPart['Midi number'].shift(-1)
        soloPart['Semitone distance between current and previous note'] = soloPart['Midi number'].shift(1)
        soloPart['Semitone distance between current and next note'] = soloPart['Semitone distance between current and next note'] - soloPart['Midi number']
        soloPart['Semitone distance between current and previous note'] = soloPart['Semitone distance between current and previous note'] - soloPart['Midi number']
        
        harmonyPart['Semitone distance between current and next note'] = harmonyPart['Midi number'].shift(-1)
        harmonyPart['Semitone distance between current and previous note'] = harmonyPart['Midi number'].shift(1)
        harmonyPart['Semitone distance between current and next note'] = harmonyPart['Semitone distance between current and next note'] - harmonyPart['Midi number']
        harmonyPart['Semitone distance between current and previous note'] = harmonyPart['Semitone distance between current and previous note'] - harmonyPart['Midi number']
        
        self.df = pd.concat([soloPart, harmonyPart], axis=0)
        self.df = self.df.sort(['Measure', 'Instrument name', 'Location of note or rest', ], ascending=[1, 1,1])
        self.df = self.df.reset_index(drop=True)
        
        
    
    def updateChordData(self):
        self.df['Chord name'].fillna(method='ffill', inplace=True)
        self.df['Chord root as minimized midi number'] = self.df.apply(getChordRootAsInt, axis=1)
        self.df['Chord bass as minimized midi number'] = self.df.apply(chordBassAsInt, axis=1)
        self.df['Chord type name'] = self.df.apply(chordTypeForDisplay, axis=1)
        

    def createStringsNeededForMongoRegexQueries(self):
        
        soloPart = self.df[self.df['Instrument name'] == 'Piano Solo Jazz (Treble)']
        soloPart = soloPart.reset_index(drop=True)
        harmonyPart = self.df[self.df['Instrument name'] == 'Jazz Harmony Bass Note']
        harmonyPart = harmonyPart.reset_index(drop=True)
     
        allMidiNumbersInSoloPart = soloPart['Midi number'].values
        allMidiNumbersInHarmonyPart = harmonyPart['Midi number'].values
        
        allDurationsInSoloPart = soloPart['Duration as a fraction of a whole note'].values
        allDurationsInHarmonyPart = harmonyPart['Duration as a fraction of a whole note'].values
        
        allLocationsOfRestsAndNotesInSoloPart = soloPart['Location of note or rest'].values
        allLocationsOfRestsAndNotesInHarmonyPart = harmonyPart['Location of note or rest'].values
        

        soloPart['Next fifty midi numbers'] = soloPart.apply(partial(getNextFiftyMidiNumbers,allMidiNumbersInSoloPart), axis=1)
        harmonyPart['Next fifty midi numbers'] = harmonyPart.apply(partial(getNextFiftyMidiNumbers,allMidiNumbersInHarmonyPart), axis=1)
        
        soloPart['Next fifty durations'] = soloPart.apply(partial(getNextFiftyDurations, allDurationsInSoloPart), axis=1)
        harmonyPart['Next fifty durations'] = harmonyPart.apply(partial(getNextFiftyDurations, allDurationsInHarmonyPart), axis=1)
                
        soloPart['Next fifty music event locations'] = soloPart.apply(partial(getNextFiftyLocations, allLocationsOfRestsAndNotesInSoloPart), axis=1)
        harmonyPart['Next fifty music event locations'] = harmonyPart.apply(partial(getNextFiftyLocations, allLocationsOfRestsAndNotesInHarmonyPart), axis=1) 
        
        
        soloPart['Next fifty midi distances'] = soloPart.apply(partial(getNextFiftyNotesAsDistancesFromStartingNote,allMidiNumbersInSoloPart), axis=1)
        harmonyPart['Next fifty midi distances'] = harmonyPart.apply(partial(getNextFiftyNotesAsDistancesFromStartingNote, allMidiNumbersInHarmonyPart), axis=1) 
       

        self.df = pd.concat([soloPart, harmonyPart], axis=0)
        self.df = self.df.sort(['Location of note or rest', 'Instrument name'], ascending=[1,1])
        self.df = self.df.reset_index(drop=True)
        
        

    def returnPreparedDataFrame(self):
        return self.df

# %%
armandosRhumbaData = CreateDataSetFromXML(xmlFile="FinalDataSet/XMLFiles/JazzSolos/ChickCoreaArmandosRhumba.xml", 
                                  performerName="Chick Corea", composerName="Chick Corea", genre="Jazz", 
                                  numberOfParts=2, title="Armandos Rhumba", 
                                  yearOfComposition=1976, yearOfPerformance=1976, 
                                  ongoingTempo=261, tempoChangeIsOccuring = False,
                                  numberOfQuarterBeatsInBar=4, globalLocation = 10000)
armandosRhumbaData.convertXMLToDataFrame()
armandosRhumbaData.fixLocationAndDuration()
armandosRhumbaData.addMetaDataAndClean()
armandosRhumbaData.sortByInstrumentsAndCalculateMidiDistancesBetweenNotes()
armandosRhumbaData.updateChordData()
armandosRhumbaData.createStringsNeededForMongoRegexQueries()
armandosRhumbaDf = armandosRhumbaData.returnPreparedDataFrame()

# %%
#armandosRhumbaDf
# Out:
#      Chord name Duration as a fraction of a whole note           Instrument name Location of note or rest  Measure  Octave Rest or note flag      Name of duration Performer name Composer name Genre            Title  Year of composition  Year of performance  Tempo at this location  Midi number Name of note Name of note without octave Text written on score Link to audio file Time position in audio file where note appears Global location Structural note flag Auxillary note flag User defined search tags  Semitone distance between current and next note  Semitone distance between current and previous note  Chord root as minimized midi number Chord bass as minimized midi number Chord type name                            Next fifty midi numbers                               Next fifty durations                   Next fifty music event locations                          Next fifty midi distances
# 0             5                                    3/8    Jazz Harmony Bass Note                        0       35       5              note   Dotted quarter note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           70          Bb5                          Bb                  None               None                                           None            None                 None                None                     None                                              -36                                                -37                                     -1                                  -1             fix  7034343434342731242631242426312428293031323334...  3/8xxxxxx1xxxxxxxx1xxxxxxxx1xxxxxxxx1/2xxxxxx1...  0xxxxxxxx35xxxxxxx36xxxxxxx37xxxxxxx75/2xxxxx3...  -36+0x+0x+0x+0x-7x+4x-7x+2x+5x-7x+0x+2x+5x-7x+...
# 1         C min                                    1/2  Piano Solo Jazz (Treble)                        0        1     NaN              rest             Half note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261          NaN         None                        None                  None               None                                           None            None                 None                None                     None                                              NaN                                                NaN                                      0                                  -1             min  xx6363xx60xx60xx576060xx5559626360555148xxxx48...  1/2xxxxxx1/8xxxxxx1/8xxxxxx1/8xxxxxx1/8xxxxxx1...  0xxxxxxxx1/8xxxxxx1/4xxxxxx3/8xxxxxx1/2xxxxxx5...  +0x-3x+0x-3x+3x+0x-5x+4x+3x+1x-3x-5x-4x-3x+0x+...
# 2         C min                                    1/8  Piano Solo Jazz (Treble)                      1/8        1       5              note           Eighth note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           63          Eb5                          Eb                  None               None                                           None            None                 None                None                     None                                                0                                                NaN                                      0                                  -1             min  6363xx60xx60xx576060xx5559626360555148xxxx4851...  1/8xxxxxx1/8xxxxxx1/8xxxxxx1/8xxxxxx1/8xxxxxx1...  0xxxxxxxx1/8xxxxxx1/4xxxxxx3/8xxxxxx1/2xxxxxx5...  +0x-3x+0x-3x+3x+0x-5x+4x+3x+1x-3x-5x-4x-3x+0x+...
# 3         C min                                    1/8  Piano Solo Jazz (Treble)                      1/4        1       5              note           Eighth note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           63          Eb5                          Eb                  None               None                                           None            None                 None                None                     None                                              NaN                                                  0                                      0                                  -1             min  63xx60xx60xx576060xx5559626360555148xxxx485155...  1/8xxxxxx1/8xxxxxx1/8xxxxxx1/8xxxxxx1/8xxxxxx1...  0xxxxxxxx1/8xxxxxx1/4xxxxxx3/8xxxxxx1/2xxxxxx5...  -3x+0x-3x+3x+0x-5x+4x+3x+1x-3x-5x-4x-3x+0x+3x+...
# 4         C min                                    1/8  Piano Solo Jazz (Treble)                      3/8        1     NaN              rest           Eighth note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261          NaN         None                        None                  None               None                                           None            None                 None                None                     None                                              NaN                                                NaN                                      0                                  -1             min  xx60xx60xx576060xx5559626360555148xxxx48515550...  1/8xxxxxx1/8xxxxxx1/8xxxxxx1/8xxxxxx1/8xxxxxx1...  0xxxxxxxx1/8xxxxxx1/4xxxxxx3/8xxxxxx1/2xxxxxx5...  +0x-3x+3x+0x-5x+4x+3x+1x-3x-5x-4x-3x+0x+3x+4x-...
# 5         C min                                    1/8  Piano Solo Jazz (Treble)                      1/2        1       5              note           Eighth note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           60           C5                           C                  None               None                                           None            None                 None                None                     None                                              NaN                                                NaN                                      0                                  -1             min  60xx60xx576060xx5559626360555148xxxx4851555054...  1/8xxxxxx1/8xxxxxx1/8xxxxxx1/8xxxxxx1/8xxxxxx1...  0xxxxxxxx1/8xxxxxx1/4xxxxxx3/8xxxxxx1/2xxxxxx3...  +0x-3x+3x+0x-5x+4x+3x+1x-3x-5x-4x-3x+0x+3x+4x-...
# 6        D dom7                                    1/8  Piano Solo Jazz (Treble)                      5/8        2     NaN              rest           Eighth note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261          NaN         None                        None                  None               None                                           None            None                 None                None                     None                                              NaN                                                NaN                                      2                                  -1            dom7  xx60xx576060xx5559626360555148xxxx485155505457...  1/8xxxxxx1/8xxxxxx1/8xxxxxx1/8xxxxxx1/4xxxxxx1...  0xxxxxxxx1/8xxxxxx1/4xxxxxx3/8xxxxxx5/8xxxxxx7...  -3x+3x+0x-5x+4x+3x+1x-3x-5x-4x-3x+0x+3x+4x-5x+...
# 7        D dom7                                    1/8  Piano Solo Jazz (Treble)                      3/4        2       5              note           Eighth note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           60           C5                           C                  None               None                                           None            None                 None                None                     None                                              NaN                                                NaN                                      2                                  -1            dom7  60xx576060xx5559626360555148xxxx48515550545760...  1/8xxxxxx1/8xxxxxx1/8xxxxxx1/4xxxxxx1/4xxxxxx1...  0xxxxxxxx1/8xxxxxx1/4xxxxxx1/2xxxxxx3/4xxxxxx5...  -3x+3x+0x-5x+4x+3x+1x-3x-5x-4x-3x+0x+3x+4x-5x+...
# 8        D dom7                                    1/8  Piano Solo Jazz (Treble)                      7/8        2     NaN              rest           Eighth note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261          NaN         None                        None                  None               None                                           None            None                 None                None                     None                                              NaN                                                NaN                                      2                                  -1            dom7  xx576060xx5559626360555148xxxx4851555054576057...  1/8xxxxxx1/8xxxxxx1/4xxxxxx1/4xxxxxx1/2xxxxxx1...  0xxxxxxxx1/8xxxxxx3/8xxxxxx5/8xxxxxx9/8xxxxxx3...  +3x+0x-5x+4x+3x+1x-3x-5x-4x-3x+0x+3x+4x-5x+4x+...
# 9         C min                                      1    Jazz Harmony Bass Note                        1        1       2              note            Whole note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           24           C2                           C                  None               None                                           None            None                 None                None                     None                                                2                                                NaN                                      0                                  -1             min  2426312424263124282930313232333333343434342731...  1xxxxxxxx1xxxxxxxx1xxxxxxxx1xxxxxxxx1xxxxxxxx1...  0xxxxxxxx1xxxxxxxx2xxxxxxxx3xxxxxxxx4xxxxxxxx5...  +2x+5x-7x+0x+2x+5x-7x+4x+1x+1x+1x+1x+0x+1x+0x+...
# 10       D dom7                                    1/8  Piano Solo Jazz (Treble)                        1        2       4              note           Eighth note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           57           A4                           A                  None               None                                           None            None                 None                None                     None                                                3                                                NaN                                      2                                  -1            dom7  576060xx5559626360555148xxxx485155505457605755...  1/8xxxxxx1/4xxxxxx1/4xxxxxx1/2xxxxxx1/6xxxxxx1...  0xxxxxxxx1/4xxxxxx1/2xxxxxx1xxxxxxxx7/6xxxxxx4...  +3x+0x-5x+4x+3x+1x-3x-5x-4x-3x+0x+3x+4x-5x+4x+...
# 11       D dom7                                    1/4  Piano Solo Jazz (Treble)                      5/4        2       5              note          Quarter note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           60           C5                           C                  None               None                                           None            None                 None                None                     None                                                0                                                 -3                                      2                                  -1            dom7  6060xx5559626360555148xxxx48515550545760575556...  1/4xxxxxx1/4xxxxxx1/2xxxxxx1/6xxxxxx1/6xxxxxx1...  0xxxxxxxx1/4xxxxxx3/4xxxxxx11/12xxxx13/12xxxx5...  +0x-5x+4x+3x+1x-3x-5x-4x-3x+0x+3x+4x-5x+4x+3x+...
# 12       D dom7                                    1/4  Piano Solo Jazz (Treble)                      3/2        2       5              note          Quarter note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           60           C5                           C                  None               None                                           None            None                 None                None                     None                                              NaN                                                  0                                      2                                  -1            dom7  60xx5559626360555148xxxx4851555054576057555659...  1/4xxxxxx1/2xxxxxx1/6xxxxxx1/6xxxxxx1/6xxxxxx1...  0xxxxxxxx1/2xxxxxx2/3xxxxxx5/6xxxxxx1xxxxxxxx7...  -5x+4x+3x+1x-3x-5x-4x-3x+0x+3x+4x-5x+4x+3x+3x-...
# 13       D dom7                                      1    Jazz Harmony Bass Note                        2        2       2              note            Whole note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           26           D2                           D                  None               None                                           None            None                 None                None                     None                                                5                                                 -2                                      2                                  -1            dom7  2631242426312428293031323233333334343434273124...  1xxxxxxxx1xxxxxxxx1xxxxxxxx1xxxxxxxx1xxxxxxxx1...  0xxxxxxxx1xxxxxxxx2xxxxxxxx3xxxxxxxx4xxxxxxxx5...  +5x-7x+0x+2x+5x-7x+4x+1x+1x+1x+1x+0x+1x+0x+0x+...
# 14       G dom7                                    1/2  Piano Solo Jazz (Treble)                        2        3     NaN              rest             Half note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261          NaN         None                        None                  None               None                                           None            None                 None                None                     None                                              NaN                                                NaN                                      7                                  -1            dom7  xx5559626360555148xxxx485155505457605755565962...  1/2xxxxxx1/6xxxxxx1/6xxxxxx1/6xxxxxx1/6xxxxxx1...  0xxxxxxxx1/6xxxxxx1/3xxxxxx1/2xxxxxx2/3xxxxxx5...  +4x+3x+1x-3x-5x-4x-3x+0x+3x+4x-5x+4x+3x+3x-3x-...
# 15       G dom7                                    1/6  Piano Solo Jazz (Treble)                     13/6        3       4              note  Quarter note triplet    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           55           G4                           G                  None               None                                           None            None                 None                None                     None                                                4                                                NaN                                      7                                  -1            dom7  5559626360555148xxxx48515550545760575556596265...  1/6xxxxxx1/6xxxxxx1/6xxxxxx1/6xxxxxx1/6xxxxxx1...  0xxxxxxxx1/6xxxxxx1/3xxxxxx1/2xxxxxx2/3xxxxxx5...  +4x+3x+1x-3x-5x-4x-3x+0x+3x+4x-5x+4x+3x+3x-3x-...
# 16       G dom7                                    1/6  Piano Solo Jazz (Treble)                      7/3        3       4              note  Quarter note triplet    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           59           B4                           B                  None               None                                           None            None                 None                None                     None                                                3                                                 -4                                      7                                  -1            dom7  59626360555148xxxx4851555054576057555659626562...  1/6xxxxxx1/6xxxxxx1/6xxxxxx1/6xxxxxx1/6xxxxxx1...  0xxxxxxxx1/6xxxxxx1/3xxxxxx1/2xxxxxx2/3xxxxxx1...  +3x+1x-3x-5x-4x-3x+0x+3x+4x-5x+4x+3x+3x-3x-2x+...
# 17       G dom7                                    1/6  Piano Solo Jazz (Treble)                      5/2        3       5              note  Quarter note triplet    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           62           D5                           D                  None               None                                           None            None                 None                None                     None                                                1                                                 -3                                      7                                  -1            dom7  626360555148xxxx485155505457605755565962656263...  1/6xxxxxx1/6xxxxxx1/6xxxxxx1/6xxxxxx1/4xxxxxx1...  0xxxxxxxx1/6xxxxxx1/3xxxxxx1/2xxxxxx3/4xxxxxx1...  +1x-3x-5x-4x-3x+0x+3x+4x-5x+4x+3x+3x-3x-2x+1x+...
# 18        C min                                    1/6  Piano Solo Jazz (Treble)                      8/3        4       5              note  Quarter note triplet    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           63          Eb5                          Eb                  None               None                                           None            None                 None                None                     None                                               -3                                                 -1                                      0                                  -1             min  6360555148xxxx48515550545760575556596265626360...  1/6xxxxxx1/6xxxxxx1/6xxxxxx1/4xxxxxx1/4xxxxxx1...  0xxxxxxxx1/6xxxxxx1/3xxxxxx7/12xxxxx5/6xxxxxx4...  -3x-5x-4x-3x+0x+3x+4x-5x+4x+3x+3x-3x-2x+1x+3x+...
# 19        C min                                    1/6  Piano Solo Jazz (Treble)                     17/6        4       5              note  Quarter note triplet    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           60           C5                           C                  None               None                                           None            None                 None                None                     None                                               -5                                                  3                                      0                                  -1             min  60555148xxxx4851555054576057555659626562636055...  1/6xxxxxx1/6xxxxxx1/4xxxxxx1/4xxxxxx1/2xxxxxx1...  0xxxxxxxx1/6xxxxxx5/12xxxxx2/3xxxxxx7/6xxxxxx3...  -5x-4x-3x+0x+3x+4x-5x+4x+3x+3x-3x-2x+1x+3x+3x+...
# 20       G dom7                                      1    Jazz Harmony Bass Note                        3        3       2              note            Whole note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           31           G2                           G                  None               None                                           None            None                 None                None                     None                                               -7                                                 -5                                      7                                  -1            dom7  3124242631242829303132323333333434343427312426...  1xxxxxxxx1xxxxxxxx1xxxxxxxx1xxxxxxxx1xxxxxxxx1...  0xxxxxxxx1xxxxxxxx2xxxxxxxx3xxxxxxxx4xxxxxxxx5...  -7x+0x+2x+5x-7x+4x+1x+1x+1x+1x+0x+1x+0x+0x+1x+...
# 21        C min                                    1/6  Piano Solo Jazz (Treble)                        3        4       4              note  Quarter note triplet    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           55           G4                           G                  None               None                                           None            None                 None                None                     None                                               -4                                                  5                                      0                                  -1             min  555148xxxx485155505457605755565962656263605553...  1/6xxxxxx1/4xxxxxx1/4xxxxxx1/2xxxxxx1/8xxxxxx1...  0xxxxxxxx1/4xxxxxx1/2xxxxxx1xxxxxxxx9/8xxxxxx5...  -4x-3x+0x+3x+4x-5x+4x+3x+3x-3x-2x+1x+3x+3x+3x-...
# 22        C min                                    1/4  Piano Solo Jazz (Treble)                     13/4        4       4              note          Quarter note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           51          Eb4                          Eb                  None               None                                           None            None                 None                None                     None                                               -3                                                  4                                      0                                  -1             min  5148xxxx48515550545760575556596265626360555351...  1/4xxxxxx1/4xxxxxx1/2xxxxxx1/8xxxxxx1/8xxxxxx1...  0xxxxxxxx1/4xxxxxx3/4xxxxxx7/8xxxxxx1xxxxxxxx9...  -3x+0x+3x+4x-5x+4x+3x+3x-3x-2x+1x+3x+3x+3x-3x+...
# 23        C min                                    1/4  Piano Solo Jazz (Treble)                      7/2        4       4              note          Quarter note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           48           C4                           C                  None               None                                           None            None                 None                None                     None                                              NaN                                                  3                                      0                                  -1             min  48xxxx48515550545760575556596265626360555351xx...  1/4xxxxxx1/2xxxxxx1/8xxxxxx1/8xxxxxx1/8xxxxxx1...  0xxxxxxxx1/2xxxxxx5/8xxxxxx3/4xxxxxx7/8xxxxxx1...  +0x+3x+4x-5x+4x+3x+3x-3x-2x+1x+3x+3x+3x-3x+1x-...
# 24        C min                                      1    Jazz Harmony Bass Note                        4        4       2              note            Whole note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           24           C2                           C                  None               None                                           None            None                 None                None                     None                                                0                                                  7                                      0                                  -1             min  2424263124282930313232333333343434342731242631...  1xxxxxxxx1xxxxxxxx1xxxxxxxx1xxxxxxxx1xxxxxxxx1...  0xxxxxxxx1xxxxxxxx2xxxxxxxx3xxxxxxxx4xxxxxxxx5...  +0x+2x+5x-7x+4x+1x+1x+1x+1x+0x+1x+0x+0x+1x+0x+...
# 25        C min                                    1/2  Piano Solo Jazz (Treble)                        4        5     NaN              rest             Half note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261          NaN         None                        None                  None               None                                           None            None                 None                None                     None                                              NaN                                                NaN                                      0                                  -1             min  xxxx48515550545760575556596265626360555351xxxx...  1/2xxxxxx1/8xxxxxx1/8xxxxxx1/8xxxxxx1/8xxxxxx1...  0xxxxxxxx1/8xxxxxx1/4xxxxxx3/8xxxxxx1/2xxxxxx3...  +3x+4x-5x+4x+3x+3x-3x-2x+1x+3x+3x+3x-3x+1x-3x-...
# 26        C min                                    1/8  Piano Solo Jazz (Treble)                     33/8        5     NaN              rest           Eighth note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261          NaN         None                        None                  None               None                                           None            None                 None                None                     None                                              NaN                                                NaN                                      0                                  -1             min  xx48515550545760575556596265626360555351xxxx60...  1/8xxxxxx1/8xxxxxx1/8xxxxxx1/8xxxxxx1/4xxxxxx1...  0xxxxxxxx1/8xxxxxx1/4xxxxxx3/8xxxxxx5/8xxxxxx3...  +3x+4x-5x+4x+3x+3x-3x-2x+1x+3x+3x+3x-3x+1x-3x-...
# 27        C min                                    1/8  Piano Solo Jazz (Treble)                     17/4        5       4              note           Eighth note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           48           C4                           C                  None               None                                           None            None                 None                None                     None                                                3                                                NaN                                      0                                  -1             min  48515550545760575556596265626360555351xxxx6058...  1/8xxxxxx1/8xxxxxx1/8xxxxxx1/4xxxxxx1/8xxxxxx1...  0xxxxxxxx1/8xxxxxx1/4xxxxxx1/2xxxxxx5/8xxxxxx3...  +3x+4x-5x+4x+3x+3x-3x-2x+1x+3x+3x+3x-3x+1x-3x-...
# 28        C min                                    1/8  Piano Solo Jazz (Treble)                     35/8        5       4              note           Eighth note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           51          Eb4                          Eb                  None               None                                           None            None                 None                None                     None                                                4                                                 -3                                      0                                  -1             min  515550545760575556596265626360555351xxxx605860...  1/8xxxxxx1/8xxxxxx1/4xxxxxx1/8xxxxxx1/8xxxxxx1...  0xxxxxxxx1/8xxxxxx3/8xxxxxx1/2xxxxxx5/8xxxxxx7...  +4x-5x+4x+3x+3x-3x-2x+1x+3x+3x+3x-3x+1x-3x-5x-...
# 29        C min                                    1/8  Piano Solo Jazz (Treble)                      9/2        5       4              note           Eighth note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           55           G4                           G                  None               None                                           None            None                 None                None                     None                                               -5                                                 -4                                      0                                  -1             min  5550545760575556596265626360555351xxxx60586063...  1/8xxxxxx1/4xxxxxx1/8xxxxxx1/8xxxxxx1/4xxxxxx1...  0xxxxxxxx1/4xxxxxx3/8xxxxxx1/2xxxxxx3/4xxxxxx1...  -5x+4x+3x+3x-3x-2x+1x+3x+3x+3x-3x+1x-3x-5x-2x-...
# ..          ...                                    ...                       ...                      ...      ...     ...               ...                   ...            ...           ...   ...              ...                  ...                  ...                     ...          ...          ...                         ...                   ...                ...                                            ...             ...                  ...                 ...                      ...                                              ...                                                ...                                    ...                                 ...             ...                                                ...                                                ...                                                ...                                                ...
# 486      A dim7                                    1/6  Piano Solo Jazz (Treble)                    311/4      114       5              note  Quarter note triplet    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           69           A5                           A                  None               None                                           None            None                 None                None                     None                                                1                                                 -3                                      9                                  -1            dim7  69705858585863676765xx68676563596163xx46474647...  1/6xxxxxx3/8xxxxxx3/8xxxxxx1/4xxxxxx1/4xxxxxx1...  0xxxxxxxx3/8xxxxxx1/2xxxxxx1xxxxxxxx5/4xxxxxx3...  +1x-12+0x+0x+0x+5x+4x+0x-2x+3x-1x-2x-2x-4x+2x+...
# 487  Ab min6/Bb                                      1    Jazz Harmony Bass Note                       78      117       2              note            Whole note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           34          Bb2                          Bb                  None               None                                           None            None                 None                None                     None                                                0                                                  0                                      8                         placeholder         min6/Bb                                         3434342731      1xxxxxxxx1/2xxxxxx1/2xxxxxx1xxxxxxxx1xxxxxxxx      0xxxxxxxx1/2xxxxxx1xxxxxxxx2xxxxxxxx3xxxxxxxx                                       +0x+0x-7x+4x
# 488  Eb maj7/Bb                                    3/8  Piano Solo Jazz (Treble)                    625/8      115       5              note   Dotted quarter note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           70          Bb5                          Bb                  None               None                                           None            None                 None                None                     None                                              -12                                                 -1                                      3                         placeholder         maj7/Bb   705858585863676765xx68676563596163xx464746474950  3/8xxxxxx3/8xxxxxx1/4xxxxxx1/4xxxxxx1/4xxxxxx1...  0xxxxxxxx1/8xxxxxx5/8xxxxxx7/8xxxxxx9/8xxxxxx1...  -12+0x+0x+0x+5x+4x+0x-2x+3x-1x-2x-2x-4x+2x+2x-...
# 489  Eb maj7/Bb                                    3/8  Piano Solo Jazz (Treble)                    313/4      115       4              note           Eighth note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           58          Bb4                          Bb                  None               None                                           None            None                 None                None                     None                                                0                                                 12                                      3                         placeholder         maj7/Bb     5858585863676765xx68676563596163xx464746474950  3/8xxxxxx1/4xxxxxx1/4xxxxxx1/4xxxxxx1/4xxxxxx1...  0xxxxxxxx1/2xxxxxx3/4xxxxxx1xxxxxxxx5/4xxxxxx3...  +0x+0x+0x+5x+4x+0x-2x+3x-1x-2x-2x-4x+2x+2x-17+...
# 490     Bb dom7                                    1/2    Jazz Harmony Bass Note                    157/2      118       2              note             Half note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           34          Bb2                          Bb                  None               None                                           None            None                 None                None                     None                                                0                                                  0                                     10                                  -1            dom7                                           34342731               1/2xxxxxx1/2xxxxxx1xxxxxxxx1xxxxxxxx               0xxxxxxxx1/2xxxxxx3/2xxxxxx5/2xxxxxx                                          +0x-7x+4x
# 491  Eb maj7/Bb                                    1/4  Piano Solo Jazz (Treble)                    315/4      115       4              note          Quarter note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           58          Bb4                          Bb                  None               None                                           None            None                 None                None                     None                                                0                                                  0                                      3                         placeholder         maj7/Bb       58585863676765xx68676563596163xx464746474950  1/4xxxxxx1/4xxxxxx1/4xxxxxx1/4xxxxxx1/4xxxxxx1...  0xxxxxxxx1/4xxxxxx1/2xxxxxx3/4xxxxxx1xxxxxxxx9...  +0x+0x+5x+4x+0x-2x+3x-1x-2x-2x-4x+2x+2x-17+1x-...
# 492     Bb dom7                                    1/2    Jazz Harmony Bass Note                       79      118       2              note             Half note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           34          Bb2                          Bb                  None               None                                           None            None                 None                None                     None                                               -7                                                  0                                     10                                  -1            dom7                                             342731                        1/2xxxxxx1xxxxxxxx1xxxxxxxx                        0xxxxxxxx1xxxxxxxx2xxxxxxxx                                             -7x+4x
# 493  Eb maj7/Bb                                    1/4  Piano Solo Jazz (Treble)                       79      116       4              note          Quarter note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           58          Bb4                          Bb                  None               None                                           None            None                 None                None                     None                                                0                                                  0                                      3                         placeholder         maj7/Bb         585863676765xx68676563596163xx464746474950  1/4xxxxxx1/4xxxxxx1/4xxxxxx1/4xxxxxx1/8xxxxxx1...  0xxxxxxxx1/4xxxxxx1/2xxxxxx3/4xxxxxx7/8xxxxxx1...  +0x+5x+4x+0x-2x+3x-1x-2x-2x-4x+2x+2x-17+1x-1x+...
# 494  Eb maj7/Bb                                    1/4  Piano Solo Jazz (Treble)                    317/4      116       4              note          Quarter note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           58          Bb4                          Bb                  None               None                                           None            None                 None                None                     None                                                5                                                  0                                      3                         placeholder         maj7/Bb           5863676765xx68676563596163xx464746474950  1/4xxxxxx1/4xxxxxx1/4xxxxxx1/8xxxxxx1/8xxxxxx1...  0xxxxxxxx1/4xxxxxx1/2xxxxxx5/8xxxxxx3/4xxxxxx7...  +5x+4x+0x-2x+3x-1x-2x-2x-4x+2x+2x-17+1x-1x+1x+...
# 495  Eb maj7/Bb                                    1/4  Piano Solo Jazz (Treble)                    159/2      116       5              note          Quarter note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           63          Eb5                          Eb                  None               None                                           None            None                 None                None                     None                                                4                                                 -5                                      3                         placeholder         maj7/Bb             63676765xx68676563596163xx464746474950  1/4xxxxxx1/4xxxxxx1/8xxxxxx1/8xxxxxx1/8xxxxxx1...  0xxxxxxxx1/4xxxxxx3/8xxxxxx1/2xxxxxx5/8xxxxxx3...   +4x+0x-2x+3x-1x-2x-2x-4x+2x+2x-17+1x-1x+1x+2x+1x
# 496  Eb maj7/Bb                                    1/4  Piano Solo Jazz (Treble)                    319/4      116       5              note          Quarter note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           67           G5                           G                  None               None                                           None            None                 None                None                     None                                                0                                                 -4                                      3                         placeholder         maj7/Bb               676765xx68676563596163xx464746474950  1/4xxxxxx1/8xxxxxx1/8xxxxxx1/8xxxxxx1/2xxxxxx1...  0xxxxxxxx1/8xxxxxx1/4xxxxxx3/8xxxxxx1/2xxxxxx1...      +0x-2x+3x-1x-2x-2x-4x+2x+2x-17+1x-1x+1x+2x+1x
# 497  Ab min6/Bb                                    1/8  Piano Solo Jazz (Treble)                    639/8      117       5              note           Eighth note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           67           G5                           G                  None               None                                           None            None                 None                None                     None                                               -2                                                  0                                      8                         placeholder         min6/Bb                 6765xx68676563596163xx464746474950  1/8xxxxxx1/8xxxxxx1/8xxxxxx1/2xxxxxx1/8xxxxxx1...  0xxxxxxxx1/8xxxxxx1/4xxxxxx3/8xxxxxx7/8xxxxxx2...         -2x+3x-1x-2x-2x-4x+2x+2x-17+1x-1x+1x+2x+1x
# 498      Eb maj                                      1    Jazz Harmony Bass Note                       80      119       2              note            Whole note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           27          Eb2                          Eb                  None               None                                           None            None                 None                None                     None                                                4                                                  7                                      3                                  -1             maj                                               2731                                 1xxxxxxxx1xxxxxxxx                                 0xxxxxxxx1xxxxxxxx                                                +4x
# 499  Ab min6/Bb                                    1/8  Piano Solo Jazz (Treble)                       80      117       5              note           Eighth note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           65           F5                           F                  None               None                                           None            None                 None                None                     None                                              NaN                                                  2                                      8                         placeholder         min6/Bb                   65xx68676563596163xx464746474950  1/8xxxxxx1/8xxxxxx1/2xxxxxx1/8xxxxxx1/6xxxxxx1...  0xxxxxxxx1/8xxxxxx1/4xxxxxx3/4xxxxxx11/12xxxx1...            +3x-1x-2x-2x-4x+2x+2x-17+1x-1x+1x+2x+1x
# 500  Ab min6/Bb                                    1/8  Piano Solo Jazz (Treble)                    641/8      117     NaN              rest           Eighth note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261          NaN         None                        None                  None               None                                           None            None                 None                None                     None                                              NaN                                                NaN                                      8                         placeholder         min6/Bb                     xx68676563596163xx464746474950  1/8xxxxxx1/2xxxxxx1/8xxxxxx1/6xxxxxx1/6xxxxxx1...  0xxxxxxxx1/8xxxxxx5/8xxxxxx19/24xxxx23/24xxxx9...               -1x-2x-2x-4x+2x+2x-17+1x-1x+1x+2x+1x
# 501  Ab min6/Bb                                    1/2  Piano Solo Jazz (Treble)                    321/4      117       5              note           Eighth note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           68          Ab5                          Ab                  None               None                                           None            None                 None                None                     None                                               -1                                                NaN                                      8                         placeholder         min6/Bb                       68676563596163xx464746474950  1/2xxxxxx1/8xxxxxx1/6xxxxxx1/6xxxxxx1/6xxxxxx3...  0xxxxxxxx1/2xxxxxx2/3xxxxxx5/6xxxxxx1xxxxxxxx1...               -1x-2x-2x-4x+2x+2x-17+1x-1x+1x+2x+1x
# 502  Ab min6/Bb                                    1/8  Piano Solo Jazz (Treble)                    323/4      117       5              note           Eighth note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           67           G5                           G                  None               None                                           None            None                 None                None                     None                                               -2                                                  1                                      8                         placeholder         min6/Bb                         676563596163xx464746474950  1/8xxxxxx1/6xxxxxx1/6xxxxxx1/6xxxxxx3/8xxxxxx1...  0xxxxxxxx1/6xxxxxx1/3xxxxxx1/2xxxxxx7/8xxxxxx1...                  -2x-2x-4x+2x+2x-17+1x-1x+1x+2x+1x
# 503     Bb dom7                                    1/6  Piano Solo Jazz (Treble)                   971/12      118       5              note  Quarter note triplet    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           65           F5                           F                  None               None                                           None            None                 None                None                     None                                               -2                                                  2                                     10                                  -1            dom7                           6563596163xx464746474950  1/6xxxxxx1/6xxxxxx1/6xxxxxx3/8xxxxxx1/8xxxxxx3...  0xxxxxxxx1/6xxxxxx1/3xxxxxx17/24xxxx5/6xxxxxx2...                     -2x-4x+2x+2x-17+1x-1x+1x+2x+1x
# 504      G dom7                                      1    Jazz Harmony Bass Note                       81      120       2              note            Whole note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           31           G2                           G                  None               None                                           None            None                 None                None                     None                                              NaN                                                 -4                                      7                                  -1            dom7                                                 31                                          1xxxxxxxx                                          0xxxxxxxx
# 505     Bb dom7                                    1/6  Piano Solo Jazz (Treble)                   973/12      118       5              note  Quarter note triplet    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           63          Eb5                          Eb                  None               None                                           None            None                 None                None                     None                                               -4                                                  2                                     10                                  -1            dom7                             63596163xx464746474950  1/6xxxxxx1/6xxxxxx3/8xxxxxx1/8xxxxxx3/8xxxxxx1...  0xxxxxxxx1/6xxxxxx13/24xxxx2/3xxxxxx25/24xxxx7...                        -4x+2x+2x-17+1x-1x+1x+2x+1x
# 506     Bb dom7                                    1/6  Piano Solo Jazz (Treble)                    325/4      118       5              note  Quarter note triplet    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           59           B5                           B                  None               None                                           None            None                 None                None                     None                                                2                                                  4                                     10                                  -1            dom7                               596163xx464746474950  1/6xxxxxx3/8xxxxxx1/8xxxxxx3/8xxxxxx1/8xxxxxx1...  0xxxxxxxx3/8xxxxxx1/2xxxxxx7/8xxxxxx1xxxxxxxx5...                           +2x+2x-17+1x-1x+1x+2x+1x
# 507     Bb dom7                                    3/8  Piano Solo Jazz (Treble)                    653/8      118       5              note   Dotted quarter note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           61          Db5                          Db                  None               None                                           None            None                 None                None                     None                                                2                                                 -2                                     10                                  -1            dom7                                 6163xx464746474950  3/8xxxxxx1/8xxxxxx3/8xxxxxx1/8xxxxxx1/4xxxxxx1...  0xxxxxxxx1/8xxxxxx1/2xxxxxx5/8xxxxxx7/8xxxxxx9...                              +2x-17+1x-1x+1x+2x+1x
# 508     Bb dom7                                    1/8  Piano Solo Jazz (Treble)                    327/4      118       5              note           Eighth note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           63          Eb5                          Eb                  None               None                                           None            None                 None                None                     None                                              NaN                                                 -2                                     10                                  -1            dom7                                   63xx464746474950  1/8xxxxxx3/8xxxxxx1/8xxxxxx1/4xxxxxx1/4xxxxxx3...  0xxxxxxxx3/8xxxxxx1/2xxxxxx3/4xxxxxx1xxxxxxxx1...                                 -17+1x-1x+1x+2x+1x
# 509      Eb maj                                    3/8  Piano Solo Jazz (Treble)                    657/8      119     NaN              rest   Dotted quarter note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261          NaN         None                        None                  None               None                                           None            None                 None                None                     None                                              NaN                                                NaN                                      3                                  -1             maj                                     xx464746474950  3/8xxxxxx1/8xxxxxx1/4xxxxxx1/4xxxxxx3/8xxxxxx1...  0xxxxxxxx1/8xxxxxx3/8xxxxxx5/8xxxxxx1xxxxxxxx2...                                    +1x-1x+1x+2x+1x
# 510      Eb maj                                    1/8  Piano Solo Jazz (Treble)                    329/4      119       3              note           Eighth note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           46          Bb3                          Bb                  None               None                                           None            None                 None                None                     None                                                1                                                NaN                                      3                                  -1             maj                                       464746474950  1/8xxxxxx1/4xxxxxx1/4xxxxxx3/8xxxxxx1xxxxxxxx5...  0xxxxxxxx1/4xxxxxx1/2xxxxxx7/8xxxxxx15/8xxxxx2...                                    +1x-1x+1x+2x+1x
# 511      Eb maj                                    1/4  Piano Solo Jazz (Treble)                    165/2      119       4              note          Quarter note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           47           B4                           B                  None               None                                           None            None                 None                None                     None                                               -1                                                 -1                                      3                                  -1             maj                                         4746474950      1/4xxxxxx1/4xxxxxx3/8xxxxxx1xxxxxxxx5/8xxxxxx      0xxxxxxxx1/4xxxxxx5/8xxxxxx13/8xxxxx7/4xxxxxx                                       -1x+1x+2x+1x
# 512      Eb maj                                    1/4  Piano Solo Jazz (Treble)                    331/4      119       3              note          Quarter note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           46          Bb3                          Bb                  None               None                                           None            None                 None                None                     None                                                1                                                  1                                      3                                  -1             maj                                           46474950               1/4xxxxxx3/8xxxxxx1xxxxxxxx5/8xxxxxx               0xxxxxxxx3/8xxxxxx11/8xxxxx3/2xxxxxx                                          +1x+2x+1x
# 513      G dom7                                    3/8  Piano Solo Jazz (Treble)                    665/8      120       3              note   Dotted quarter note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           47           B3                           B                  None               None                                           None            None                 None                None                     None                                                2                                                 -1                                      7                                  -1            dom7                                             474950                        3/8xxxxxx1xxxxxxxx5/8xxxxxx                        0xxxxxxxx1xxxxxxxx9/8xxxxxx                                             +2x+1x
# 514      G dom7                                      1  Piano Solo Jazz (Treble)                    673/8      120       4              note                  None    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           49          Db4                          Db                  None               None                                           None            None                 None                None                     None                                                1                                                 -2                                      7                                  -1            dom7                                               4950                                 1xxxxxxxx5/8xxxxxx                                 0xxxxxxxx1/8xxxxxx                                                +1x
# 515      G dom7                                    5/8  Piano Solo Jazz (Treble)                    337/4      120       4              note           Eighth note    Chick Corea   Chick Corea  Jazz  Armandos Rhumba                 1976                 1976                     261           50           D4                           D                  None               None                                           None            None                 None                None                     None                                              NaN                                                 -1                                      7                                  -1            dom7                                                 50                                          5/8xxxxxx                                          0xxxxxxxx
#
# [516 rows x 34 columns]

# %%
stellaData = CreateDataSetFromXML(xmlFile="FinalDataSet/XMLFiles/JazzSolos/KeithJarrettStellaByStarlight.xml", 
                                  performerName="Keith Jarrett", composerName="Victor Young", genre="Jazz", 
                                  numberOfParts=2, title="Stella By Starlight", 
                                  yearOfComposition=1944, yearOfPerformance=1983, 
                                  ongoingTempo=151,numberOfQuarterBeatsInBar=4, 
                                  tempoChangeIsOccuring = False, globalLocation = 20000)
stellaData.convertXMLToDataFrame()
stellaData.fixLocationAndDuration()
stellaData.addMetaDataAndClean()
stellaData.sortByInstrumentsAndCalculateMidiDistancesBetweenNotes()
stellaData.updateChordData()
stellaData.createStringsNeededForMongoRegexQueries()
stellaDf = stellaData.returnPreparedDataFrame()

# %%
stellaDf.tail(1)
# Out:
#      Chord name Duration as a fraction of a whole note           Instrument name Location of note or rest  Measure  Octave Rest or note flag Name of duration Performer name Composer name Genre                Title  Year of composition  Year of performance  Tempo at this location  Midi number Name of note Name of note without octave Text written on score Link to audio file Time position in audio file where note appears Global location Structural note flag Auxillary note flag User defined search tags  Semitone distance between current and next note  Semitone distance between current and previous note  Chord root as minimized midi number  Chord bass as minimized midi number Chord type name Next fifty midi numbers Next fifty durations Next fifty music event locations Next fifty midi distances
# 1662   E min7b5                                    NaN  Piano Solo Jazz (Treble)                30887/192      161     NaN              rest        Half note  Keith Jarrett  Victor Young  Jazz  Stella By Starlight                 1944                 1983                     151          NaN         None                        None                  None               None                                           None            None                 None                None                     None                                              NaN                                                NaN                                      4                                   -1          min7b5                      xx                                             0xxxxxxxx

# %%
groovinData = CreateDataSetFromXML(xmlFile="FinalDataSet/XMLFiles/JazzSolos/KeithJarrettGroovinHigh.xml", 
                                  performerName="Keith Jarrett", composerName="Dizzy Gillespie", genre="Jazz", 
                                  numberOfParts=2, title="Groovin High", 
                                  yearOfComposition=1945, yearOfPerformance=1999, 
                                  ongoingTempo=282, 
                                  numberOfQuarterBeatsInBar=4, 
                                  tempoChangeIsOccuring = False, globalLocation = 30000)
groovinData.convertXMLToDataFrame()
groovinData.fixLocationAndDuration()
groovinData.addMetaDataAndClean()
groovinData.sortByInstrumentsAndCalculateMidiDistancesBetweenNotes()
groovinData.updateChordData()
groovinData.createStringsNeededForMongoRegexQueries()
groovinDf = groovinData.returnPreparedDataFrame()

# %%
autumnData = CreateDataSetFromXML(xmlFile="FinalDataSet/XMLFiles/JazzSolos/KeithJarrettAutumnLeaves.xml", 
                                  performerName="Keith Jarrett", composerName="Joseph Kosma", genre="Jazz", 
                                  numberOfParts=2, title="Autumn Leaves", 
                                  yearOfComposition=1945, yearOfPerformance=1996, 
                                  ongoingTempo=214, 
                                  numberOfQuarterBeatsInBar=4, 
                                  tempoChangeIsOccuring = False, globalLocation = 40000)
autumnData.convertXMLToDataFrame()
autumnData.fixLocationAndDuration()
autumnData.addMetaDataAndClean()
autumnData.sortByInstrumentsAndCalculateMidiDistancesBetweenNotes()
autumnData.updateChordData()
autumnData.createStringsNeededForMongoRegexQueries()
autumnDf = autumnData.returnPreparedDataFrame()

# %%
ifIWereData = CreateDataSetFromXML(xmlFile="FinalDataSet/XMLFiles/JazzSolos/KeithJarrettIfIWereABell.xml", 
                                  performerName="Keith Jarrett", composerName="Frank Loesser", genre="Jazz", 
                                  numberOfParts=2, title="If I Were A Bell", 
                                  yearOfComposition=1950, yearOfPerformance=2002, 
                                  ongoingTempo=154, numberOfQuarterBeatsInBar=4, 
                                  tempoChangeIsOccuring = False, globalLocation = 50000)
ifIWereData.convertXMLToDataFrame()
ifIWereData.fixLocationAndDuration()
ifIWereData.addMetaDataAndClean()
ifIWereData.sortByInstrumentsAndCalculateMidiDistancesBetweenNotes()
ifIWereData.updateChordData()
ifIWereData.createStringsNeededForMongoRegexQueries()
ifIWereDf = ifIWereData.returnPreparedDataFrame()

# %%
allTheThingsData = CreateDataSetFromXML(xmlFile="FinalDataSet/XMLFiles/JazzSolos/KeithJarrettAllTheThingsYouAre.xml", 
                                  performerName="Keith Jarrett", composerName="Jerome Kern", genre="Jazz", 
                                  numberOfParts=2, title="All The Things You Are", 
                                  yearOfComposition=1939, yearOfPerformance=1983, 
                                  ongoingTempo=120, tempoChangeIsOccuring = False, 
                                  numberOfQuarterBeatsInBar=4, globalLocation = 60000)
allTheThingsData.convertXMLToDataFrame()
allTheThingsData.fixLocationAndDuration()
allTheThingsData.addMetaDataAndClean()
allTheThingsData.sortByInstrumentsAndCalculateMidiDistancesBetweenNotes()
allTheThingsData.updateChordData()
allTheThingsData.createStringsNeededForMongoRegexQueries()
allTheThingsDf = allTheThingsData.returnPreparedDataFrame()

# %%
somedayMyPrinceData = CreateDataSetFromXML(xmlFile="FinalDataSet/XMLFiles/JazzSolos/KeithJarrettSomedayMyPrinceWillCome.xml", 
                                  performerName="Keith Jarrett", composerName="Frank Churchill", genre="Jazz", 
                                  numberOfParts=2, title="Someday My Prince Will Come", 
                                  yearOfComposition=1937, yearOfPerformance=2002, 
                                  ongoingTempo=146, tempoChangeIsOccuring = False,
                                  numberOfQuarterBeatsInBar=3, globalLocation = 70000)
somedayMyPrinceData.convertXMLToDataFrame()
somedayMyPrinceData.fixLocationAndDuration()
somedayMyPrinceData.addMetaDataAndClean()
somedayMyPrinceData.sortByInstrumentsAndCalculateMidiDistancesBetweenNotes()
somedayMyPrinceData.updateChordData()
somedayMyPrinceData.createStringsNeededForMongoRegexQueries()
somedayMyPrinceDf = somedayMyPrinceData.returnPreparedDataFrame()

# %%
daysOfWineData = CreateDataSetFromXML(xmlFile="FinalDataSet/XMLFiles/JazzSolos/KeithJarrettDaysOfWineAndRoses.xml", 
                                  performerName="Keith Jarrett", composerName="Henry Mancini", genre="Jazz", 
                                  numberOfParts=2, title="Days Of Wine And Roses", 
                                  yearOfComposition=1962, yearOfPerformance=1994, 
                                  ongoingTempo=168, tempoChangeIsOccuring = False,
                                  numberOfQuarterBeatsInBar=4, globalLocation = 80000)
daysOfWineData.convertXMLToDataFrame()
daysOfWineData.fixLocationAndDuration()
daysOfWineData.addMetaDataAndClean()
daysOfWineData.sortByInstrumentsAndCalculateMidiDistancesBetweenNotes()
daysOfWineData.updateChordData()
daysOfWineData.createStringsNeededForMongoRegexQueries()
daysOfWineDf = daysOfWineData.returnPreparedDataFrame()

# %%
df = pd.concat([stellaDf, groovinDf, autumnDf, ifIWereDf, allTheThingsDf, somedayMyPrinceDf, daysOfWineDf, armandosRhumbaDf], axis=0)
#df = stellaDf
df.to_pickle('data_set_as_pk.pkl')

# %%
df['Title'].value_counts()
# Out:
# All The Things You Are         2313
# If I Were A Bell               2280
# Groovin High                   2118
# Someday My Prince Will Come    2049
# Stella By Starlight            1663
# Days Of Wine And Roses         1614
# Autumn Leaves                  1416
# dtype: int64

# %%
df.tail(100)
# Out:
#      Chord name Duration as a fraction of a whole note           Instrument name Location of note or rest  Measure  Octave Rest or note flag     Name of duration Performer name  Composer name Genre                   Title  Year of composition  Year of performance  Tempo at this location  Midi number Name of note Name of note without octave Text written on score Link to audio file Time position in audio file where note appears Global location Structural note flag Auxillary note flag User defined search tags  Semitone distance between current and next note  Semitone distance between current and previous note  Chord root as minimized midi number Chord bass as minimized midi number Chord type name                            Next fifty midi numbers                               Next fifty durations                   Next fifty music event locations                          Next fifty midi distances
# 1514     G min7                                   1/12  Piano Solo Jazz (Treble)              450019/3072      147       4              note  Eighth note triplet  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           59           B4                           B                  None               None                                           None            None                 None                None                     None                                                4                                                 -1                                      7                                  -1            min7  5963666763586265636467616761605857xxxxxxxxxxxx...  1/12xxxxx1/12xxxxx1/12xxxxx1/12xxxxx1/16xxxxx1...  0xxxxxxxx1/12xxxxx1/6xxxxxx1/4xxxxxx5/16xxxxx3...  +4x+3x+1x-4x-5x+4x+3x-2x+1x+3x-6x+6x-6x-1x-2x-...
# 1515     G min7                                      1    Jazz Harmony Bass Note                    293/2      147       2              note           Whole note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           31           G2                           G                  None               None                                           None            None                 None                None                     None                                                5                                                  0                                      7                                  -1            min7     3136292827263131343433262635283333313129293131  1xxxxxxxx1xxxxxxxx1xxxxxxxx1xxxxxxxx1xxxxxxxx1...  0xxxxxxxx1xxxxxxxx2xxxxxxxx3xxxxxxxx4xxxxxxxx5...  +5x-7x-1x-1x-1x+5x+0x+3x+0x-1x-7x+0x+9x-7x+5x+...
# 1516     G min7                                   1/12  Piano Solo Jazz (Treble)              450275/3072      147       5              note  Eighth note triplet  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           63          Eb5                          Eb                  None               None                                           None            None                 None                None                     None                                                3                                                 -4                                      7                                  -1            min7  63666763586265636467616761605857xxxxxxxxxxxxxx...  1/12xxxxx1/12xxxxx1/12xxxxx1/16xxxxx1/16xxxxx1...  0xxxxxxxx1/12xxxxx1/6xxxxxx11/48xxxx7/24xxxxx1...  +3x+1x-4x-5x+4x+3x-2x+1x+3x-6x+6x-6x-1x-2x-1x+...
# 1517     G min7                                   1/12  Piano Solo Jazz (Treble)              150177/1024      147       5              note  Eighth note triplet  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           66          Gb5                          Gb                  None               None                                           None            None                 None                None                     None                                                1                                                 -3                                      7                                  -1            min7  666763586265636467616761605857xxxxxxxxxxxxxxxx...  1/12xxxxx1/12xxxxx1/16xxxxx1/16xxxxx1/16xxxxx1...  0xxxxxxxx1/12xxxxx7/48xxxxx5/24xxxxx13/48xxxx1...  +1x-4x-5x+4x+3x-2x+1x+3x-6x+6x-6x-1x-2x-1x+3x-...
# 1518     G min7                                   1/12  Piano Solo Jazz (Treble)              450787/3072      147       5              note  Eighth note triplet  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           67           G5                           G                  None               None                                           None            None                 None                None                     None                                               -4                                                 -1                                      7                                  -1            min7  6763586265636467616761605857xxxxxxxxxxxxxxxxxx...  1/12xxxxx1/16xxxxx1/16xxxxx1/16xxxxx1/16xxxxx1...  0xxxxxxxx1/16xxxxx1/8xxxxxx3/16xxxxx1/4xxxxxx1...  -4x-5x+4x+3x-2x+1x+3x-6x+6x-6x-1x-2x-1x+3x-3x-...
# 1519     C dom7                                   1/16  Piano Solo Jazz (Treble)              450979/3072      148       5              note       Sixteenth note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           63          Eb5                          Eb                  None               None                                           None            None                 None                None                     None                                               -5                                                  4                                      0                                  -1            dom7  63586265636467616761605857xxxxxxxxxxxxxxxxxxxx...  1/16xxxxx1/16xxxxx1/16xxxxx1/16xxxxx1/12xxxxx1...  0xxxxxxxx1/16xxxxx1/8xxxxxx3/16xxxxx13/48xxxx1...  -5x+4x+3x-2x+1x+3x-6x+6x-6x-1x-2x-1x+3x-3x-4x-...
# 1520     C dom7                                   1/16  Piano Solo Jazz (Treble)              451171/3072      148       4              note       Sixteenth note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           58          Bb4                          Bb                  None               None                                           None            None                 None                None                     None                                                4                                                  5                                      0                                  -1            dom7  586265636467616761605857xxxxxxxxxxxxxxxxxxxxxx...  1/16xxxxx1/16xxxxx1/16xxxxx1/12xxxxx1/12xxxxx1...  0xxxxxxxx1/16xxxxx1/8xxxxxx5/24xxxxx7/24xxxxx3...  +4x+3x-2x+1x+3x-6x+6x-6x-1x-2x-1x+3x-3x-4x-5x+...
# 1521     C dom7                                   1/16  Piano Solo Jazz (Treble)              451363/3072      148       5              note       Sixteenth note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           62           D5                           D                  None               None                                           None            None                 None                None                     None                                                3                                                 -4                                      0                                  -1            dom7  6265636467616761605857xxxxxxxxxxxxxxxxxxxxxxxx...  1/16xxxxx1/16xxxxx1/12xxxxx1/12xxxxx1/12xxxxx1...  0xxxxxxxx1/16xxxxx7/48xxxxx11/48xxxx5/16xxxxx7...  +3x-2x+1x+3x-6x+6x-6x-1x-2x-1x+3x-3x-4x-5x+2x+...
# 1522     C dom7                                   1/16  Piano Solo Jazz (Treble)              451555/3072      148       5              note       Sixteenth note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           65           F5                           F                  None               None                                           None            None                 None                None                     None                                               -2                                                 -3                                      0                                  -1            dom7  65636467616761605857xxxxxxxxxxxxxxxxxxxxxxxx60...  1/16xxxxx1/12xxxxx1/12xxxxx1/12xxxxx1/8xxxxxx1...  0xxxxxxxx1/12xxxxx1/6xxxxxx1/4xxxxxx3/8xxxxxx7...  -2x+1x+3x-6x+6x-6x-1x-2x-1x+3x-3x-4x-5x+2x+3x+...
# 1523     C dom7                                   1/12  Piano Solo Jazz (Treble)              451811/3072      148       5              note  Eighth note triplet  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           63          Eb5                          Eb                  None               None                                           None            None                 None                None                     None                                                1                                                  2                                      0                                  -1            dom7  636467616761605857xxxxxxxxxxxxxxxxxxxxxxxx6057...  1/12xxxxx1/12xxxxx1/12xxxxx1/8xxxxxx1/16xxxxx1...  0xxxxxxxx1/12xxxxx1/6xxxxxx7/24xxxxx17/48xxxx5...  +1x+3x-6x+6x-6x-1x-2x-1x+3x-3x-4x-5x+2x+3x+2x-...
# 1524     C dom7                                   1/12  Piano Solo Jazz (Treble)              150689/1024      148       5              note  Eighth note triplet  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           64           E5                           E                  None               None                                           None            None                 None                None                     None                                                3                                                 -1                                      0                                  -1            dom7  6467616761605857xxxxxxxxxxxxxxxxxxxxxxxx605753...  1/12xxxxx1/12xxxxx1/8xxxxxx1/16xxxxx1/16xxxxx1...  0xxxxxxxx1/12xxxxx5/24xxxxx13/48xxxx1/3xxxxxx1...  +3x-6x+6x-6x-1x-2x-1x+3x-3x-4x-5x+2x+3x+2x-2x+...
# 1525     C dom7                                   1/12  Piano Solo Jazz (Treble)              452323/3072      148       5              note  Eighth note triplet  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           67           G5                           G                  None               None                                           None            None                 None                None                     None                                               -6                                                 -3                                      0                                  -1            dom7  67616761605857xxxxxxxxxxxxxxxxxxxxxxxx60575348...  1/12xxxxx1/8xxxxxx1/16xxxxx1/16xxxxx1/8xxxxxx1...  0xxxxxxxx1/8xxxxxx3/16xxxxx1/4xxxxxx3/8xxxxxx1...  -6x+6x-6x-1x-2x-1x+3x-3x-4x-5x+2x+3x+2x-2x+2x-...
# 1526     C dom7                                    1/8  Piano Solo Jazz (Treble)              452707/3072      148       5              note          Eighth note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           61          Db5                          Db                  None               None                                           None            None                 None                None                     None                                                6                                                  6                                      0                                  -1            dom7  616761605857xxxxxxxxxxxxxxxxxxxxxxxx6057534850...  1/8xxxxxx1/16xxxxx1/16xxxxx1/8xxxxxx1/8xxxxxx1...  0xxxxxxxx1/16xxxxx1/8xxxxxx1/4xxxxxx3/8xxxxxx5...  +6x-6x-1x-2x-1x+3x-3x-4x-5x+2x+3x+2x-2x+2x-2x-...
# 1527     C dom7                                   1/16  Piano Solo Jazz (Treble)              452899/3072      148       5              note       Sixteenth note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           67           G5                           G                  None               None                                           None            None                 None                None                     None                                               -6                                                 -6                                      0                                  -1            dom7  6761605857xxxxxxxxxxxxxxxxxxxxxxxx605753485053...  1/16xxxxx1/16xxxxx1/8xxxxxx1/8xxxxxx1/4xxxxxx1...  0xxxxxxxx1/16xxxxx3/16xxxxx5/16xxxxx9/16xxxxx1...  -6x-1x-2x-1x+3x-3x-4x-5x+2x+3x+2x-2x+2x-2x-1x-...
# 1528     C dom7                                   1/16  Piano Solo Jazz (Treble)              453091/3072      148       5              note       Sixteenth note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           61          Db5                          Db                  None               None                                           None            None                 None                None                     None                                               -1                                                  6                                      0                                  -1            dom7  61605857xxxxxxxxxxxxxxxxxxxxxxxx60575348505355...  1/16xxxxx1/8xxxxxx1/8xxxxxx1/4xxxxxx1/4xxxxxx1...  0xxxxxxxx1/8xxxxxx1/4xxxxxx1/2xxxxxx3/4xxxxxx5...  -1x-2x-1x+3x-3x-4x-5x+2x+3x+2x-2x+2x-2x-1x-2x+...
# 1529     C dom7                                      1    Jazz Harmony Bass Note                    295/2      148       3              note           Whole note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           36           C3                           C                  None               None                                           None            None                 None                None                     None                                               -7                                                 -5                                      0                                  -1            dom7       36292827263131343433262635283333313129293131  1xxxxxxxx1xxxxxxxx1xxxxxxxx1xxxxxxxx1xxxxxxxx1...  0xxxxxxxx1xxxxxxxx2xxxxxxxx3xxxxxxxx4xxxxxxxx5...  -7x-1x-1x-1x+5x+0x+3x+0x-1x-7x+0x+9x-7x+5x+0x-...
# 1530     C dom7                                    1/8  Piano Solo Jazz (Treble)              453475/3072      148       5              note          Eighth note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           60           C5                           C                  None               None                                           None            None                 None                None                     None                                               -2                                                  1                                      0                                  -1            dom7  605857xxxxxxxxxxxxxxxxxxxxxxxx6057534850535553...  1/8xxxxxx1/8xxxxxx1/4xxxxxx1/4xxxxxx1/2xxxxxx1...  0xxxxxxxx1/8xxxxxx3/8xxxxxx5/8xxxxxx9/8xxxxxx1...  -2x-1x+3x-3x-4x-5x+2x+3x+2x-2x+2x-2x-1x-2x+2x-...
# 1531     C dom7                                    1/8  Piano Solo Jazz (Treble)              453859/3072      148       4              note          Eighth note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           58          Bb4                          Bb                  None               None                                           None            None                 None                None                     None                                               -1                                                  2                                      0                                  -1            dom7  5857xxxxxxxxxxxxxxxxxxxxxxxx605753485053555355...  1/8xxxxxx1/4xxxxxx1/4xxxxxx1/2xxxxxx1xxxxxxxx1...  0xxxxxxxx1/4xxxxxx1/2xxxxxx1xxxxxxxx2xxxxxxxx3...  -1x+3x-3x-4x-5x+2x+3x+2x-2x+2x-2x-1x-2x+2x-2x-...
# 1532     F maj7                                    1/4  Piano Solo Jazz (Treble)              454627/3072      149       4              note         Quarter note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           57           A4                           A                  None               None                                           None            None                 None                None                     None                                              NaN                                                  1                                      5                                  -1            maj7  57xxxxxxxxxxxxxxxxxxxxxxxx60575348505355535553...  1/4xxxxxx1/4xxxxxx1/2xxxxxx1xxxxxxxx1xxxxxxxx1...  0xxxxxxxx1/4xxxxxx3/4xxxxxx7/4xxxxxx11/4xxxxx1...  +3x-3x-4x-5x+2x+3x+2x-2x+2x-2x-1x-2x+2x-2x-2x-...
# 1533     F maj7                                    1/4  Piano Solo Jazz (Treble)              455395/3072      149     NaN              rest         Quarter note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168          NaN         None                        None                  None               None                                           None            None                 None                None                     None                                              NaN                                                NaN                                      5                                  -1            maj7  xxxxxxxxxxxxxxxxxxxxxxxx6057534850535553555352...  1/4xxxxxx1/2xxxxxx1xxxxxxxx1xxxxxxxx1xxxxxxxx1...  0xxxxxxxx1/2xxxxxx3/2xxxxxx5/2xxxxxx7/2xxxxxx9...  -3x-4x-5x+2x+3x+2x-2x+2x-2x-1x-2x+2x-2x-2x-1x+...
# 1534     F maj7                                      1    Jazz Harmony Bass Note                    297/2      149       2              note           Whole note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           29           F2                           F                  None               None                                           None            None                 None                None                     None                                               -1                                                  7                                      5                                  -1            maj7         292827263131343433262635283333313129293131  1xxxxxxxx1xxxxxxxx1xxxxxxxx1xxxxxxxx1xxxxxxxx1...  0xxxxxxxx1xxxxxxxx2xxxxxxxx3xxxxxxxx4xxxxxxxx5...  -1x-1x-1x+5x+0x+3x+0x-1x-7x+0x+9x-7x+5x+0x-2x+...
# 1535     F maj7                                    1/2  Piano Solo Jazz (Treble)              456931/3072      149     NaN              rest            Half note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168          NaN         None                        None                  None               None                                           None            None                 None                None                     None                                              NaN                                                NaN                                      5                                  -1            maj7  xxxxxxxxxxxxxxxxxxxxxx605753485053555355535250...  1/2xxxxxx1xxxxxxxx1xxxxxxxx1xxxxxxxx1xxxxxxxx1...  0xxxxxxxx1xxxxxxxx2xxxxxxxx3xxxxxxxx4xxxxxxxx5...  -3x-4x-5x+2x+3x+2x-2x+2x-2x-1x-2x+2x-2x-2x-1x+...
# 1536     E dom7                                      1    Jazz Harmony Bass Note                    299/2      150       2              note           Whole note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           28           E2                           E                  None               None                                           None            None                 None                None                     None                                               -1                                                  1                                      4                                  -1            dom7           2827263131343433262635283333313129293131  1xxxxxxxx1xxxxxxxx1xxxxxxxx1xxxxxxxx1xxxxxxxx1...  0xxxxxxxx1xxxxxxxx2xxxxxxxx3xxxxxxxx4xxxxxxxx5...  -1x-1x+5x+0x+3x+0x-1x-7x+0x+9x-7x+5x+0x-2x+0x-...
# 1537     E dom7                                      1  Piano Solo Jazz (Treble)              460003/3072      150     NaN              rest           Whole note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168          NaN         None                        None                  None               None                                           None            None                 None                None                     None                                              NaN                                                NaN                                      4                                  -1            dom7  xxxxxxxxxxxxxxxxxxxx60575348505355535553525052...  1xxxxxxxx1xxxxxxxx1xxxxxxxx1xxxxxxxx1xxxxxxxx1...  0xxxxxxxx1xxxxxxxx2xxxxxxxx3xxxxxxxx4xxxxxxxx5...  -3x-4x-5x+2x+3x+2x-2x+2x-2x-1x-2x+2x-2x-2x-1x+...
# 1538    Eb dom7                                      1    Jazz Harmony Bass Note                    301/2      151       2              note           Whole note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           27          Eb2                          Eb                  None               None                                           None            None                 None                None                     None                                               -1                                                  1                                      3                                  -1            dom7             27263131343433262635283333313129293131  1xxxxxxxx1xxxxxxxx1xxxxxxxx1xxxxxxxx1xxxxxxxx1...  0xxxxxxxx1xxxxxxxx2xxxxxxxx3xxxxxxxx4xxxxxxxx5...  -1x+5x+0x+3x+0x-1x-7x+0x+9x-7x+5x+0x-2x+0x-2x+...
# 1539    Eb dom7                                      1  Piano Solo Jazz (Treble)              463075/3072      151     NaN              rest           Whole note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168          NaN         None                        None                  None               None                                           None            None                 None                None                     None                                              NaN                                                NaN                                      3                                  -1            dom7  xxxxxxxxxxxxxxxxxx6057534850535553555352505250...  1xxxxxxxx1xxxxxxxx1xxxxxxxx1xxxxxxxx1xxxxxxxx1...  0xxxxxxxx1xxxxxxxx2xxxxxxxx3xxxxxxxx4xxxxxxxx5...  -3x-4x-5x+2x+3x+2x-2x+2x-2x-1x-2x+2x-2x-2x-1x+...
# 1540     D dom7                                      1    Jazz Harmony Bass Note                    303/2      152       2              note           Whole note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           26           D2                           D                  None               None                                           None            None                 None                None                     None                                                5                                                  1                                      2                                  -1            dom7               263131343433262635283333313129293131  1xxxxxxxx1xxxxxxxx1xxxxxxxx1xxxxxxxx1xxxxxxxx1...  0xxxxxxxx1xxxxxxxx2xxxxxxxx3xxxxxxxx4xxxxxxxx5...  +5x+0x+3x+0x-1x-7x+0x+9x-7x+5x+0x-2x+0x-2x+0x+...
# 1541     D dom7                                      1  Piano Solo Jazz (Treble)              466147/3072      152     NaN              rest           Whole note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168          NaN         None                        None                  None               None                                           None            None                 None                None                     None                                              NaN                                                NaN                                      2                                  -1            dom7  xxxxxxxxxxxxxxxx605753485053555355535250525048...  1xxxxxxxx1xxxxxxxx1xxxxxxxx1xxxxxxxx1xxxxxxxx1...  0xxxxxxxx1xxxxxxxx2xxxxxxxx3xxxxxxxx4xxxxxxxx1...  -3x-4x-5x+2x+3x+2x-2x+2x-2x-1x-2x+2x-2x-2x-1x+...
# 1542     G min7                                      1    Jazz Harmony Bass Note                    305/2      153       2              note           Whole note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           31           G2                           G                  None               None                                           None            None                 None                None                     None                                                0                                                 -5                                      7                                  -1            min7                 3131343433262635283333313129293131  1xxxxxxxx1xxxxxxxx1xxxxxxxx1xxxxxxxx1xxxxxxxx1...  0xxxxxxxx1xxxxxxxx2xxxxxxxx3xxxxxxxx4xxxxxxxx9...   +0x+3x+0x-1x-7x+0x+9x-7x+5x+0x-2x+0x-2x+0x+2x+0x
# 1543     G min7                                      1  Piano Solo Jazz (Treble)              469219/3072      153     NaN              rest           Whole note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168          NaN         None                        None                  None               None                                           None            None                 None                None                     None                                              NaN                                                NaN                                      7                                  -1            min7  xxxxxxxxxxxxxx60575348505355535553525052504847...  1xxxxxxxx1xxxxxxxx1xxxxxxxx1xxxxxxxx1/4xxxxxx1...  0xxxxxxxx1xxxxxxxx2xxxxxxxx3xxxxxxxx13/4xxxxx7...  -3x-4x-5x+2x+3x+2x-2x+2x-2x-1x-2x+2x-2x-2x-1x+...
# ...         ...                                    ...                       ...                      ...      ...     ...               ...                  ...            ...            ...   ...                     ...                  ...                  ...                     ...          ...          ...                         ...                   ...                ...                                            ...             ...                  ...                 ...                      ...                                              ...                                                ...                                    ...                                 ...             ...                                                ...                                                ...                                                ...                                                ...
# 1584     E dom7                                    1/8  Piano Solo Jazz (Treble)              490339/3072      160       4              note          Eighth note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           52           E4                           E                  None               None                                           None            None                 None                None                     None                                               -2                                                  4                                      4                                  -1            dom7       52504852555956536260585054575652514948xxxxxx  1/8xxxxxx1/8xxxxxx1/8xxxxxx1/8xxxxxx1/8xxxxxx1...  0xxxxxxxx1/8xxxxxx1/4xxxxxx3/8xxxxxx1/2xxxxxx5...  -2x-2x+4x+3x+4x-3x-3x+9x-2x-2x-8x+4x+3x-1x-4x-...
# 1585     E dom7                                    1/8  Piano Solo Jazz (Treble)              490723/3072      160       4              note          Eighth note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           50           D4                           D                  None               None                                           None            None                 None                None                     None                                               -2                                                  2                                      4                                  -1            dom7         504852555956536260585054575652514948xxxxxx  1/8xxxxxx1/8xxxxxx1/8xxxxxx1/8xxxxxx1/8xxxxxx1...  0xxxxxxxx1/8xxxxxx1/4xxxxxx3/8xxxxxx1/2xxxxxx5...  -2x+4x+3x+4x-3x-3x+9x-2x-2x-8x+4x+3x-1x-4x-1x-...
# 1586     D dom7                                    1/8  Piano Solo Jazz (Treble)              491107/3072      161       4              note          Eighth note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           48           C4                           C                  None               None                                           None            None                 None                None                     None                                                4                                                  2                                      2                                  -1            dom7           4852555956536260585054575652514948xxxxxx  1/8xxxxxx1/8xxxxxx1/8xxxxxx1/8xxxxxx1/8xxxxxx1...  0xxxxxxxx1/8xxxxxx1/4xxxxxx3/8xxxxxx1/2xxxxxx5...   +4x+3x+4x-3x-3x+9x-2x-2x-8x+4x+3x-1x-4x-1x-2x-1x
# 1587     D dom7                                    1/8  Piano Solo Jazz (Treble)              491491/3072      161       4              note          Eighth note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           52           E4                           E                  None               None                                           None            None                 None                None                     None                                                3                                                 -4                                      2                                  -1            dom7             52555956536260585054575652514948xxxxxx  1/8xxxxxx1/8xxxxxx1/8xxxxxx1/8xxxxxx1/8xxxxxx1...  0xxxxxxxx1/8xxxxxx1/4xxxxxx3/8xxxxxx1/2xxxxxx5...      +3x+4x-3x-3x+9x-2x-2x-8x+4x+3x-1x-4x-1x-2x-1x
# 1588     A min7                                    1/2    Jazz Harmony Bass Note                      160      161       2              note            Half note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           33           A2                           A                  None               None                                           None            None                 None                None                     None                                                0                                                 -5                                      9                                  -1            min7                                   3333313129293131  1/2xxxxxx1/2xxxxxx1/2xxxxxx1/2xxxxxx1/2xxxxxx1...  0xxxxxxxx1/2xxxxxx1xxxxxxxx3/2xxxxxx2xxxxxxxx5...                              +0x-2x+0x-2x+0x+2x+0x
# 1589     D dom7                                    1/8  Piano Solo Jazz (Treble)              491875/3072      161       4              note          Eighth note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           55           G4                           G                  None               None                                           None            None                 None                None                     None                                                4                                                 -3                                      2                                  -1            dom7               555956536260585054575652514948xxxxxx  1/8xxxxxx1/8xxxxxx1/8xxxxxx1/8xxxxxx1/8xxxxxx1...  0xxxxxxxx1/8xxxxxx1/4xxxxxx3/8xxxxxx1/2xxxxxx5...         +4x-3x-3x+9x-2x-2x-8x+4x+3x-1x-4x-1x-2x-1x
# 1590     D dom7                                    1/8  Piano Solo Jazz (Treble)              492259/3072      161       4              note          Eighth note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           59           B4                           B                  None               None                                           None            None                 None                None                     None                                               -3                                                 -4                                      2                                  -1            dom7                 5956536260585054575652514948xxxxxx  1/8xxxxxx1/8xxxxxx1/8xxxxxx1/8xxxxxx1/8xxxxxx1...  0xxxxxxxx1/8xxxxxx1/4xxxxxx3/8xxxxxx1/2xxxxxx5...            -3x-3x+9x-2x-2x-8x+4x+3x-1x-4x-1x-2x-1x
# 1591     D dom7                                    1/8  Piano Solo Jazz (Treble)              492643/3072      161       4              note          Eighth note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           56          Ab4                          Ab                  None               None                                           None            None                 None                None                     None                                               -3                                                  3                                      2                                  -1            dom7                   56536260585054575652514948xxxxxx  1/8xxxxxx1/8xxxxxx1/8xxxxxx1/8xxxxxx1/8xxxxxx1...  0xxxxxxxx1/8xxxxxx1/4xxxxxx3/8xxxxxx1/2xxxxxx5...               -3x+9x-2x-2x-8x+4x+3x-1x-4x-1x-2x-1x
# 1592     D dom7                                    1/8  Piano Solo Jazz (Treble)              493027/3072      161       4              note          Eighth note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           53           F4                           F                  None               None                                           None            None                 None                None                     None                                                9                                                  3                                      2                                  -1            dom7                     536260585054575652514948xxxxxx  1/8xxxxxx1/8xxxxxx1/8xxxxxx1/8xxxxxx1/8xxxxxx1...  0xxxxxxxx1/8xxxxxx1/4xxxxxx3/8xxxxxx1/2xxxxxx5...                  +9x-2x-2x-8x+4x+3x-1x-4x-1x-2x-1x
# 1593     D dom7                                    1/2    Jazz Harmony Bass Note                    321/2      161       2              note            Half note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           33           A2                           A                  None               None                                           None            None                 None                None                     None                                               -2                                                  0                                      2                                  -1            dom7                                     33313129293131  1/2xxxxxx1/2xxxxxx1/2xxxxxx1/2xxxxxx1/2xxxxxx1...  0xxxxxxxx1/2xxxxxx1xxxxxxxx3/2xxxxxx2xxxxxxxx5...                                 -2x+0x-2x+0x+2x+0x
# 1594     D dom7                                    1/8  Piano Solo Jazz (Treble)              493411/3072      161       5              note          Eighth note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           62           D5                           D                  None               None                                           None            None                 None                None                     None                                               -2                                                 -9                                      2                                  -1            dom7                       6260585054575652514948xxxxxx  1/8xxxxxx1/8xxxxxx1/8xxxxxx1/8xxxxxx1/8xxxxxx1...  0xxxxxxxx1/8xxxxxx1/4xxxxxx3/8xxxxxx1/2xxxxxx5...                     -2x-2x-8x+4x+3x-1x-4x-1x-2x-1x
# 1595     D dom7                                    1/8  Piano Solo Jazz (Treble)              493795/3072      161       5              note          Eighth note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           60           C5                           C                  None               None                                           None            None                 None                None                     None                                               -2                                                  2                                      2                                  -1            dom7                         60585054575652514948xxxxxx  1/8xxxxxx1/8xxxxxx1/8xxxxxx1/8xxxxxx1/8xxxxxx1...  0xxxxxxxx1/8xxxxxx1/4xxxxxx3/8xxxxxx1/2xxxxxx5...                        -2x-8x+4x+3x-1x-4x-1x-2x-1x
# 1596     C dom7                                    1/8  Piano Solo Jazz (Treble)              494179/3072      162       4              note          Eighth note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           58          Bb4                          Bb                  None               None                                           None            None                 None                None                     None                                               -8                                                  2                                      0                                  -1            dom7                           585054575652514948xxxxxx  1/8xxxxxx1/8xxxxxx1/8xxxxxx1/8xxxxxx1/8xxxxxx1...  0xxxxxxxx1/8xxxxxx1/4xxxxxx3/8xxxxxx1/2xxxxxx5...                           -8x+4x+3x-1x-4x-1x-2x-1x
# 1597     C dom7                                    1/8  Piano Solo Jazz (Treble)              494563/3072      162       4              note          Eighth note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           50           D4                           D                  None               None                                           None            None                 None                None                     None                                                4                                                  8                                      0                                  -1            dom7                             5054575652514948xxxxxx  1/8xxxxxx1/8xxxxxx1/8xxxxxx1/8xxxxxx1/8xxxxxx1...  0xxxxxxxx1/8xxxxxx1/4xxxxxx3/8xxxxxx1/2xxxxxx5...                              +4x+3x-1x-4x-1x-2x-1x
# 1598     G min7                                    1/2    Jazz Harmony Bass Note                      161      162       2              note            Half note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           31           G2                           G                  None               None                                           None            None                 None                None                     None                                                0                                                  2                                      7                                  -1            min7                                       313129293131  1/2xxxxxx1/2xxxxxx1/2xxxxxx1/2xxxxxx1/2xxxxxx1...  0xxxxxxxx1/2xxxxxx1xxxxxxxx3/2xxxxxx2xxxxxxxx5...                                    +0x-2x+0x+2x+0x
# 1599     C dom7                                    1/8  Piano Solo Jazz (Treble)              494947/3072      162       4              note          Eighth note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           54          Gb4                          Gb                  None               None                                           None            None                 None                None                     None                                                3                                                 -4                                      0                                  -1            dom7                               54575652514948xxxxxx  1/8xxxxxx1/8xxxxxx1/8xxxxxx1/8xxxxxx1/8xxxxxx1...  0xxxxxxxx1/8xxxxxx1/4xxxxxx3/8xxxxxx1/2xxxxxx5...                                 +3x-1x-4x-1x-2x-1x
# 1600     C dom7                                    1/8  Piano Solo Jazz (Treble)              495331/3072      162       4              note          Eighth note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           57           A4                           A                  None               None                                           None            None                 None                None                     None                                               -1                                                 -3                                      0                                  -1            dom7                                 575652514948xxxxxx  1/8xxxxxx1/8xxxxxx1/8xxxxxx1/8xxxxxx1/8xxxxxx1...  0xxxxxxxx1/8xxxxxx1/4xxxxxx3/8xxxxxx1/2xxxxxx3...                                    -1x-4x-1x-2x-1x
# 1601     C dom7                                    1/8  Piano Solo Jazz (Treble)              495715/3072      162       4              note          Eighth note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           56          Ab4                          Ab                  None               None                                           None            None                 None                None                     None                                               -4                                                  1                                      0                                  -1            dom7                                   5652514948xxxxxx  1/8xxxxxx1/8xxxxxx1/8xxxxxx1/8xxxxxx1/4xxxxxx1...  0xxxxxxxx1/8xxxxxx1/4xxxxxx3/8xxxxxx5/8xxxxxx7...                                       -4x-1x-2x-1x
# 1602     C dom7                                    1/8  Piano Solo Jazz (Treble)              496099/3072      162       4              note          Eighth note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           52           E4                           E                  None               None                                           None            None                 None                None                     None                                               -1                                                  4                                      0                                  -1            dom7                                     52514948xxxxxx  1/8xxxxxx1/8xxxxxx1/8xxxxxx1/4xxxxxx1/4xxxxxx1...  0xxxxxxxx1/8xxxxxx1/4xxxxxx1/2xxxxxx3/4xxxxxx5...                                          -1x-2x-1x
# 1603     C dom7                                    1/2    Jazz Harmony Bass Note                    323/2      162       2              note            Half note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           31           G2                           G                  None               None                                           None            None                 None                None                     None                                               -2                                                  0                                      0                                  -1            dom7                                         3129293131      1/2xxxxxx1/2xxxxxx1/2xxxxxx1/2xxxxxx1/2xxxxxx      0xxxxxxxx1/2xxxxxx1xxxxxxxx3/2xxxxxx2xxxxxxxx                                       -2x+0x+2x+0x
# 1604     C dom7                                    1/8  Piano Solo Jazz (Treble)              496483/3072      162       4              note          Eighth note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           51          Eb4                          Eb                  None               None                                           None            None                 None                None                     None                                               -2                                                  1                                      0                                  -1            dom7                                       514948xxxxxx      1/8xxxxxx1/8xxxxxx1/4xxxxxx1/4xxxxxx1/2xxxxxx  0xxxxxxxx1/8xxxxxx3/8xxxxxx5/8xxxxxx9/8xxxxxx1...                                             -2x-1x
# 1605     C dom7                                    1/8  Piano Solo Jazz (Treble)              496867/3072      162       4              note          Eighth note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           49          Db4                          Db                  None               None                                           None            None                 None                None                     None                                               -1                                                  2                                      0                                  -1            dom7                                         4948xxxxxx               1/8xxxxxx1/4xxxxxx1/4xxxxxx1/2xxxxxx      0xxxxxxxx1/4xxxxxx1/2xxxxxx1xxxxxxxx2xxxxxxxx                                                -1x
# 1606     D dom7                                    1/4  Piano Solo Jazz (Treble)              497635/3072      163       4              note         Quarter note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           48           C4                           C                  None               None                                           None            None                 None                None                     None                                              NaN                                                  1                                      2                                  -1            dom7                                           48xxxxxx                        1/4xxxxxx1/4xxxxxx1/2xxxxxx               0xxxxxxxx1/4xxxxxx3/4xxxxxx7/4xxxxxx
# 1607     F maj7                                    1/2    Jazz Harmony Bass Note                      162      163       2              note            Half note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           29           F2                           F                  None               None                                           None            None                 None                None                     None                                                0                                                  2                                      5                                  -1            maj7                                           29293131               1/2xxxxxx1/2xxxxxx1/2xxxxxx1/2xxxxxx               0xxxxxxxx1/2xxxxxx1xxxxxxxx3/2xxxxxx                                          +0x+2x+0x
# 1608     D dom7                                    1/4  Piano Solo Jazz (Treble)              498403/3072      163     NaN              rest         Quarter note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168          NaN         None                        None                  None               None                                           None            None                 None                None                     None                                              NaN                                                NaN                                      2                                  -1            dom7                                             xxxxxx                                 1/4xxxxxx1/2xxxxxx                        0xxxxxxxx1/2xxxxxx3/2xxxxxx
# 1609     D dom7                                    1/2    Jazz Harmony Bass Note                    325/2      163       2              note            Half note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           29           F2                           F                  None               None                                           None            None                 None                None                     None                                                2                                                  0                                      2                                  -1            dom7                                             293131                        1/2xxxxxx1/2xxxxxx1/2xxxxxx                        0xxxxxxxx1/2xxxxxx1xxxxxxxx                                             +2x+0x
# 1610     D dom7                                    1/2  Piano Solo Jazz (Treble)              499939/3072      163     NaN              rest            Half note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168          NaN         None                        None                  None               None                                           None            None                 None                None                     None                                              NaN                                                NaN                                      2                                  -1            dom7                                               xxxx                                          1/2xxxxxx                                 0xxxxxxxx1xxxxxxxx
# 1611     G min7                                    1/2    Jazz Harmony Bass Note                      163      164       2              note            Half note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           31           G2                           G                  None               None                                           None            None                 None                None                     None                                                0                                                 -2                                      7                                  -1            min7                                               3131                                 1/2xxxxxx1/2xxxxxx                                 0xxxxxxxx1/2xxxxxx                                                +0x
# 1612     C dom7                                    1/2    Jazz Harmony Bass Note                    327/2      164       2              note            Half note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168           31           G2                           G                  None               None                                           None            None                 None                None                     None                                              NaN                                                  0                                      0                                  -1            dom7                                                 31                                          1/2xxxxxx                                          0xxxxxxxx
# 1613     C dom7                                    NaN  Piano Solo Jazz (Treble)              503011/3072      164     NaN              rest           Whole note  Keith Jarrett  Henry Mancini  Jazz  Days Of Wine And Roses                 1962                 1994                     168          NaN         None                        None                  None               None                                           None            None                 None                None                     None                                              NaN                                                NaN                                      0                                  -1            dom7                                                 xx                                                                                             0xxxxxxxx
#
# [100 rows x 34 columns]

# %%
#df['Duration as a fraction of a whole note'].value_counts()

# %%
#df.dtypes

# %%
df.to_json(orient='records', path_or_buf='FinalDataSet/JSONFilesLoadedIntoDataBase/fullcorpus.json')
