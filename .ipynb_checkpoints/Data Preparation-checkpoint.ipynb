# %% [markdown]
# <h1>Data Preparation</h1>

# %%
import music21 as mu
import numpy as np
import pandas as pd
# %pylab inline
import math
from IPython.core.display import HTML
from IPython.core.display import Image
# %load_ext music21.ipython21.ipExtension
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
globalPhraseCount = 0

# %%
#mu_stella = mu.converter.parse('xml_files/stella_by_starlight.xml')
#mu_autumn = mu.converter.parse('xml_files/autumn_leaves_v2.xml')
#mu_if_i_were = mu.converter.parse('xml_files/if_i_were_a_bell.xml')
#mu_groovin = mu.converter.parse('xml_files/groovin_high.xml')
#mu_all_the_things = mu.converter.parse('xml_files/all_the_things_you_are.xml')

# %%
#import files with music21 for visual data validation


#prep data functions
def prep_data_from_xml(xml_file=''):
    global globalPhraseCount
    globalPhraseCount = 0
    notes = mu.converter.parse(xml_file)
    i = 0
    parts_list = []
    while i < len(notes.parts):
        parts_list.append(notes.parts[i])
        i = i + 1


    notes_list = []
    part_name_list = []
    for part in parts_list:
        a = part.flat.getElementsByClass(mu.note.Note)
        b = part.id
        notes_list.append(a)
        part_name_list.append(b)


#create lists
    mel_notes = []
    mel_pos = []
    mel_duration = []

    solo_notes = []
    solo_pos = []
    solo_duration = []

    root_notes = []
    root_pos = []
    root_duration = []


    third_pos = []
    third_notes = []
    third_duration = []
    
    fifth_notes = []
    fifth_pos = []
    fifth_duration = []

    seventh_notes = []
    seventh_pos = []
    seventh_duration = []

#add notes from parts into lists
    for note in notes_list[0]:
        mel_pos.append(note.offset)
        mel_notes.append(note.midi)
        mel_duration.append(note.duration.quarterLength)
    
    for note in notes_list[1]:
        solo_pos.append(note.offset)
        solo_notes.append(note.midi)
        solo_duration.append(note.duration.quarterLength)
        
    for note in notes_list[5]:
        root_pos.append(note.offset)
        root_notes.append(note.midi)
        root_duration.append(note.duration.quarterLength)   
    
    for note in notes_list[4]:
        third_pos.append(note.offset)
        third_notes.append(note.midi)
        third_duration.append(note.duration.quarterLength)
        
    for note in notes_list[3]:
        fifth_pos.append(note.offset)
        fifth_notes.append(note.midi)
        fifth_duration.append(note.duration.quarterLength)
    
    for note in notes_list[2]:
        seventh_pos.append(note.offset)
        seventh_notes.append(note.midi)
        seventh_duration.append(note.duration.quarterLength)
        

# Create Data Frames for each part showing location and frequency</p>



    solo_df = pd.DataFrame({'part':0,
                   'location': solo_pos,
                   'noteFrequency': solo_notes,
                   'noteDuration' : solo_duration,
                   })

    root_df = pd.DataFrame({'part':1,
                  'location':root_pos,
                  'noteFrequency': root_notes,
                  'noteDuration' : root_duration,
                  })
    third_df = pd.DataFrame({'part':2,
                  'location':third_pos,
                  'noteFrequency': third_notes,
                  'noteDuration' : third_duration,
                  })

    fifth_df = pd.DataFrame({'part': 3,
                         'location':fifth_pos,
                         'noteFrequency':fifth_notes,
                         'noteDuration':fifth_duration,
                         })
    seventh_df = pd.DataFrame({'part': 4,
                           'location':seventh_pos,
                           'noteFrequency':seventh_notes,
                           'noteDuration' : seventh_duration,
                           })



    solo_root_df = solo_df.append(root_df)
    solo_root_third_df = solo_root_df.append(third_df)
    solo_root_third_fifth_df = solo_root_third_df.append(fifth_df)
    solo_root_third_fifth_seventh_df = solo_root_third_fifth_df.append(seventh_df)
    all_note_events = solo_root_third_fifth_seventh_df
    all_note_events = all_note_events.sort('location')


    def create_root_col(note_event):
        if note_event['part'] == 1:
            return note_event['noteFrequency']
        else:
            return None

    def create_third_col(note_event):
        if note_event['part'] == 2:
            return note_event['noteFrequency']
        else:
            return None
    
    def create_fifth_col(note_event):
        if note_event['part'] == 3:
            return note_event['noteFrequency']
        else:
            return None
    
    def create_seventh_col(note_event):
        if note_event['part'] == 4:
            return note_event['noteFrequency']
        else:
            return None
    
    

    all_note_events['root'] = all_note_events.apply(create_root_col, axis=1)
    all_note_events['third'] = all_note_events.apply(create_third_col, axis=1)
    all_note_events['fifth'] = all_note_events.apply(create_fifth_col, axis=1)
    all_note_events['seventh'] = all_note_events.apply(create_seventh_col, axis=1)


    all_note_events = all_note_events.sort(['location', 'root'], ascending=[True, False])
    all_note_events['root'] = all_note_events['root'].fillna(method="pad")
    
    all_note_events = all_note_events.sort(['location', 'third'], ascending=[True, False])
    all_note_events['third'] = all_note_events['third'].fillna(method='pad')
    
    all_note_events = all_note_events.sort(['location', 'fifth'], ascending=[True, False])
    all_note_events['fifth'] = all_note_events['fifth'].fillna(method='pad')

    all_note_events = all_note_events.sort(['location', 'seventh'], ascending=[True, False])
    all_note_events['seventh'] = all_note_events['seventh'].fillna(method='pad')
    all_note_events['locationInMeasure'] = (all_note_events['location'] + 4) / 4
    
    solo_note_events = all_note_events[all_note_events.part == 0]

    
    solo_note_events['previousNotePitchDistance'] = solo_note_events['noteFrequency'].shift(1)
    solo_note_events['previousNotePitchDistance'] = solo_note_events['previousNotePitchDistance'] - solo_note_events['noteFrequency']
    solo_note_events['nextNotePitchDistance'] = solo_note_events['noteFrequency'].shift(-1)
    solo_note_events['nextNotePitchDistance'] = solo_note_events['nextNotePitchDistance'] - solo_note_events['noteFrequency']
    solo_note_events['previousNoteDurationDistance'] = solo_note_events['location'].shift(1)
    solo_note_events['previousNoteDurationDistance'] = abs(solo_note_events['previousNoteDurationDistance'] - solo_note_events['location'])
    solo_note_events['nextNoteDurationDistance'] = solo_note_events['location'].shift(-1)
    solo_note_events['nextNoteDurationDistance'] = abs(solo_note_events['nextNoteDurationDistance'] - solo_note_events['location'])

    solo_note_events['endOfCurrentNoteDistanceToNextNote'] = abs(solo_note_events['nextNoteDurationDistance'] - solo_note_events['noteDuration'])


    
#each note belongs to scertain phrase  
    def phraseCounter(data_row):
        if data_row['endOfCurrentNoteDistanceToNextNote'] >= 0.5:
            return 'lastNoteOfPhrase'
        else: 
            return 'inPhrase'
        
    solo_note_events['phraseStatus'] = solo_note_events.apply(phraseCounter, axis=1)

    

    def incPhraseTwo(data_row):
        global globalPhraseCount
        x = globalPhraseCount
        if data_row['phraseStatus'] == 'lastNoteOfPhrase':
            globalPhraseCount = globalPhraseCount + 1
        return x
    
    
    solo_note_events['phrase'] = solo_note_events.apply(incPhraseTwo, axis=1)
            
####################################### FIND CHORD TYPE          
   
    
    def find_chord_type(row):
        if row['third'] - row['root'] == 4 and row['fifth'] - row['third'] == 3 and row['seventh'] - row['fifth'] == 3:
            return 'dominantSeventh'
        elif row['third'] - row['root'] == 4 and row['fifth'] - row['third'] == 3 and row['seventh'] - row['fifth'] == 4:
            return 'majorSeventh'
        elif row['third'] - row['root'] == 3 and row['fifth'] - row['third'] == 4 and row['seventh'] - row['fifth'] == 3:
            return 'minorSeventh'
        elif row['third'] - row['root'] == 3 and row['fifth'] - row['third'] == 3 and row['seventh'] - row['fifth'] == 4:
            return 'minorSeventhFlatFive'
        else:
            return 'notDetermined'

    solo_note_events['chordType'] = solo_note_events.apply(find_chord_type, axis=1)

    
####################################### DIST TO ROOT FUNCTION ##########    
    def calc_dist_note_root(data_row):
        x = (data_row['noteFrequency'] - data_row['root']) % 12
        return x
    
    
    solo_note_events['notePitchDistanceToRoot'] = solo_note_events.apply(calc_dist_note_root, axis=1)
    
########################## CURRENT MEASURE ######################    
    def calc_measure_floor(data_row):
        x = math.floor(data_row.locationInMeasure)
        return x
    
    solo_note_events['currentMeasure'] = solo_note_events.apply(calc_measure_floor, axis=1)

########################### API URL STRING ###########################
    
    
    def createUrlResourceString(data_row):
        url = 'http://api.musicdata.' + str(data_row['part']) + str(data_row['location'])
        return url
    
    solo_note_events['resourceUrl'] = solo_note_events.apply(createUrlResourceString, axis=1)
    
 
    
    return solo_note_events

# %%
####################### SMALL DATA SET VALIDATION AND TESTING ##########
testData = prep_data_from_xml('xml_files/testingData.xml')
testData['title'] = "Stella By Starlight"
testData['currentTempo'] = 120
testData['composerFirstName'] = 'Oscar'
testData['composerLastName'] = 'Hammerstein'
testData['performerFirstName'] = 'Keith'
testData['perfomerLastName'] = 'Jarrett'
testData['yearComposed'] = 1943
testData['yearPerformed'] = 1986
# Out:
# -c:174: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_index,col_indexer] = value instead
# -c:176: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_index,col_indexer] = value instead
# -c:178: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_index,col_indexer] = value instead
# -c:180: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_index,col_indexer] = value instead

# %%
display(HTML(testData[0:2].to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>location</th>
#       <th>noteDuration</th>
#       <th>noteFrequency</th>
#       <th>part</th>
#       <th>root</th>
#       <th>third</th>
#       <th>fifth</th>
#       <th>seventh</th>
#       <th>locationInMeasure</th>
#       <th>previousNotePitchDistance</th>
#       <th>nextNotePitchDistance</th>
#       <th>previousNoteDurationDistance</th>
#       <th>nextNoteDurationDistance</th>
#       <th>endOfCurrentNoteDistanceToNextNote</th>
#       <th>phraseStatus</th>
#       <th>phrase</th>
#       <th>chordType</th>
#       <th>notePitchDistanceToRoot</th>
#       <th>currentMeasure</th>
#       <th>resourceUrl</th>
#       <th>title</th>
#       <th>currentTempo</th>
#       <th>composerFirstName</th>
#       <th>composerLastName</th>
#       <th>performerFirstName</th>
#       <th>perfomerLastName</th>
#       <th>yearComposed</th>
# ...

# %% [markdown]
# <p>Using Real Data</p>

# %%
#parse all real data

# %%
stella_by_starlight_solo = prep_data_from_xml('xml_files/stella_by_starlight.xml')

# %%
autumn_leaves_solo = prep_data_from_xml('xml_files/autumn_leaves_v2.xml')

# %%
if_i_were_a_bell_solo = prep_data_from_xml('xml_files/if_i_were_a_bell.xml')

# %%
groovin_high_solo = prep_data_from_xml('xml_files/groovin_high.xml')

# %%
all_the_things_you_are_solo = prep_data_from_xml('xml_files/all_the_things_you_are.xml')

# %%
# add meta data to files
stella_by_starlight_solo['title'] = "Stella By Starlight"
stella_by_starlight_solo['currentTempo'] = 120
stella_by_starlight_solo['composerFirstName'] = 'Oscar'
stella_by_starlight_solo['composerLastName'] = 'Hammerstein'
stella_by_starlight_solo['performerFirstName'] = 'Keith'
stella_by_starlight_solo['perfomerLastName'] = 'Jarrett'
stella_by_starlight_solo['yearComposed'] = 1943
stella_by_starlight_solo['yearPerformed'] = 1986

autumn_leaves_solo['title'] = 'Autumn Leaves'
autumn_leaves_solo['currentTempo'] = 178
autumn_leaves_solo['composerFirstName'] = 'Oscar'
autumn_leaves_solo['composerLastName'] = 'Smith'
autumn_leaves_solo['performerFirstName'] = 'Keith'
autumn_leaves_solo['perfomerLastName'] = 'Jarrett'
autumn_leaves_solo['yearComposed'] = 1966
autumn_leaves_solo['yearPerformed'] = 1991

if_i_were_a_bell_solo['title'] = 'If I Were A Bell'
if_i_were_a_bell_solo['currentTempo'] = 55
if_i_were_a_bell_solo['composerFirstName'] = 'Oscar'
if_i_were_a_bell_solo['composerLastName'] = 'Jones'
if_i_were_a_bell_solo['performerFirstName'] = 'Keith'
if_i_were_a_bell_solo['perfomerLastName'] = 'Jarrett'
if_i_were_a_bell_solo['yearComposed'] = 1922
if_i_were_a_bell_solo['yearPerformed'] = 2003

groovin_high_solo['title'] = 'Groovin High'
groovin_high_solo['currentTempo'] = 155
groovin_high_solo['composerFirstName'] = 'Oscar'
groovin_high_solo['composerLastName'] = 'Joes'
groovin_high_solo['performerFirstName'] = 'Keith'
groovin_high_solo['perfomerLastName'] = 'Jarrett'
groovin_high_solo['yearComposed'] = 1944
groovin_high_solo['yearPerformed'] = 1988

all_the_things_you_are_solo['title'] = 'All The Things You Are'
all_the_things_you_are_solo['currentTempo'] = 160
all_the_things_you_are_solo['composerFirstName'] = 'Oscar'
all_the_things_you_are_solo['composerLastName'] = 'Hammerstein'
all_the_things_you_are_solo['performerFirstName'] = 'Keith'
all_the_things_you_are_solo['perfomerLastName'] = 'Jarrett'
all_the_things_you_are_solo['yearComposed'] = 1944
all_the_things_you_are_solo['yearPerformed'] = 2003

# %%
#concatenate all datasets into one set
data_set = pd.concat([all_the_things_you_are_solo, stella_by_starlight_solo, groovin_high_solo, autumn_leaves_solo, if_i_were_a_bell_solo], ignore_index=True)

# %%
display(HTML(data_set[0:2].to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>location</th>
#       <th>noteDuration</th>
#       <th>noteFrequency</th>
#       <th>part</th>
#       <th>root</th>
#       <th>third</th>
#       <th>fifth</th>
#       <th>seventh</th>
#       <th>locationInMeasure</th>
#       <th>previousNotePitchDistance</th>
#       <th>nextNotePitchDistance</th>
#       <th>previousNoteDurationDistance</th>
#       <th>nextNoteDurationDistance</th>
#       <th>endOfCurrentNoteDistanceToNextNote</th>
#       <th>phraseStatus</th>
#       <th>phrase</th>
#       <th>chordType</th>
#       <th>notePitchDistanceToRoot</th>
#       <th>currentMeasure</th>
#       <th>resourceUrl</th>
#       <th>title</th>
#       <th>currentTempo</th>
#       <th>composerFirstName</th>
#       <th>composerLastName</th>
#       <th>performerFirstName</th>
#       <th>perfomerLastName</th>
#       <th>yearComposed</th>
# ...

# %%
#data_set.to_json(orient='records', path_or_buf='music_data.json')
#save dataset to file for next section
#data_set.to_pickle('data_set_as_pk.pkl')
