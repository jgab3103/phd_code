# %%
import pandas as pd
from IPython.core.display import HTML
from IPython.core.display import Image 
# %load_ext music21.ipython21.ipExtension
import numpy as np
import music21 as mu
import pymongo
# %pylab inline
from pymongo import MongoClient
from bs4 import BeautifulSoup
import re
import pydash as py_
pd.set_option('display.mpl_style', 'default')
plt.rcParams['figure.figsize'] = (15, 5)
import math
import music21 as mu
from functools import partial

# This is necessary to show lots of columns in pandas 0.12. 
# Not necessary in pandas 0.13.
pd.set_option('display.width', 5000) 
pd.set_option('display.max_columns', 60)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
muAllTheThingsYouAre = mu.converter.parse('FinalDataSet/XMLFiles/JazzSolos/KeithJarrettAllTheThingsYouAre.xml')
muAutumnLeaves = mu.converter.parse('FinalDataSet/XMLFiles/JazzSolos/KeithJarrettAutumnLeaves.xml')
muDaysOfWineAndRoses = mu.converter.parse('FinalDataSet/XMLFiles/JazzSolos/KeithJarrettDaysOfWineAndRoses.xml')
muGroovingHigh = mu.converter.parse('FinalDataSet/XMLFiles/JazzSolos/KeithJarrettGroovinHigh.xml')
muIfIWereABell = mu.converter.parse('FinalDataSet/XMLFiles/JazzSolos/KeithJarrettIfIWereABell.xml')
muSomedayMyPrinceWillCome = mu.converter.parse('FinalDataSet/XMLFiles/JazzSolos/KeithJarrettSomedayMyPrinceWillCome.xml')
muStellaByStarlight = mu.converter.parse('FinalDataSet/XMLFiles/JazzSolos/KeithJarrettStellaByStarlight.xml')

# %% [markdown]
# <h2>Data Preparation</h2>

# %%
df = pd.read_pickle('data_set_as_pk.pkl')

# %% [markdown]
# <h4><a id="microphrase">Harmony and Rhythm</a></h4>

# %% [markdown]
# <div>We have not looked at harmony at all until now, regardless of underlying harmony notes operate in similar ways, there does emerge Contours, similiarieis, repeition of partial. But what about about harmony? Place voice leading at the forefront There are patterns that emerge both in the sequence of chords and the types of chords that can be seen. just using basic chords here. Intereesting questions about idiomatic devices</div>
#
# <div>In the following section we will look at note choice, but also voice leading, do major sevenths lead roots, what is happening</div>

# %% [markdown]
# <div>First to notice is that chords have structre - below shows the distribution of differnt chords used. So it doesn't seem the the case more of a particular type of chord, but this music practice chaaracterised by distribution....</div>

# %%
df.head(1)
# Out:
#   Auxillary note flag Chord name Composer name Genre Global location         Instrument name  Length in quarter notes Link to audio file  Location of note or rest  Midi number Name of note Name of note without octave Part name Performer name Rest or note flag  Semitone distance between current and next note  Semitone distance between current and previous note Structural note flag  Tempo at this location Text written on score Time position in audio file where note appears                Title  Year of composition  Year of performance  Measure number  Location of note or rest within measure  Chord root as minimized midi number  Chord type as minimized midi number Chord bass as minimized midi number Chord type name  Semitone distance between note and chord root Semitone distance between note and chord bass Harmonic function of note given the underlying chord                          Next ten chord type names          Next ten chord root notes as midi numbers veryNextChordType
# 0                None   E min7b5  Victor Young  Jazz            None  Jazz Harmony Bass Note                        4               None                         0           28           E2                           E        P2  Keith Jarrett              note                                                5                                                NaN                   None                     151                  None                                           None  Stella By Starlight                 1944                 1983               1                                        0                                    4                                    7                                  -1          min7b5                                              0                                          None                                               root    [9.0, 0.0, 5.0, 10.0, 3.0, 8.0, 10.0, 4.0, 2.0...  [dom7, min7, dom7, min7, dom7, maj7, dom7, maj...              dom7

# %%
def getNextChord(data_row):
    veryNextChord = None
    if data_row['Next ten chord root notes as midi numbers']:
        veryNextChord = data_row['Next ten chord root notes as midi numbers'][0:1][0]
    return veryNextChord

def getNextChordBass(data_row):
    veryNextChordRoot = None
    currentChordRoot = None
    if data_row['Next ten chord type names']:
        veryNextChordRoot = data_row['Next ten chord type names'][0:1]
        currentChordRoot = data_row['Chord root as minimized midi number']
        veryNextChordRoot = veryNextChordRoot[0] - currentChordRoot
        if veryNextChordRoot < 0:
            veryNextChordRoot = veryNextChordRoot + 12
        #veryNextChordRoot = abs(veryNextChordRoot %12)
        
    return veryNextChordRoot
    
#chords = df[df['chordTypeDisplay'] == 'dom7']

df['veryNextChordType'] = df.apply(getNextChord, axis=1)
df['veryNextChordRootAsInt'] = df.apply(getNextChordBass, axis=1)

# %% [markdown]
# <div> So for these examples, what is the harmony?Major sevents and dominant sevenths are used very heavily and this makes intuitive sense</div>

# %%
df.groupby(['Title', 'Chord type name'])['Chord type name'].count().plot(kind="bar")

# %% [markdown]
# <div>Two interesting questions emerge, one is note choice - her questions kinds of notes are played over a dominant sevent chord. What about a major seventh chord. Are some notes more common that others. How often is a major seventh chord. THere are lots o guidelines but what are they There is a tendency. We can talk about rhythm also, do certain notes occcur at certain times. Major seventh played off the beat on the dominant chord. Prior, generally, leaving all esle aside,  </div>
# <div>
# another questions is about sequences in chords, chord progressions. Are there relationships between chords and other chords
# </div>

# %% [markdown]
# <div> An initial question to ask is about note harmonic relationship</div>

# %%
df[df['Chord name'] == 'C min7b5']['Name of note without octave'].value_counts()[1:].plot(kind="bar")

# %% [markdown]
# <div>THen chords in depth with degrees. The first thing to notice is that there appears to be some kind of relatinoship from all notes to the harmony, but different intensities. Consider the above minor seventh flat five and the below major chord </div>

# %%
df[df['Chord name'] == 'Ab maj7']['Name of note without octave'].value_counts().plot(kind="bar")

# %% [markdown]
# <div>So harmony has come kind of meaning above shows that there harmony has meaning here. A c minor7 b5 chord has certain notes. There are some interesting things, keith jarrett uses major ninth. A major chord has notes. But in both cases, all notes are in play</div>

# %% [markdown]
# <div>What types of chords are here. problematic to use chord extensions as the notes played and subsitution will bear that out. below hows over all, which chords are in play. Across the entire corpus there are different used chords. The diminised is very rare </div>

# %%
df['Chord name'].value_counts().plot(kind="bar")

# %% [markdown]
# <div>. As a preliminary, what about the progressions, Other thing to check out is progressions - movement between chords - overwhemingly through cycle of fourths. Taking into count, the next chord, what is happening</div>

# %%
df['veryNextChordRootAsInt'].value_counts().plot(kind="pie")

# %% [markdown]
# <div>Immedietel question, is what type of degrees are used. THis again is iutivive, relathioship between cycle of fourths, cadence material</div>
# <div>THe data allows a far more granular approach, how chords are moving</div>

# %%
df.groupby(['Chord type name','veryNextChordType','veryNextChordRootAsInt'])['Chord name'].count()
# Out:
# Chord type name  veryNextChordType  veryNextChordRootAsInt
# dim7             fix                1                            8
#                                     2                            7
#                  maj/G              9                            9
#                  maj7               6                           75
#                  maj7/Bb            1                           17
#                                     6                           28
#                  maj7/G             9                            5
#                  min                1                           16
#                  min7               11                         193
# dom7             dom7/E             5                            5
#                  maj                5                           28
#                  maj7               1                          264
#                                     2                          146
#                                     5                         1111
#                                     10                          35
#                  min                5                          119
#                  min7               3                           50
#                                     4                           80
#                                     5                         1757
#                                     6                           62
#                                     7                           72
#                                     9                          209
#                                     10                         267
#                                     11                         186
#                  min7b5             5                          104
# dom7/E           min7               5                           22
# fix              maj7/Bb            4                            3
# maj              dom7               4                           23
# maj/G            min                9                            6
# maj7             dim7               1                           64
#                                                               ...
#                  min7b5             7                           59
#                                     11                         304
# maj7/Bb          fix                8                            1
#                  min6/Bb            5                           36
# maj7/G           dim7               5                            6
# min              dim7               1                           13
#                                     8                           16
#                  dom7               2                           69
#                  dom7/E             5                           19
# min6/Bb          dom7               2                           24
# min7             dim7               1                           28
#                                     11                         206
#                  dom7               5                         1598
#                                     7                          113
#                                     8                           93
#                                     10                          43
#                                     11                         149
#                  maj7               3                           68
#                                     7                          148
#                                     8                           53
#                                     9                           69
#                                     10                         752
#                  min7b5             2                           61
#                                     3                          171
#                                     5                          124
#                                     9                          134
#                                     11                         202
# min7b5           dom7               5                         1037
#                                     10                          84
#                  min7               10                         280
# Name: Chord name, dtype: int64

# %%
df.groupby(['Chord type name','veryNextChordType','veryNextChordRootAsInt'])['Chord name'].count().plot(kind="bar")

# %% [markdown]
# <div>So above we see pathways spike moving in fourths</div>

# %% [markdown]
# <div>Returning to note degrees, are played, it is possible to look at the roots, broadly stepping back finds some trends, that regarldess of song, jarrett uses root heavily. </div>

# %%
fig, axes = plt.subplots(nrows=2,ncols=3)

df[df['Title'] == 'Stella By Starlight']['Harmonic function of note given the underlying chord'].value_counts().plot(kind="bar", ax=axes[0,0], figsize=(20, 10), title='Stella By Starlight')
df[df['Title'] == 'Autumn Leaves']['Harmonic function of note given the underlying chord'].value_counts().plot(kind="bar", ax=axes[0,1], figsize=(20, 10), title='Autumn Leaves')
df[df['Title'] == 'Groovin High']['Harmonic function of note given the underlying chord'].value_counts().plot(kind="bar", ax=axes[0,2], figsize=(20, 10), title='Groovin High')
df[df['Title'] == 'All The Things You Are']['Harmonic function of note given the underlying chord'].value_counts().plot(kind="bar", ax=axes[1,0], figsize=(20, 10), title='All The Things You Are')
df[df['Title'] == 'If I Were A Bell']['Harmonic function of note given the underlying chord'].value_counts().plot(kind="bar", ax=axes[1,1], figsize=(20, 10), title='If I Were A Bell')
subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None, hspace=0.8)

left  = 0.125  # the left side of the subplots of the figure
right = 0.9    # the right side of the subplots of the figure
bottom = 0.3   # the bottom of the subplots of the figure
top = 2      # the top of the subplots of the figure
wspace = 0.2   # the amount of width reserved for blank space between subplots
hspace = 2   # the amount of height reserved for white space between subplots

# %% [markdown]
# <div>Above shows the flattended fith is not as important typcial jazz. But in corea if functions differently</div>

# %% [markdown]
# <div>So that is some general remarks, but what about looking more closely at particular chord types. One thing to do is look at Dominant chords. But to look at dominant chords, how does note choice behave in terms of harmony. We know melodically there is a preference for small leaps, but harmonically how do things behave</div>

# %% [markdown]
# <div>Again with dom, heavy use of the root note. So how exactly is the root note used in Jarrett's solos</div>

# %%
df[df['Chord type name'] == 'dom7']['Harmonic function of note given the underlying chord'].value_counts().plot(kind="bar")

# %% [markdown]
# <div> The first thing to notice is that the root is really dominant - this goes against seventh and third stuff, fifth is important also, and is a trend across all the solos </div>

# %% [markdown]
# <div>Break it down by song</div>

# %%
#df1 = df[(df.a != -1) & (df.b != -1)]
fig, axes = plt.subplots(nrows=2,ncols=3)

df[(df['Title'] == 'Stella By Starlight') & (df['Chord type name'] == 'dom7')]['Harmonic function of note given the underlying chord'].value_counts().plot(kind="bar", ax=axes[0,0], figsize=(20, 10), title='Dominant Chords In Stella By Starlight')
df[(df['Title'] == 'Autumn Leaves') & (df['Chord type name'] == 'dom7')]['Harmonic function of note given the underlying chord'].value_counts().plot(kind="bar", ax=axes[0,1], figsize=(20, 10), title='Dominant Chords In Autumn Leaves')
df[(df['Title'] == 'Groovin High') & (df['Chord type name'] == 'dom7')]['Harmonic function of note given the underlying chord'].value_counts().plot(kind="bar", ax=axes[0,2], figsize=(20, 10), title='Dominant Chords In Groovin High')
df[(df['Title'] == 'All The Things You Are') & (df['Chord type name'] == 'dom7')]['Harmonic function of note given the underlying chord'].value_counts().plot(kind="bar", ax=axes[1,0], figsize=(20, 10), title='Dominant Chords In All The Things You Are')
df[(df['Title'] == 'If I Were A Bell') & (df['Chord type name'] == 'dom7')]['Harmonic function of note given the underlying chord'].value_counts().plot(kind="bar", ax=axes[1,1], figsize=(20, 10), title='Dominant Chords In If I Were A Bell')
subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None, hspace=0.8)

left  = 0.125  # the left side of the subplots of the figure
right = 0.9    # the right side of the subplots of the figure
bottom = 0.3   # the bottom of the subplots of the figure
top = 2      # the top of the subplots of the figure
wspace = 0.2   # the amount of width reserved for blank space between subplots
hspace = 2   # the amount of height reserved for white space between subplots

# %% [markdown]
# <div>However the root is not played more often, it occurs in come kind of context. It is proceeded by paritcular notes, and followed by other notes is key here. but how is it behaving. The root doesn't just appear as a statistically most common note - it is rather quiet different, it is driven what happens before and what happens afterw which is a questions</div>

# %% [markdown]
# <div>So how is the root prepared, in terms of voice leading</div>

# %%
df[(df['Part name'] == 'P1') &(df['Harmonic function of note given the underlying chord'] == 'root') & (df['Chord type name'] == 'dom7')]['Semitone distance between current and previous note'].value_counts().plot(kind="pie", figsize=(8,8), title='What note is played before the root on a dominant chord')

# %% [markdown]
# <div>Overall, the use of the root chord is very structured, over 50 percent of cases, there are ony 4 possible note shtat come before it. Some of this is the predominance in tones and semitones, use of a major third how does each note  in terms of the various solos </div>

# %%
fig, axes = plt.subplots(nrows=4,ncols=1)

df[(df['Part name'] == 'P1') & (df['Title'] == 'Stella By Starlight') & (df['Harmonic function of note given the underlying chord'] == 'root') & (df['Chord type name'] == 'dom7')]['Semitone distance between current and previous note'].value_counts().plot(kind="pie", figsize=(7,7), ax=axes[0], title='What note is played before the root on a dominant chord in Stella By Starlight')
df[(df['Part name'] == 'P1') & (df['Title'] == 'Groovin High') & (df['Harmonic function of note given the underlying chord'] == 'root') & (df['Chord type name'] == 'dom7')]['Semitone distance between current and previous note'].value_counts().plot(kind="pie", figsize=(7,7), ax=axes[1], title='What note is played before the root on a dominant chord in Groovin High')
df[(df['Part name'] == 'P1') & (df['Title'] == 'Autumn Leaves') & (df['Harmonic function of note given the underlying chord'] == 'root') & (df['Chord type name'] == 'dom7')]['Semitone distance between current and previous note'].value_counts().plot(kind="pie", figsize=(7,7), ax=axes[2], title='What note is played before the root on a dominant chord in Autumn Leaves')
df[(df['Part name'] == 'P1') & (df['Title'] == 'If I Were A Bell') & (df['Harmonic function of note given the underlying chord'] == 'root') & (df['Chord type name'] == 'dom7')]['Semitone distance between current and previous note'].value_counts().plot(kind="pie", figsize=(7,7), ax=axes[3], title='What note is played before the root on a dominant chord in If I Were A Bell')

axes[0].legend(['The major third of the dominant chord', 'The flat ninth of the dominant chord'])

axes[0].legend(['The major third of the dominant chord', 'The flat ninth of the dominant chord'],bbox_to_anchor=(1.1, 1.05))

left  = 1.0  # the left side of the subplots of the figure
right = 3.0    # the right side of the subplots of the figure
bottom = 1.0   # the bottom of the subplots of the figure
top = 3.0      # the top of the subplots of the figure
wspace = 0   # the amount of width reserved for blank space between subplots
hspace = 0   # the amount of height reserved for white space between subplots

subplots_adjust(left=left, bottom=bottom, right=right, top=top, wspace=None, hspace=None)

# %% [markdown]
# <div>This unusual. It it more to do with progression, or chord minor or major, challenges play on a dominant chord, but says that dominant chords appear to be treated differently depening on the overall song. But as a musicin this seems counter inutivie It suggests that it is not the full story. constrain results to V I and include tonality of minor or major. So good idea to look at</div>
# <div>Limit the dominant chords under consideration here, to just those V of a major chord, (such as G7 moving to C major). As opposed to G dom7 leading to F# minor 7 b5</div>

# %% [markdown]
# <div>Perhaps a deeper quesion to ask is to keep in mind the nature of the progression - take into account these progression, before examining the voice leading, to locate them in progressions</div>

# %%
dfV_IMinAllDegrees = df[(df['Part name'] == 'P1') &(df['Chord type name'] == 'dom7') &(df['veryNextChordType'] == 'min7') & (df['veryNextChordRootAsInt'] == 5) ]

# %%
dfV_IMinAllDegrees['Harmonic function of note given the underlying chord'].value_counts()
# Out:
# root                              197
# fifth                             179
# seventh                           165
# flat thirteenth or sharp fifth    153
# major third                       116
# sharp ninth or minor third        113
# eleventh                          108
# flat ninth                         93
# thirteenth                         82
# major seventh                      69
# sharp eleventh or flat fifth       68
# ninth                              65
# dtype: int64

# %%
dfV_IMajAllDegrees = df[(df['Part name'] == 'P1') &(df['Chord type name'] == 'dom7') &(df['veryNextChordType'] == 'maj7') & (df['veryNextChordRootAsInt'] == 5) ]

# %%
dfV_IMajAllDegrees['Harmonic function of note given the underlying chord'].value_counts()
# Out:
# major third                       107
# seventh                           105
# root                              100
# thirteenth                         97
# fifth                              93
# ninth                              78
# flat ninth                         74
# eleventh                           57
# sharp ninth or minor third         41
# major seventh                      41
# flat thirteenth or sharp fifth     36
# sharp eleventh or flat fifth       32
# dtype: int64

# %%
dfV_IMinJustRoot = df[(df['Part name'] == 'P1') &(df['Harmonic function of note given the underlying chord'] == 'root') &(df['Chord type name'] == 'dom7') &(df['veryNextChordType'] == 'min7') & (df['veryNextChordRootAsInt'] == 5) ]

# %% [markdown]
# <div>So Note choice is affected by the chord that comes after dominant chord and heavily so. Question to ask is what happens to root note on a dominant chord when it is minor progression</div>

# %%
fig, axes = plt.subplots(nrows=2,ncols=1)

dfV_IMinJustRoot[dfV_IMinJustRoot['Title'] == 'Autumn Leaves']['Semitone distance between current and previous note'].value_counts().plot(kind="pie", figsize=(7,7), ax=axes[0], title='What note is played before the root on a dominant chord in Autumn Leaves')
dfV_IMinJustRoot[dfV_IMinJustRoot['Title'] == 'If I Were A Bell']['Semitone distance between current and previous note'].value_counts().plot(kind="pie", figsize=(7,7), ax=axes[1], title='What note is played before the root on a dominant chord in If I Were A Bell')


axes[0].legend(['The major third of the dominant chord', 'The flat ninth of the dominant chord'],bbox_to_anchor=(1.1, 1.05))

left  = 1.0  # the left side of the subplots of the figure
right = 3.0    # the right side of the subplots of the figure
bottom = 1.0   # the bottom of the subplots of the figure
top = 3.0      # the top of the subplots of the figure
wspace = 0   # the amount of width reserved for blank space between subplots
hspace = 0   # the amount of height reserved for white space between subplots

subplots_adjust(left=left, bottom=bottom, right=right, top=top, wspace=None, hspace=None)

# %% [markdown]
# <div>Look at some examples</div>

# %%
#dfV_Imin[(dfV_Imin['title'] == 'If I Were A Bell') &(dfV_Imin['prevNoteFreqDistance'] == 1)]

# %%
#Ab going to the G
select = muAutumnLeaves.parts[0].measures(20,21)
select.show()

# %%
#Ab going to G
select = muAutumnLeaves.parts[0].measures(72,73)
select.show()

# %%
#Eb going to D
select = muAutumnLeaves.parts[0].measures(158,159)
select.show()

# %%
#Gb going to an F in a similiar fashion. 
select = muIfIWereABell.parts[0].measures(73,74)
select.show()

# %% [markdown]
# <div>What this suggests, the thesis here, is that Jarrett always produces variation, but taking two isolated notes out shows that there is structure - a tendency for the root to be predominant, and a tendency for it to preceeded by a the flat ningth when it is in a minor progression. An alternate way of saying this is that if there is a 44% chance a dominant chord will be occuring. if this is the case, a dom chord is occuring, there is 44% chance that root note will be played. If this occurs, flat ninth. In terms of all the data set, tells us little, but behaviour modified level it says something really definitive is happening</div>

# %% [markdown]
# <div>This goes to the heart of the issue, lots information, tells with great granularity how this chord is behaving. The following chapter will go into more depth of the problem of informatin this presents. essentially this is a case study approach</div>

# %% [markdown]
# <div>What about afterward the root note plays, what is happening, limit only to Autumn leaves </div>

# %%
dfV_IMinJustRoot[dfV_IMinJustRoot['Title'] == 'Autumn Leaves']['Semitone distance between current and next note'].value_counts().plot(kind="pie")

# %% [markdown]
# <div>This says that D dominant seventh, to put into contect, d note most ofent F, C, a G, Eb, C# etc</div>

# %%
dfV_IMinJustRoot[(dfV_IMinJustRoot['Title'] == 'Autumn Leaves') & (dfV_IMinJustRoot['Semitone distance between current and next note'] == 5)]
# Out:
#      Auxillary note flag Chord name Composer name Genre Global location           Instrument name  Length in quarter notes Link to audio file  Location of note or rest  Midi number Name of note Name of note without octave Part name Performer name Rest or note flag  Semitone distance between current and next note  Semitone distance between current and previous note Structural note flag  Tempo at this location Text written on score Time position in audio file where note appears          Title  Year of composition  Year of performance  Measure number  Location of note or rest within measure  Chord root as minimized midi number  Chord type as minimized midi number Chord bass as minimized midi number Chord type name  Semitone distance between note and chord root Semitone distance between note and chord bass Harmonic function of note given the underlying chord                          Next ten chord type names          Next ten chord root notes as midi numbers veryNextChordType  veryNextChordRootAsInt
# 126                 None     D dom7  Joseph Kosma  Jazz            None  Piano Solo Jazz (Treble)                      0.5               None                     70.98           50           D4                           D        P1  Keith Jarrett              note                                                5                                                 -2                   None                     214                  None                                           None  Autumn Leaves                 1945                 1996              18                                     2.98                                    2                                  NaN                                  -1            dom7                                              0                                          None                                               root    [7.0, 0.0, 5.0, 10.0, 3.0, 9.0, 2.0, 7.0, 5.0,...  [min7, dom7, min7, dom7, maj7, min7b5, dom7, m...              min7                       5
# 191                 None     D dom7  Joseph Kosma  Jazz            None  Piano Solo Jazz (Treble)                      0.5               None                    102.48           50           D4                           D        P1  Keith Jarrett              note                                                5                                                 -4                   None                     214                  None                                           None  Autumn Leaves                 1945                 1996              26                                     2.48                                    2                                  NaN                                  -1            dom7                                              0                                          None                                               root    [7.0, 5.0, 3.0, 9.0, 7.0, 0.0, 5.0, 10.0, 3.0,...  [min7, dom7, maj7, min7b5, min7, dom7, min7, d...              min7                       5
# 441                 None     D dom7  Joseph Kosma  Jazz            None  Piano Solo Jazz (Treble)                      0.5               None                    228.41           62           D5                           D        P1  Keith Jarrett              note                                                5                                                 -1                   None                     214                  None                                           None  Autumn Leaves                 1945                 1996              58                                     0.41                                    2                                  NaN                                  -1            dom7                                              0                                          None                                               root    [7.0, 5.0, 3.0, 2.0, 7.0, 0.0, 5.0, 10.0, 3.0,...  [min7, dom7, maj7, dom7, min7, dom7, min7, dom...              min7                       5
# 543                 None     D dom7  Joseph Kosma  Jazz            None  Piano Solo Jazz (Treble)                      0.5               None                    278.90           62           D5                           D        P1  Keith Jarrett              note                                                5                                                 -2                   None                     214                  None                                           None  Autumn Leaves                 1945                 1996              70                                     2.90                                    2                                  NaN                                  -1            dom7                                              0                                          None                                               root    [7.0, 0.0, 5.0, 10.0, 3.0, 9.0, 2.0, 7.0, 9.0,...  [min7, dom7, min7, dom7, maj7, min7b5, dom7, m...              min7                       5
# 650                 None     D dom7  Joseph Kosma  Jazz            None  Piano Solo Jazz (Treble)                      0.5               None                    327.20           50           D4                           D        P1  Keith Jarrett              note                                                5                                                NaN                   None                     214                  None                                           None  Autumn Leaves                 1945                 1996              82                                     3.20                                    2                                  NaN                                  -1            dom7                                              0                                          None                                               root    [7.0, 0.0, 5.0, 10.0, 3.0, 9.0, 2.0, 7.0, 5.0,...  [min7, dom7, min7, dom7, maj7, min7b5, dom7, m...              min7                       5
# 1114                None     D dom7  Joseph Kosma  Jazz            None  Piano Solo Jazz (Treble)                      0.5               None                    536.00           62           D5                           D        P1  Keith Jarrett              note                                                5                                                 -1                   None                     214                  None                                           None  Autumn Leaves                 1945                 1996             134                                     4.00                                    2                                  NaN                                  -1            dom7                                              0                                          None                                               root    [7.0, 0.0, 5.0, 10.0, 3.0, 9.0, 2.0, 7.0, 9.0,...  [min7, dom7, min7, dom7, maj7, min7b5, dom7, m...              min7                       5
# 1166                None     D dom7  Joseph Kosma  Jazz            None  Piano Solo Jazz (Treble)                      0.5               None                    566.00           50           D4                           D        P1  Keith Jarrett              note                                                5                                                 -4                   None                     214                  None                                           None  Autumn Leaves                 1945                 1996             142                                     2.00                                    2                                  NaN                                  -1            dom7                                              0                                          None                                               root    [7.0, 9.0, 2.0, 7.0, 0.0, 5.0, 10.0, 3.0, 9.0,...  [min7, min7b5, dom7, min7, dom7, min7, dom7, m...              min7                       5

# %% [markdown]
# <div>really seeing similiartity here</div>

# %%
#D going to G
select = muAutumnLeaves.parts[0].measures(18,19)
select.show()

# %%
select = muAutumnLeaves.parts[0].measures(26,27)
select.show()

# %%
select = muAutumnLeaves.parts[0].measures(58,59)
select.show()

# %%
select = muAutumnLeaves.parts[0].measures(70,71)
select.show()

# %%
select = muAutumnLeaves.parts[0].measures(142,143)
select.show()

# %%
dfV_IMinJustFifth = df[(df['Part name'] == 'P1') &(df['Harmonic function of note given the underlying chord'] == 'fifth') &(df['Chord type name'] == 'dom7') &(df['veryNextChordType'] == 'min7') & (df['veryNextChordRootAsInt'] == 5) ]

# %%
fig, axes = plt.subplots(nrows=2,ncols=1)

dfV_IMinJustFifth[dfV_IMinJustFifth['Title'] == 'Autumn Leaves']['Semitone distance between current and previous note'].value_counts().plot(kind="pie", figsize=(7,7), ax=axes[0], title='What note is played before the root on a dominant chord in Autumn Leaves')
dfV_IMinJustFifth[dfV_IMinJustFifth['Title'] == 'If I Were A Bell']['Semitone distance between current and previous note'].value_counts().plot(kind="pie", figsize=(7,7), ax=axes[1], title='What note is played before the root on a dominant chord in If I Were A Bell')


axes[0].legend(['The major third of the dominant chord', 'The flat ninth of the dominant chord'],bbox_to_anchor=(1.1, 1.05))

left  = 1.0  # the left side of the subplots of the figure
right = 3.0    # the right side of the subplots of the figure
bottom = 1.0   # the bottom of the subplots of the figure
top = 3.0      # the top of the subplots of the figure
wspace = 0   # the amount of width reserved for blank space between subplots
hspace = 0   # the amount of height reserved for white space between subplots

subplots_adjust(left=left, bottom=bottom, right=right, top=top, wspace=None, hspace=None)

# %% [markdown]
# <div> Its possible to go through all and in the hte next chpater - but establishes a case that each note has certain tendencies JG _ GO through the ROOT, FIFTH AND SEVENTH TO SEE HOW THEY ARE BEHAVING, CONSTRUCT VOICE LEADING SHENKER STYLE</div>

# %% [markdown]
# <div>But it gets exhaustive to go through this process, but it establishes that there is deep structure here, not driven by sets of notes, but behavious at certain points </div>

# %%
# note0 = mu.note.Note("F5")
# note0.duration.type = 'half'
# note1 = mu.note.Note("C4")
# note1.duration.type = 'eighth'
# note2 = mu.note.Note("F#4")

# streamOne = mu.stream.Stream()
# streamOne.append(note0)
# streamOne.append(note1)
# streamOne.append(note2)

# %%
#streamOne.show()

# %%
x = df.groupby('Chord name')

# %%
x = df

# %%
x.head()
# Out:
#   Auxillary note flag Chord name Composer name Genre Global location           Instrument name  Length in quarter notes Link to audio file  Location of note or rest  Midi number Name of note Name of note without octave Part name Performer name Rest or note flag  Semitone distance between current and next note  Semitone distance between current and previous note Structural note flag  Tempo at this location Text written on score Time position in audio file where note appears                Title  Year of composition  Year of performance  Measure number  Location of note or rest within measure  Chord root as minimized midi number  Chord type as minimized midi number Chord bass as minimized midi number Chord type name  Semitone distance between note and chord root Semitone distance between note and chord bass Harmonic function of note given the underlying chord                          Next ten chord type names          Next ten chord root notes as midi numbers veryNextChordType  veryNextChordRootAsInt
# 0                None   E min7b5  Victor Young  Jazz            None    Jazz Harmony Bass Note                      4.0               None                       0.0           28           E2                           E        P2  Keith Jarrett              note                                                5                                                NaN                   None                     151                  None                                           None  Stella By Starlight                 1944                 1983               1                                      0.0                                    4                                    7                                  -1          min7b5                                              0                                          None                                               root    [9.0, 0.0, 5.0, 10.0, 3.0, 8.0, 10.0, 4.0, 2.0...  [dom7, min7, dom7, min7, dom7, maj7, dom7, maj...              dom7                       5
# 1                None   E min7b5  Victor Young  Jazz            None  Piano Solo Jazz (Treble)                      0.5               None                       0.0           55           G4                           G        P1  Keith Jarrett              note                                              NaN                                                NaN                   None                     151                  None                                           None  Stella By Starlight                 1944                 1983               1                                      0.0                                    4                                  NaN                                  -1          min7b5                                              3                                          None                         sharp ninth or minor third    [9.0, 0.0, 5.0, 10.0, 3.0, 8.0, 10.0, 4.0, 2.0...  [dom7, min7, dom7, min7, dom7, maj7, dom7, maj...              dom7                       5
# 2                None   E min7b5  Victor Young  Jazz            None  Piano Solo Jazz (Treble)                      0.5               None                       0.5          NaN         None                        None        P1  Keith Jarrett              rest                                              NaN                                                NaN                   None                     151                  None                                           None  Stella By Starlight                 1944                 1983               1                                      0.5                                    4                                  NaN                                  -1          min7b5                                            NaN                                          None                                                NaN    [9.0, 0.0, 5.0, 10.0, 3.0, 8.0, 10.0, 4.0, 2.0...  [dom7, min7, dom7, min7, dom7, maj7, dom7, maj...              dom7                       5
# 3                None   E min7b5  Victor Young  Jazz            None  Piano Solo Jazz (Treble)                      0.5               None                       1.0          NaN         None                        None        P1  Keith Jarrett              rest                                              NaN                                                NaN                   None                     151                  None                                           None  Stella By Starlight                 1944                 1983               1                                      1.0                                    4                                  NaN                                  -1          min7b5                                            NaN                                          None                                                NaN    [9.0, 0.0, 5.0, 10.0, 3.0, 8.0, 10.0, 4.0, 2.0...  [dom7, min7, dom7, min7, dom7, maj7, dom7, maj...              dom7                       5
# 4                None   E min7b5  Victor Young  Jazz            None  Piano Solo Jazz (Treble)                      0.5               None                       1.5           57           A4                           A        P1  Keith Jarrett              note                                                1                                                NaN                   None                     151                  None                                           None  Stella By Starlight                 1944                 1983               1                                      1.5                                    4                                  NaN                                  -1          min7b5                                              5                                          None                                           eleventh    [9.0, 0.0, 5.0, 10.0, 3.0, 8.0, 10.0, 4.0, 2.0...  [dom7, min7, dom7, min7, dom7, maj7, dom7, maj...              dom7                       5

# %%
a = x.set_index(['Chord name', 'Year of performance', 'Rest or note flag', 'Composer name'])

# %%
pd.melt(a)
# Out:
#                       variable value
# 0          Auxillary note flag  None
# 1          Auxillary note flag  None
# 2          Auxillary note flag  None
# 3          Auxillary note flag  None
# 4          Auxillary note flag  None
# 5          Auxillary note flag  None
# 6          Auxillary note flag  None
# 7          Auxillary note flag  None
# 8          Auxillary note flag  None
# 9          Auxillary note flag  None
# 10         Auxillary note flag  None
# 11         Auxillary note flag  None
# 12         Auxillary note flag  None
# 13         Auxillary note flag  None
# 14         Auxillary note flag  None
# 15         Auxillary note flag  None
# 16         Auxillary note flag  None
# 17         Auxillary note flag  None
# 18         Auxillary note flag  None
# 19         Auxillary note flag  None
# 20         Auxillary note flag  None
# 21         Auxillary note flag  None
# 22         Auxillary note flag  None
# 23         Auxillary note flag  None
# 24         Auxillary note flag  None
# 25         Auxillary note flag  None
# 26         Auxillary note flag  None
# 27         Auxillary note flag  None
# 28         Auxillary note flag  None
# 29         Auxillary note flag  None
# ...                        ...   ...
# 460914  veryNextChordRootAsInt     5
# 460915  veryNextChordRootAsInt     5
# 460916  veryNextChordRootAsInt     5
# 460917  veryNextChordRootAsInt     5
# 460918  veryNextChordRootAsInt     5
# 460919  veryNextChordRootAsInt     2
# 460920  veryNextChordRootAsInt     2
# 460921  veryNextChordRootAsInt     2
# 460922  veryNextChordRootAsInt     2
# 460923  veryNextChordRootAsInt     2
# 460924  veryNextChordRootAsInt     5
# 460925  veryNextChordRootAsInt     5
# 460926  veryNextChordRootAsInt     5
# 460927  veryNextChordRootAsInt     5
# 460928  veryNextChordRootAsInt     5
# 460929  veryNextChordRootAsInt     5
# 460930  veryNextChordRootAsInt     5
# 460931  veryNextChordRootAsInt     4
# 460932  veryNextChordRootAsInt     4
# 460933  veryNextChordRootAsInt     4
# 460934  veryNextChordRootAsInt     4
# 460935  veryNextChordRootAsInt     4
# 460936  veryNextChordRootAsInt     4
# 460937  veryNextChordRootAsInt   NaN
# 460938  veryNextChordRootAsInt   NaN
# 460939  veryNextChordRootAsInt   NaN
# 460940  veryNextChordRootAsInt   NaN
# 460941  veryNextChordRootAsInt   NaN
# 460942  veryNextChordRootAsInt   NaN
# 460943  veryNextChordRootAsInt   NaN
#
# [460944 rows x 2 columns]

# %%
c = pd.read_csv('test.csv')
